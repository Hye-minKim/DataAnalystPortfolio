# %% [markdown]
# ## 크몽 데이터팀에 오신 것을 환영합니다!
#
# <img src = 'https://t1.daumcdn.net/thumb/R1280x0/?fname=http://t1.daumcdn.net/brunch/service/user/11Yx/image/jNo1MfbPhIsud4DhAFh5fej9nQA.jpg' width=180 />
#
# <center><small><a href="https://kmong.com/">kmong.com</a></small></center>
#
# 안녕하세요! [크몽](https://kmong.com) 데이터팀에 오신 것을 환영합니다.
#
# 크몽은 "비합리적인 서비스 시장을 정보기술로 혁신하여 새로운 일자리를 만들고 사람들이 행복하게 일하는 세상을 만든다."는 미션을 가지고 있는 프리랜서 마켓 플랫폼입니다. 크몽팀은 디자인, 마케팅, IT&개발, 컨텐츠 제작, 통번역 등 다양한 서비스 카테고리를 기반으로 직업과 직장의 경계를 허물며 사람들이 스스로 경제 주체가 되어 행복하게 일하는 세상을 만들고 있습니다.
#
# 크몽에서는 주어진 데이터를 활용하여 1) 사용자에게 새로운 상품을 추천하거나, 2) 오픈마켓에서 금기시되는 개인간 거래를 발견하 등 다양한 분야에서 데이터와 머신러닝 알고리즘을 사용합니다. 여기에는 크몽의 서비스에서 발생한 다양한 데이터를 사용하게 되는데, 이 부분에서 가장 중요한 것이 바로 데이터를 정리하는 과정, 일명 데이터 클리닝([Data Cleaning](https://en.wikipedia.org/wiki/Data_cleansing))입니다.

# %%
# 파이썬의 import를 활용해 데이터 분석용 패키지인 판다스(Pandas)를 읽어옵니다.
import pandas as pd

# 판다스 데이터프레임(DataFrame)을 출력할 때, 최대 출력할 수 있는 컬럼을 100개로 늘려줍니다.
# 이렇게 해야 데이터를 분석할 때 출력해서 확인하기 편합니다.
pd.options.display.max_columns = 100

# %% [markdown]
# ### 데이터 로딩하기
#
# 먼저 데이터를 로딩해오겠습니다. 데이터를 읽어올때는 [판다스(Pandas)](https://pandas.pydata.org/)의 [read_csv](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) 라는 기능을 사용합니다.
#
# 여기서 파일의 경로를 지정하는 방법에 주의하셔야 합니다. read_csv를 실행할 때 (**FileNotFoundError**)라는 이름의 에러가 난다면 경로가 제대로 지정이 되지 않은 것입니다.

# %% [markdown]
# **kmong-conversion.csv**
#
# 먼저 크몽의 로그 데이터를 하나씩 가져오겠습니다. 가장 처음 가져올 데이터는 크몽의 가장 핵심 데이터라고 할 수 있는 ```kmong-conversion.csv``` 입니다. 여기에는 사용자가 크몽의 웹사이트/모바일 서비스에서 활동한 모든 활동 기록(activity)이 상세하게 담겨져 있으며, 이 정보를 바탕으로 데이터를 분석하여 사용자의 패턴을 유추할 수 있습니다. 컬럼 정보는 다음과 같습니다.
#
# * ```eventcategory```: 앱의 이벤트에 대한 카테고리입니다. 크게 다음의 종류가 있습니다.
#   - ```install```: 앱설치
#   - ```launch```: 앱실행
#   - ```deeplinkLaunch```: 딥링크 통한 앱실행
#   - ```goal```: 앱 내에서의 활동 여부
#   - ```exit```: 앱 종료
#   - ```foreground```, background```: 앱을 foreground, background로 전환
#   - ```launchlnSession```: Session의 시작.
# * ```isfirstactivity```: 해당 이벤트가 해당 유저에 한하여 첫 번째인지 혹은 두 번째 이상인지를 알려주는 값입니다.
#   - boolean 형식으로, 해당 이벤트가 해당 유저에 한하여 첫 번째 이벤트이면 True, 아니면 False를 갖습니다.
# * ```apppackagename```: 앱의 패키지의 고유한 이름입니다. 안드로이드의 경우 applicationId을, iOS의 경우 Bundle ID를 가져오게 됩니다.
# * ```appversion```: kmong 어플리케이션의 버전입니다.
# * ```devicetype```: 사용자가 kmong app을 실행하고 있는 기기의 제품명입니다.
# * ```devicemanufacturer```: 사용자가 kmong app을 실행하고 있는 기기의 제조회사입니다.
# * ```osversion```: 사용자가 kmong app을 실행하고 있는 기기의 os 버전입니다.
# * ```canonicaldeviceuuid```: 사용자가 kmong app을 실행하고 있는 기기의 고유 식별자입니다. (사용자를 구분하는 식별자로 이용할 수 있습니다)
# * ```sourcetype```: 해당 로그를 만든 고객이 유입된 경로입니다. 유료 광고 채널, 바이럴 채널, 앱 마켓 등으로 구분합니다.
# * ```channel```: sourcetype과 동일하지만 조금 더 세분화되어 있습니다.
#   - unattributed, WEB, google-play, m_naver, google, (not set), google.adwords, m_naverpowercontents, pc_naver, apple.searchads, facebook, m_daum
# * ```params_campaign```: 마케터가 입력한 캠페인 파라미터 중 캠페인명입니다.
# * ```params_medium```: 마케터가 입력한 캠페인 파라미터 중 매체입니다.
# * ```params_term```: 마케터가 입력한 캠페인 파라미터 중 키워드입니다.
# * ```inappeventcategory```: 인앱이벤트 식별자값으로 인앱이벤트를 지칭하는 3개의 값(category > action > label) 중 가장 상위에 속하는 구분값입니다.
#   - ```eventcategory```가 goal인 경우에만 제공됩니다.
#   - 차후에 읽어올 funnel 데이터셋과 연결할 수 있습니다.
#   - ex) seller_selling_history.view, gig_detail.view
# * ```inappeventlabel```: categoryid와 동일합니다.
#   - 차후에 읽어올 category 데이터셋과 연결할 수 있습니다.
#   - 인앱이벤트를 지칭하는 3개의 값(category > action > label) 중 마지막에 속하는 구분값입니다.
# * ```eventdatetime```: 모바일 클라이언트 상에서의 실제 이벤트 발생시간입니다. ISO 8601 표준에 따라서 제공됩니다.
# * ```isfirstgoalactivity```: goal 이벤트의 경우, 해당 Goal Label, Description, Key, Category를 가진 이벤트가 해당 유저에 한하여 첫 번째인지 혹은 두 번째 이상 인지를 알려주는 boolean 값입니다. 예를 들어 동일한 유저로부터 두 번 이상의 같은 Goal 이벤트가 발생한 경우(e.g. 동일한 물건 재구매 등) 이 값은 false가 됩니다.
#
# * ```event_rank```: 데이터를 정렬하는데 필요한 컬럼입니다. log엔 기록되지 않으며, 자체 제공되는 전처리된 컬럼입니다.

# %%
# 판다스(pandas)의 read_csv를 활용하여 크몽의 전환 정보(conversion) 관련 기록을 저장한 kmong-conversion.csv을 읽어옵니다.
# 이 데이터를 conversion라는 이름의 변수에 할당합니다.
conversion = pd.read_csv("data/kmong/kmong-conversion.csv")

# conversion 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(conversion.shape)

# head()로 conversion 데이터의 상위 5개를 띄웁니다.
conversion.head()
# Out:
# (434244, 19)
#   eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0          goal           False    com.kmong.iOS      4.0.4     iPhone
# 1          goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2          goal           False    com.kmong.iOS      4.0.4     iPhone
# 3    foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4          goal           False    com.kmong.iOS      4.0.4     iPhone
#
#   devicemanufacturer   osversion                   canonicaldeviceuuid  \
# 0              Apple   iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1            samsung  Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2              Apple     iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3              Apple   iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4              Apple   iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
#
#      sourcetype       channel params_campaign params_medium params_term  \
# 0  unattributed  unattributed             NaN           NaN         NaN
# 1  unattributed  unattributed             NaN           NaN         NaN
# 2  unattributed  unattributed             NaN           NaN         NaN
# 3           NaN           NaN             NaN           NaN         NaN
# 4         viral           WEB             NaN           NaN         NaN
#
#        inappeventcategory  inappeventlabel              eventdatetime  \
# 0               home.view              NaN  2018-09-28T00:00:00+09:00
# 1         gig_detail.view          41201.0  2018-09-28T00:00:00+09:00
# 2       inbox_detail.view              NaN  2018-09-28T00:00:00+09:00
# 3                     NaN              NaN  2018-09-28T00:00:01+09:00
# 4  buyer_order_track.view              NaN  2018-09-28T00:00:02+09:00
#
#                                 rowuuid isfirstgoalactivity  event_rank
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817               False        True
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38               False        True
# 2  14eb3197-db83-493a-b7be-83582960c40b               False        True
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                 NaN        True
# 4  236e9946-7801-4898-b609-06c8ab1139dc               False        True

# %%
conversion.params_campaign.value_counts()
# Out:
# mweb-app-install      3186
# 1431863900            2696
# 1569347016            1378
# design                 801
# 1234567890             697
# contentsproduction     163
# brand                  162
# dynamic                 56
# consulting              46
# 0                       31
# translation             21
# lesson                  15
# 101                     12
# 1002                    12
# marketing               12
# curation                11
# writing                 10
# 215                      4
# ITprogramming            3
# 1431863900.0             2
# Name: params_campaign, dtype: int64

# %%
conversion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434244 entries, 0 to 434243
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   eventcategory        434244 non-null  object
#  1   isfirstactivity      331165 non-null  object
#  2   apppackagename       434244 non-null  object
#  3   appversion           434244 non-null  object
#  4   devicetype           434244 non-null  object
#  5   devicemanufacturer   434244 non-null  object
#  6   osversion            434244 non-null  object
#  7   canonicaldeviceuuid  434244 non-null  object
#  8   sourcetype           331165 non-null  object
#  9   channel              331165 non-null  object
#  10  params_campaign      9318 non-null    object
#  11  params_medium        27919 non-null   object
#  12  params_term          1941 non-null    object
#  13  inappeventcategory   305533 non-null  object
#  14  inappeventlabel      60834 non-null   float64
#  15  eventdatetime        434244 non-null  object
#  16  rowuuid              434244 non-null  object
#  17  isfirstgoalactivity  331165 non-null  object
#  18  event_rank           434244 non-null  bool
# dtypes: bool(1), float64(1), object(17)
# memory usage: 60.0+ MB

# %%
conversion.describe()
# Out:
#        inappeventlabel
# count     60834.000000
# mean       7885.390966
# std       15176.355757
# min           1.000000
# 25%         104.000000
# 50%         408.000000
# 75%       10201.000000
# max       72505.000000

# %% [markdown]
# **kmong-funnel.csv**
#
# 그 다음 가져올 데이터셋은 퍼널(Funnel) 정보를 나타내는 ```kmong-funnel.csv``` 입니다. 퍼널은 사용자가 서비스에 접속한 뒤 상품을 구매하기까지의 모든 경로를 구조화 한 것을 의미합니다.
#
# 사용자가 특정 상품을 결제하기 위해선, 해당 상품의 설명을 적은 페이지를 방문해야 하며, 상품 설명 페이지를 방문하기 위해서는 해당 상품이 리스트되어있는 페이지를 방문해야 합니다. 이런 방식으로 웹사이트를 설명하는 것을 일명 퍼널이라고 합니다.
#
# <img src="https://cdn-images-1.medium.com/max/1600/0*voRGTKciwKuIb2HS.png" width=480 />
#
# <br />
# <center><small>사용자가 처음 유입(Acquistion) 되었을 때부터 구매(Revenue)를 할 때 까지의 모든 과정을 깔때기로 묘사한 것을 퍼널이라고 합니다.
# <br />
# (참고 자료: <a href="https://medium.com/the-school-of-mobile/app-marketing-metrics-for-pirates-growth-hacking-the-purchase-funnel-b4f1219c5945">App Marketing Metrics for Pirates: Growth Hacking the Purchase Funnel</a>)</small></center>
#
# 이 퍼널 정보를 이용해 사용자가 상품을 구매하는 전환(Conversion) 여부, 내지는 서비스를 이탈하는 이탈(Churn) 여부를 추적할 수 있으며, 이를 통해서 웹사이트나 모바일서비스를 개선하여 전환율을 높이고 이탈률을 낮출 수 있습니다. 크몽에서는 서비스에서 사용하는 퍼널에 대한 설명을 ```kmong-funnel.csv``` 파일에 저장해두고 있습니다.

# %%
# 판다스(pandas)의 read_csv를 활용하여 크몽의 퍼널(funnel) 관련 기록을 저장한 kmong-funnel.csv을 읽어옵니다.
# 이 데이터를 funnel라는 이름의 변수에 할당합니다.
funnel = pd.read_csv("data/kmong/kmong-funnel.csv")

# raw_funnel 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(funnel.shape)

# funnel 데이터 전체를 출력합니다.
funnel
# Out:
# (53, 6)
#      Lv2                           viewid                 viewid desc  Lv1  \
# 0   1100                             home                       홈 (탭)   11
# 1   1210                    category_list                 카테고리 목록 (탭)   12
# 2   1200                     category_gig                   카테고리-상품목록   12
# 3   1300                           search                          검색   13
# 4   1301                       search_gig                     검색-상품목록   13
# 5   1302                    search_seller                      검색-전문가   13
# 6   1400                       gig_detail                        상품상세   14
# 7   1401                gig_detail_option                   상품상세-상품선택   14
# 8   1420                          profile                      전문가프로필   14
# 9   1520                        login_sns                       간편로그인   15
# 10  1500                      login_email                간편로그인-이메일로그인   15
# 11  1510                     find_account    간편로그인-이메일로그인-아이디/비밀번호-찾기   15
# 12  1600                            inbox                   메시지목록 (탭)   16
# 13  1610                     inbox_detail                    메시지목록-상세   16
# 14  1611        inbox_detail_orderRequest               메시지목록-상세-결제요청   16
# 15  1700                    bookmarks_gig                메뉴목록-찜목록-서비스   17
# 16  1701              bookmarks_portfolio              메뉴목록-찜목록-포트폴리오   17
# 17  1801                  order_addOption                   상품상세-주문하기   18
# 18  1800                    order_payment              상품상세-주문하기-결제하기   18
# 19  1810                 kmongCash_charge            메뉴목록-크몽캐시-캐시충전하기   18
# 20  1900                         thankyou                        결제완료   19
# 21  2000                           signup                  개인/기업-회원가입   20
# 22  2001                       mobileAuth                       휴대폰인증   20
# 23  2020              seller_gig_register                  메뉴목록-서비스등록   20
# 24  2200                  account_setting                   메뉴목록-계정설정   22
# 25  2210     account_setting_notification              메뉴목록-계정설정-알림설정   22
# 26  2220       account_setting_AuthStatus              메뉴목록-계정설정-인증정보   22
# 27  2230              account_setting_pwd           메뉴목록-계정설정-비밀번호 변경   22
# 28  2240          account_setting_profile               메뉴목록-계정설정-프로필   22
# 29  2320                       seller_gig                  메뉴목록-나의서비스   23
# 30  2400                             menu                    메뉴목록 (탭)   24
# 31  2410                buyer_order_track             메뉴목록-구매관리-거래메시지   24
# 32  2411         buyer_order_track_cancel     메뉴목록-구매관리-거래메시지-취소/문제해결   24
# 33  2412  buyer_order_track_cancel_submit  메뉴목록-구매관리-거래메시지-취소/문제해결-제출   24
# 34  2420              buyer_order_history                   메뉴목록-구매관리   24
# 35  2421             buyer_coupon_history                   메뉴목록-쿠폰내역   24
# 36  2430           seller_selling_history                   메뉴목록-판매관리   24
# 37  2431           seller_mileage_history                메뉴목록-마일리지 내역   24
# 38  2432           seller_profits_history                   메뉴목록-수익관리   24
# 39  2450            buyer_payment_history                   메뉴목록-결제내역   24
# 40  2451                kmongCash_history                   메뉴목록-크몽캐시   24
# 41  2452  kmongCash_history_refundRequest              메뉴목록-크몽캐시-캐시환불   24
# 42  2510                   about_howToUse                 메뉴목록-크몽이용방법   25
# 43  2520                   termsOfService                   메인하단-이용약관   25
# 44  2521                    privacyPolicy               메인하단-개인정보처리방침   25
# 45  2530                         tutorial                        튜토리얼   25
# 46  2700                  referrerProgram                   메뉴목록-친구초대   27
# 47  2800                            event                         이벤트   28
# 48  3010                kmongNotification                   메뉴목록-크몽안내   30
# 49  3011         kmongNotification_detail                메뉴목록-크몽안내-상세   30
# 50  3000                     notification                       알림-알림   30
# 51  3001              notification_detail                    알림-알림-상세   30
# 52  9910                              NPS                         NPS   99
#
#             funnel name  funnel desc
# 0                  home            홈
# 1              category         카테고리
# 2              category         카테고리
# 3                search           검색
# 4                search           검색
# 5                search           검색
# 6                   gig           상품
# 7                   gig           상품
# 8                   gig           상품
# 9                 login          로그인
# 10                login          로그인
# 11                login          로그인
# 12                inbox          메시지
# 13                inbox          메시지
# 14                inbox          메시지
# 15            bookmarks          찜하기
# 16            bookmarks          찜하기
# 17                order           결제
# 18                order           결제
# 19                order           결제
# 20             thankyou         결제완료
# 21                  new         신규등록
# 22                  new         신규등록
# 23                  new         신규등록
# 24              account  계정관리 - 회원공통
# 25              account  계정관리 - 회원공통
# 26              account  계정관리 - 회원공통
# 27              account  계정관리 - 회원공통
# 28              account  계정관리 - 회원공통
# 29       account_seller   계정관리 - 판매자
# 30  transaction_history         거래관리
# 31  transaction_history         거래관리
# 32  transaction_history         거래관리
# 33  transaction_history         거래관리
# 34  transaction_history         거래관리
# 35  transaction_history         거래관리
# 36  transaction_history         거래관리
# 37  transaction_history         거래관리
# 38  transaction_history         거래관리
# 39  transaction_history         거래관리
# 40  transaction_history         거래관리
# 41  transaction_history         거래관리
# 42                 info      소개 및 안내
# 43                 info      소개 및 안내
# 44                 info      소개 및 안내
# 45                 info      소개 및 안내
# 46     referral_program     친구초대프로그램
# 47                event      이벤트프로모션
# 48         notification           알림
# 49         notification           알림
# 50         notification           알림
# 51         notification           알림
# 52               others           기타

# %% [markdown]
# **kmong-category.csv**
#
# 마지막으로 가져올 데이터셋은 크몽에서 판매하는 상품의 카테고리를 나타내는 ```kmong-category.csv``` 입니다. 크몽에서는 디자인, 번역, 컨텐츠 제작등 다양한 상품을 판매하고 있는데, 이 상품을 그룹화하고 정리할 수 있도록 만든 것이 카테고리입니다. 크몽에서는 이 값을 ```kmong-category.csv``` 라는 변수에 저장해두고 있습니다.

# %%
# 판다스(pandas)의 read_csv를 활용하여 크몽의 카테고리(category) 관련 기록을 저장한 kmong-category.csv을 읽어옵니다.
# 이 데이터를 category라는 이름의 변수에 할당합니다.
category = pd.read_csv("data/kmong/kmong-category.csv")

# category 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(category.shape)

# category 데이터 전체를 출력합니다.
category
# Out:
# (245, 9)
#      depth  categoryid categoryname  cat1_id  cat2_id  cat3_id      cat1  \
# 0        1           1          디자인        1      NaN      NaN       디자인
# 1        1           2          마케팅        2      NaN      NaN       마케팅
# 2        1           3        번역·통역        3      NaN      NaN     번역·통역
# 3        1           4         문서작성        4      NaN      NaN      문서작성
# 4        1           6     IT·프로그래밍        6      NaN      NaN  IT·프로그래밍
# ..     ...         ...          ...      ...      ...      ...       ...
# 240      3       72501           모델        7    725.0  72501.0    콘텐츠 제작
# 241      3       72502           MC        7    725.0  72502.0    콘텐츠 제작
# 242      3       72503           배우        7    725.0  72503.0    콘텐츠 제작
# 243      3       72504           공연        7    725.0  72504.0    콘텐츠 제작
# 244      3       72505           기타        7    725.0  72505.0    콘텐츠 제작
#
#       cat2 cat3
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# 4      NaN  NaN
# ..     ...  ...
# 240  엔터테이너   모델
# 241  엔터테이너   MC
# 242  엔터테이너   배우
# 243  엔터테이너   공연
# 244  엔터테이너   기타
#
# [245 rows x 9 columns]

# %% [markdown]
# ### 데이터 정리하기
#
# 먼저 가장 기본이 되는 ```kmong-conversion.csv```부터 정리하겠습니다. 이 데이터에는 사용자의 활동 기록을 자세하게 정리하였다는 장점이 있지만, 데이터가 다소 지저분하게 기록되어 있기 때문에, 이 데이터를 정리하지 않은 채 분석하는 것은 많은 시간을 낭비하게 될 것 같습니다. 그러므로 이번 기회에 데이터를 깔끔하게 정리하여 저장하도록 하겠습니다.

# %% [markdown]
# **1. ```canonicaldeviceuuid``` 컬럼명을 ```userid``` 컬럼명으로 바꿔주세요.**
#
# 먼저 ```canonicaldeviceuuid```라는 컬럼명을 바꾸고 싶습니다. 이 컬럼은 크몽을 이용하는 한 명의 사용자를 나타내는 중요한 정보임에는 틀림없지만, ```canonicaldeviceuuid```라는 표현 자체가 크몽, 내지는 다른 몇몇 분야에서만 쓰이는 표현이기 때문에 이 데이터를 처음 보는 사람의 입장에서는 직관적으로 이해하기 힘듭니다. 그렇기 때문에 이 컬럼의 이름을 많은 사람들이 직관적으로 이해할 수 있는 ```userid```로 바꾸고 싶습니다. 최종적으로 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe", style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>canonicaldeviceuuid</th>
#             <th>userid</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
conversion['userid'] = conversion['canonicaldeviceuuid']

# %%
conversion[['canonicaldeviceuuid','userid']]
# Out:
#                          canonicaldeviceuuid  \
# 0       F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1       8a871e50-0717-4aed-9bad-04ac3c3793be
# 2       A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3       168761CB-CB67-4592-867D-52780D651297
# 4       ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
# ...                                      ...
# 434239  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434240  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434241  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434242  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434243  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8
#
#                                       userid
# 0       F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1       8a871e50-0717-4aed-9bad-04ac3c3793be
# 2       A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3       168761CB-CB67-4592-867D-52780D651297
# 4       ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
# ...                                      ...
# 434239  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434240  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434241  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434242  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434243  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8
#
# [434244 rows x 2 columns]

# %% [markdown]
# **2. ```eventdatetime``` 컬럼은 datetime 형태로 바꾼 뒤 연/월/일/시/분/초 데이터를 추출해주세요.**
#
# ```eventdatetime```은 날짜와 시간 형식으로 표현되어 있습니다. (ex: 2018-01-01T00:00:00+09:00) 하지만 이 데이터를 처음 읽을 때, 판다스는 날짜 데이터로 인식하지 않고 문자열(object, 내지는 string)으로 인식합니다. 이 데이터를 날짜와 시간 형식을 나타내는 ```datetime``` 형태로 바꾼 뒤, 연/월/일/시/분/초 데이터를 추출해주세요. 최종적으로 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>eventdatetime</th>
#             <th>eventdatetime_year</th>
#             <th>eventdatetime_month</th>
#             <th>eventdatetime_day</th>
#             <th>eventdatetime_hour</th>
#             <th>eventdatetime_minute</th>
#             <th>eventdatetime_second</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#         </tr>
#     </tbody>
# </table>

# %%
# eventdatetime 열의 값이 str 타입인 경우에는, apply() 함수와 lambda 함수를 사용하여 datetime 형식으로 변환하는 것이 좋다.
# conversion['eventdatetime'] = conversion['eventdatetime'].apply(lambda x: pd.to_datetime(x, format="%Y-%m-%dT%H:%M:%S%z").strftime("%Y-%m-%d %H:%M:%S"))

# %%
# 문자열 형식의 날짜/시간 값을 datetime 형식으로 변환
conversion['eventdatetime'] = pd.to_datetime(conversion['eventdatetime'])

# %%
conversion[['eventdatetime']]
# Out:
#                    eventdatetime
# 0      2018-09-28 00:00:00+09:00
# 1      2018-09-28 00:00:00+09:00
# 2      2018-09-28 00:00:00+09:00
# 3      2018-09-28 00:00:01+09:00
# 4      2018-09-28 00:00:02+09:00
# ...                          ...
# 434239 2018-09-29 23:59:52+09:00
# 434240 2018-09-29 23:59:53+09:00
# 434241 2018-09-29 23:59:53+09:00
# 434242 2018-09-29 23:59:54+09:00
# 434243 2018-09-29 23:59:58+09:00
#
# [434244 rows x 1 columns]

# %%
# 연도, 월, 일, 시간, 분, 초 값을 추출하여 새로운 컬럼에 할당
conversion['eventdatetime_year'] = conversion['eventdatetime'].dt.year
conversion['eventdatetime_month'] = conversion['eventdatetime'].dt.month
conversion['eventdatetime_day'] = conversion['eventdatetime'].dt.day
conversion['eventdatetime_hour'] = conversion['eventdatetime'].dt.hour
conversion['eventdatetime_minute'] = conversion['eventdatetime'].dt.minute
conversion['eventdatetime_second'] = conversion['eventdatetime'].dt.second

# %%
conversion[['eventdatetime','eventdatetime_year','eventdatetime_month','eventdatetime_day','eventdatetime_hour','eventdatetime_minute','eventdatetime_second']]
# Out:
#                    eventdatetime  eventdatetime_year  eventdatetime_month  \
# 0      2018-09-28 00:00:00+09:00                2018                    9
# 1      2018-09-28 00:00:00+09:00                2018                    9
# 2      2018-09-28 00:00:00+09:00                2018                    9
# 3      2018-09-28 00:00:01+09:00                2018                    9
# 4      2018-09-28 00:00:02+09:00                2018                    9
# ...                          ...                 ...                  ...
# 434239 2018-09-29 23:59:52+09:00                2018                    9
# 434240 2018-09-29 23:59:53+09:00                2018                    9
# 434241 2018-09-29 23:59:53+09:00                2018                    9
# 434242 2018-09-29 23:59:54+09:00                2018                    9
# 434243 2018-09-29 23:59:58+09:00                2018                    9
#
#         eventdatetime_day  eventdatetime_hour  eventdatetime_minute  \
# 0                      28                   0                     0
# 1                      28                   0                     0
# 2                      28                   0                     0
# 3                      28                   0                     0
# 4                      28                   0                     0
# ...                   ...                 ...                   ...
# 434239                 29                  23                    59
# 434240                 29                  23                    59
# 434241                 29                  23                    59
# 434242                 29                  23                    59
# 434243                 29                  23                    59
#
#         eventdatetime_second
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          2
# ...                      ...
# 434239                    52
# 434240                    53
# 434241                    53
# 434242                    54
# 434243                    58
#
# [434244 rows x 7 columns]

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>osversion</th>
#             <th>ostype(clean)</th>
#             <th>osversion(clean)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>iOS11.4.1</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>Android7.0</td>
#             <td>Android</td>
#             <td>7.0</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>iOS12.0</td>
#             <td>iOS</td>
#             <td>12.0</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>iOS11.4.1</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>iOS11.4.1</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#         </tr>
#     </tbody>
# </table>

# %%
conversion[['ostype(clean)', 'osversion(clean)']] = conversion['osversion'].str.extract(r'([a-zA-Z]+)(\d[\d\.]*)', expand=False)

# %%
conversion[['osversion','ostype(clean)','osversion(clean)']]
# Out:
#            osversion ostype(clean) osversion(clean)
# 0          iOS11.4.1           iOS           11.4.1
# 1         Android7.0       Android              7.0
# 2            iOS12.0           iOS             12.0
# 3          iOS11.4.1           iOS           11.4.1
# 4          iOS11.4.1           iOS           11.4.1
# ...              ...           ...              ...
# 434239  Android8.0.0       Android            8.0.0
# 434240  Android8.0.0       Android            8.0.0
# 434241  Android8.0.0       Android            8.0.0
# 434242  Android8.0.0       Android            8.0.0
# 434243  Android8.0.0       Android            8.0.0
#
# [434244 rows x 3 columns]

# %%
conversion['ostype(clean)'].value_counts()
# Out:
# Android    270678
# iOS        163566
# Name: ostype(clean), dtype: int64

# %% [markdown]
# **4. ```devicemanufacturer``` 컬럼 정보를 정리해주세요.**
#
# ```devicemanufacturer``` 컬럼은 사용자가 현재 사용하고 있는 스마트폰 디바이스를 제조한 제조사의 정보가 들어가 있습니다. 가령 ```samsung```이라고 적혀있으면 이 스마트폰은 삼성전자가 제조했다고 볼 수 있고, ```LG Electronics```라고 적혀있으면 이 스마트폰은 LG전자가 제조했다고 볼 수 있습니다.
#
# 하지만 ```devicemanufacturer``` 컬럼에는 이 외에도 샤오미(Xiaomi), 폭스콘(Foxconn), 팬텍(PANTECH), 화웨이(HUAWEI)와 같은 마이너한 제조사 정보도 들어가 있습니다. 이 제조사들은 전체 사용자의 2%도 되지 않기 때문에, 이 데이터를 무시하거나 하나의 값(ex: Others)으로 통일해주면 데이터 분석가가 더 효율적으로 데이터를 분석할 수 있을 것 같습니다.
#
# 그러므로 ```devicemanufacturer``` 컬럼의 값을 정리해보겠습니다. 정리 방식은 다음과 같습니다.
#
#  * ```samsung```이라고 적혀있는 값은 앞 글자를 대문자로 바꿉니다. (=```Samsung```)
#  * ```LGE```와 ```LG Electronics```라는 값은 ```LG```로 통일합니다.
#  * ```Apple```, ```Samsung```, ```LG```를 제외한 나머지는 ```Other```로 묶습니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.
#
#   * Samsung - 230313
#   * Apple - 163566
#   * LG - 32649
#   * Others - 7716

# %%
# devicemanufacturer(clean) 컬럼 생성
conversion['devicemanufacturer(clean)'] = conversion['devicemanufacturer']

# samsung 첫 글자 대문자로 변환
conversion.loc[conversion['devicemanufacturer(clean)']=='samsung', 'devicemanufacturer(clean)'] = 'Samsung'

# LG 통일
conversion.loc[conversion['devicemanufacturer(clean)'].str.contains('LG'), 'devicemanufacturer(clean)'] = 'LG'

# 기타 제조사 Others로 묶기
# 'Samsung', 'Apple', 'LG'가 아닌 경우 (~)
conversion.loc[~conversion['devicemanufacturer(clean)'].str.contains("Samsung|Apple|LG"), 'devicemanufacturer(clean)'] = 'Others'

# %%
conversion['devicemanufacturer(clean)'].value_counts()
# Out:
# Samsung    230313
# Apple      163566
# LG          32649
# Others       7716
# Name: devicemanufacturer(clean), dtype: int64

# %% [markdown]
# **5. ```channel``` 컬럼 정보를 정리해주세요.**
#
# ```channel``` 컬럼을 사용자가 크몽 서비스에 유입된 경로를 기록한 정보입니다. 여기에는 웹(WEB), 구글(ex: google-play, google, google.adwords, etc), 네이버(ex: m_naver, m_naverpowercontents, pc_naver)등이 기록되어 있습니다. 이 정보도 마찬가지로 데이터를 분석하기 어렵게 산재되어 있기 때문에, 깔끔하게 정리해주고 싶습니다. 정리 방식은 다음과 같습니다.
#
#   * 컬럼값에 google이라고 들어간 값(ex: google-play, google.adwords, etc)은 전부 google로 통일합니다.
#   * 컬럼값에 daum이라고 들어간 값(ex: m_daum, etc)은 전부 daum으로 통일합니다.
#   * 컬럼값이 naver라고 들어간 값(ex: m_naver, pc_naver, m_naverpowercontents, etc)은 전부 naver로 통일합니다.
#   * 컬럼값에 apple이라고 들어간 값(ex: apple.searchads, etc)은 전부 apple로 통일합니다.
#   * 컬럼값에 WEB이라고 들어간 값(ex: WEB)은 전부 web으로 통일합니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.
#
# * unattributed - 270834
# * web - 27639
# * google - 27235
# * (not set) - 2444
# * naver - 1224
# * daum - 966
# * apple - 697
# * facebook - 126
#
# 단, 여기서 ```channel``` 값에 빈 값(NaN, Not a Number)가 있다는 걸 주의하세요. 이 값은 소수점(float)으로 간주하기 때문에, 문자열에서 쓰이는 기능을 지원하지 않습니다. 이 점 주의해서 작성해주세요. (참고로 어떤 값이 빈 값(NaN)인지 아닌지를 구분하는 기능으로 판다스의 [isnull](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.isnull.html)을 사용하면 됩니다. 페이지의 Examples란을 살펴보세요)

# %%
# channel(clean) 컬럼 생성
conversion['channel(clean)'] = conversion['channel']

# google이 들어간 값은 전부 google로 변경
conversion.loc[conversion['channel'].str.contains('google', case=False) & conversion['channel'].notna(), 'channel(clean)'] = 'google'

# daum이 들어간 값은 전부 daum으로 변경
conversion.loc[conversion['channel'].str.contains('daum', case=False) & conversion['channel'].notna(), 'channel(clean)'] = 'daum'

# naver가 들어간 값은 전부 naver로 변경
conversion.loc[conversion['channel'].str.contains('naver', case=False) & conversion['channel'].notna(), 'channel(clean)'] = 'naver'

# apple이 들어간 값은 전부 apple로 변경
conversion.loc[conversion['channel'].str.contains('apple', case=False) & conversion['channel'].notna(), 'channel(clean)'] = 'apple'

# WEB이라는 값은 전부 web으로 변경
conversion.loc[conversion['channel'].str.contains('web', case=False) & conversion['channel'].notna(), 'channel(clean)'] = 'web'

# %%
conversion['channel(clean)'].value_counts()
# Out:
# unattributed    270834
# web              27639
# google           27235
# (not set)         2444
# naver             1224
# daum               966
# apple              697
# facebook           126
# Name: channel(clean), dtype: int64

# %% [markdown]
# **6. ```inappeventcategory``` 컬럼에 들어가 있는 정보를 여러 개의 컬럼으로 나눠주세요.**
#
# ```inappeventcategory```에는 사용자 액티비티를 나타내는 정보가 들어있습니다. 크몽에 방문한 고객이 상품 페이지를 보고 있는지, 구매를 진행중인지 등에 대한 정보가 이 컬럼에 담겨있다고 보시면 됩니다. 또한 ```inappeventcategory```에 있는 정보는 차후 퍼널(funnel) 데이터를 합치는데 사용되기도 합니다. 이 데이터를 정리해주세요. 정리 방식은 다음과 같습니다.
#
#   * ```viewcategory``` - ```inappeventcategory```에서 언더바(_)를 기준으로 왼쪽 텍스트만 가져옵니다. 언더바가 없을 경우 점(.)의 왼쪽 텍스트만 가져옵니다.
#   * ```viewid``` - ```inappeventcategory```에서 점(.)의 왼쪽 텍스트만 가져옵니다.
#   * ```viewaction``` - ```inappeventcategory```에서 점(.)의 오른쪽 텍스트만 가져옵니다.
#
# (팁: 파이썬에서 문자열을 나누는 기능인 [split](https://wikidocs.net/13#split)을 활용하면 생각보다 쉽게 문제를 풀 수 있습니다)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>inappeventcategory</th>
#             <th>viewcategory</th>
#             <th>viewid</th>
#             <th>viewaction</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>home.view</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>gig_detail.view</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>inbox_detail.view</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>buyer_order_track.view</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#         </tr>
#     </tbody>
# </table>

# %%
# viewcategory 추출
conversion['viewcategory'] = conversion['inappeventcategory'].str.split('_').str[0]
conversion['viewcategory'].fillna(conversion['inappeventcategory'].str.split('.').str[0], inplace=True)

# viewid 추출
conversion['viewid'] = conversion['inappeventcategory'].str.split('.').str[0]

# viewaction 추출
conversion['viewaction'] = conversion['inappeventcategory'].str.split('.').str[1]

# %%
conversion[['inappeventcategory', 'viewcategory', 'viewid', 'viewaction']]
# Out:
#             inappeventcategory viewcategory             viewid viewaction
# 0                    home.view    home.view               home       view
# 1              gig_detail.view          gig         gig_detail       view
# 2            inbox_detail.view        inbox       inbox_detail       view
# 3                          NaN          NaN                NaN        NaN
# 4       buyer_order_track.view        buyer  buyer_order_track       view
# ...                        ...          ...                ...        ...
# 434239         gig_detail.view          gig         gig_detail       view
# 434240               home.view    home.view               home       view
# 434241       category_gig.view     category       category_gig       view
# 434242                     NaN          NaN                NaN        NaN
# 434243         search_gig.view       search         search_gig       view
#
# [434244 rows x 4 columns]

# %% [markdown]
# **7. 필요하지 않은 컬럼을 버려주세요.**
#
# 여기까지 했으면 대부분의 컬럼이 잘 정리된 것 같습니다. 이제 남은 것은 필요하지 않은 컬럼을 버리고, 기존 컬럼의 이름을 직관적으로 수정하는 일들만 남았습니다. 먼저 필요하지 않은 컬럼을 제거하겠습니다. 다음의 컬럼을 데이터에서 제거해주세요.
#
# * ```osversion``` - 이제 이 컬럼을 버린 뒤 ```osversion(clean)```을 사용할 것입니다.
# * ```devicemanufacturer``` - 이제 이 컬럼을 버린 뒤 ```devicemanufacturer(clean)```을 사용할 것입니다.
# * ```canonicaldeviceuuid``` - 이제 이 컬럼을 버린 뒤 ```userid```를 사용할 것입니다.
# * ```channel``` - 이제 이 컬럼을 버린 뒤 ```channel(clean)```을 사용할 것입니다.
# * ```event_rank``` - 이 컬럼은 애초부터 사용할 필요가 없기 때문에 제거해줘도 됩니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>eventcategory</th>
#             <th>isfirstactivity</th>
#             <th>apppackagename</th>
#             <th>appversion</th>
#             <th>devicetype</th>
#             <th>sourcetype</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>inappeventcategory</th>
#             <th>inappeventlabel</th>
#             <th>eventdatetime</th>
#             <th>rowuuid</th>
#             <th>isfirstgoalactivity</th>
#             <th>ostype(clean)</th>
#             <th>osversion(clean)</th>
#             <th>devicemanufacturer(clean)</th>
#             <th>userid</th>
#             <th>channel(clean)</th>
#             <th>eventdatetime_year</th>
#             <th>eventdatetime_month</th>
#             <th>eventdatetime_day</th>
#             <th>eventdatetime_hour</th>
#             <th>eventdatetime_minute</th>
#             <th>eventdatetime_second</th>
#             <th>viewid</th>
#             <th>viewaction</th>
#             <th>viewcategory</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.kmong</td>
#             <td>3.3.5</td>
#             <td>SM-N935S</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>False</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>Samsung</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>Apple</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>NaN</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>NaN</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>viral</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>web</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 필요하지 않은 컬럼 제거
conversion = conversion.drop(columns=['osversion', 'devicemanufacturer', 'canonicaldeviceuuid', 'channel', 'event_rank'])

# %%
conversion.head()
# Out:
#   eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0          goal           False    com.kmong.iOS      4.0.4     iPhone
# 1          goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2          goal           False    com.kmong.iOS      4.0.4     iPhone
# 3    foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4          goal           False    com.kmong.iOS      4.0.4     iPhone
#
#      sourcetype params_campaign params_medium params_term  \
# 0  unattributed             NaN           NaN         NaN
# 1  unattributed             NaN           NaN         NaN
# 2  unattributed             NaN           NaN         NaN
# 3           NaN             NaN           NaN         NaN
# 4         viral             NaN           NaN         NaN
#
#        inappeventcategory  inappeventlabel             eventdatetime  \
# 0               home.view              NaN 2018-09-28 00:00:00+09:00
# 1         gig_detail.view          41201.0 2018-09-28 00:00:00+09:00
# 2       inbox_detail.view              NaN 2018-09-28 00:00:00+09:00
# 3                     NaN              NaN 2018-09-28 00:00:01+09:00
# 4  buyer_order_track.view              NaN 2018-09-28 00:00:02+09:00
#
#                                 rowuuid isfirstgoalactivity  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817               False
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38               False
# 2  14eb3197-db83-493a-b7be-83582960c40b               False
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                 NaN
# 4  236e9946-7801-4898-b609-06c8ab1139dc               False
#
#                                  userid  eventdatetime_year  \
# 0  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957                2018
# 1  8a871e50-0717-4aed-9bad-04ac3c3793be                2018
# 2  A9E5778A-8F3D-4597-9718-74BF953A9F64                2018
# 3  168761CB-CB67-4592-867D-52780D651297                2018
# 4  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D                2018
#
#    eventdatetime_month  eventdatetime_day  eventdatetime_hour  \
# 0                    9                 28                   0
# 1                    9                 28                   0
# 2                    9                 28                   0
# 3                    9                 28                   0
# 4                    9                 28                   0
#
#    eventdatetime_minute  eventdatetime_second ostype(clean) osversion(clean)  \
# 0                     0                     0           iOS           11.4.1
# 1                     0                     0       Android              7.0
# 2                     0                     0           iOS             12.0
# 3                     0                     1           iOS           11.4.1
# 4                     0                     2           iOS           11.4.1
#
#   devicemanufacturer(clean) channel(clean) viewcategory             viewid  \
# 0                     Apple   unattributed    home.view               home
# 1                   Samsung   unattributed          gig         gig_detail
# 2                     Apple   unattributed        inbox       inbox_detail
# 3                     Apple            NaN          NaN                NaN
# 4                     Apple            web        buyer  buyer_order_track
#
#   viewaction
# 0       view
# 1       view
# 2       view
# 3        NaN
# 4       view

# %% [markdown]
# **8. 이름을 통일성있게 변경해주세요.**
#
# 데이터를 분석할 때 컬럼명의 형식을 동일하게 유지하는 것이 중요합니다. 가령 회사 내부 데이터 팀에서 컬럼에서 두 개의 단어를 하이픈(-)으로 연결하기로 합의했다면 모든 컬럼을 하이픈으로 연결해야 하고, 언더바(_)로 연결하기로 합의했다면 모든 컬럼을 언더바로 연결해야 합니다.
#
# 하지만 아쉽게도, 현재 데이터의 컬럼명에는 이런 통일성이 잘 갖춰져 있는 것 같습니다. (ex: ```eventcategory``` vs ```params_term```) 그러므로 데이터의 컬럼명을 작성하는 형식을 하나로 통일하도록 하겠습니다. 이번 데이터에서 컬럼명을 짓는 방식은 다음과 같습니다.
#
#   * 단어와 단어 사이는 언제나 언더바(_)로 구분합니다. 가령 하이픈(-)으로 구분하거나, 띄어쓰기를 사용하면 안 됩니다. (ex: event_category는 허용하지만, eventcategory나 event-category, 또는 event category는 허용하지 않습니다)
#   * 컬럼명에 (clean)이라고 들어간 표현은 이제는 지워줘도 될 것 같습니다. (ex channel(clean) -> channel)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>event_category</th>
#             <th>is_first_activity</th>
#             <th>app_package_name</th>
#             <th>app_version</th>
#             <th>device_type</th>
#             <th>source_type</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>event_datetime</th>
#             <th>row_uuid</th>
#             <th>is_first_goal_activity</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>device_manufacturer</th>
#             <th>user_id</th>
#             <th>channel</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>view_category</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.kmong</td>
#             <td>3.3.5</td>
#             <td>SM-N935S</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>False</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>Samsung</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>Apple</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>NaN</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>NaN</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>viral</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>web</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer</td>
#         </tr>
#     </tbody>
# </table>

# %%
conversion = conversion.rename(columns={'eventcategory': 'event_category',
                                        'isfirstactivity': 'is_first_activity',
                                        'apppackagename': 'app_package_name',
                                        'appversion': 'app_version',
                                        'devicetype': 'device_type',
                                        'devicemanufacturer(clean)': 'device_manufacturer',
                                        'userid': 'user_id',
                                        'sourcetype': 'source_type',
                                        'channel(clean)': 'channel',
                                        'inappeventcategory': 'in_app_event_category',
                                        'inappeventlabel': 'in_app_event_label',
                                        'eventdatetime': 'event_datetime',
                                        'rowuuid': 'row_uuid',
                                        'isfirstgoalactivity': 'is_first_goal_activity',
                                        'eventdatetime_year':'event_datetime_year',
                                        'eventdatetime_month':'event_datetime_month',
                                        'eventdatetime_day' :'event_datetime_day',
                                        'eventdatetime_hour':'event_datetime_hour',
                                        'eventdatetime_minute':'event_datetime_minute',
                                        'eventdatetime_second':'event_datetime_second',
                                        'ostype(clean)': 'os_type',
                                        'osversion(clean)' :'os_version',
                                        'viewcategory': 'view_category',
                                        'viewid': 'view_id',
                                        'viewaction': 'view_action'
})

# %%
conversion.head()
# Out:
#   event_category is_first_activity app_package_name app_version device_type  \
# 0           goal             False    com.kmong.iOS       4.0.4      iPhone
# 1           goal             False  com.kmong.kmong       3.3.5    SM-N935S
# 2           goal             False    com.kmong.iOS       4.0.4      iPhone
# 3     foreground               NaN    com.kmong.iOS       4.0.4      iPhone
# 4           goal             False    com.kmong.iOS       4.0.4      iPhone
#
#     source_type params_campaign params_medium params_term  \
# 0  unattributed             NaN           NaN         NaN
# 1  unattributed             NaN           NaN         NaN
# 2  unattributed             NaN           NaN         NaN
# 3           NaN             NaN           NaN         NaN
# 4         viral             NaN           NaN         NaN
#
#     in_app_event_category  in_app_event_label            event_datetime  \
# 0               home.view                 NaN 2018-09-28 00:00:00+09:00
# 1         gig_detail.view             41201.0 2018-09-28 00:00:00+09:00
# 2       inbox_detail.view                 NaN 2018-09-28 00:00:00+09:00
# 3                     NaN                 NaN 2018-09-28 00:00:01+09:00
# 4  buyer_order_track.view                 NaN 2018-09-28 00:00:02+09:00
#
#                                row_uuid is_first_goal_activity  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817                  False
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38                  False
# 2  14eb3197-db83-493a-b7be-83582960c40b                  False
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                    NaN
# 4  236e9946-7801-4898-b609-06c8ab1139dc                  False
#
#                                 user_id  event_datetime_year  \
# 0  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957                 2018
# 1  8a871e50-0717-4aed-9bad-04ac3c3793be                 2018
# 2  A9E5778A-8F3D-4597-9718-74BF953A9F64                 2018
# 3  168761CB-CB67-4592-867D-52780D651297                 2018
# 4  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D                 2018
#
#    event_datetime_month  event_datetime_day  event_datetime_hour  \
# 0                     9                  28                    0
# 1                     9                  28                    0
# 2                     9                  28                    0
# 3                     9                  28                    0
# 4                     9                  28                    0
#
#    event_datetime_minute  event_datetime_second  os_type os_version  \
# 0                      0                      0      iOS     11.4.1
# 1                      0                      0  Android        7.0
# 2                      0                      0      iOS       12.0
# 3                      0                      1      iOS     11.4.1
# 4                      0                      2      iOS     11.4.1
#
#   device_manufacturer       channel view_category            view_id  \
# 0               Apple  unattributed     home.view               home
# 1             Samsung  unattributed           gig         gig_detail
# 2               Apple  unattributed         inbox       inbox_detail
# 3               Apple           NaN           NaN                NaN
# 4               Apple           web         buyer  buyer_order_track
#
#   view_action
# 0        view
# 1        view
# 2        view
# 3         NaN
# 4        view

# %% [markdown]
# **9. 컬럼을 정렬해주세요.**
#
# 마지막은 컬럼을 용도에 맞게 잘 정렬해주면 될 것 같습니다. 정렬할 때는 보통 1) 중요한 컬럼을 좌측으로, 상대적으로 중요하지 않은 컬럼을 우측으로 옮겨주고, 2) 비슷한 역할을 하는 컬럼이나 서로간에 연관되어있는 컬럼은 같은 위치로 묶어줍니다. 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>source_type</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>viral</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 컬럼 순서 변경
conversion = conversion[['row_uuid', 'app_package_name', 'user_id', 'event_datetime', 'event_datetime_year', 'event_datetime_month', 'event_datetime_day', 'event_datetime_hour', 'event_datetime_minute', 'event_datetime_second', 'device_manufacturer', 'device_type', 'os_type', 'os_version', 'app_version', 'event_category', 'view_category', 'view_id', 'view_action', 'in_app_event_category', 'in_app_event_label', 'source_type', 'channel', 'params_campaign', 'params_medium', 'params_term', 'is_first_activity', 'is_first_goal_activity']]

# %%
conversion.head()
# Out:
#                                row_uuid app_package_name  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817    com.kmong.iOS
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# 2  14eb3197-db83-493a-b7be-83582960c40b    com.kmong.iOS
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b    com.kmong.iOS
# 4  236e9946-7801-4898-b609-06c8ab1139dc    com.kmong.iOS
#
#                                 user_id            event_datetime  \
# 0  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957 2018-09-28 00:00:00+09:00
# 1  8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:00+09:00
# 2  A9E5778A-8F3D-4597-9718-74BF953A9F64 2018-09-28 00:00:00+09:00
# 3  168761CB-CB67-4592-867D-52780D651297 2018-09-28 00:00:01+09:00
# 4  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D 2018-09-28 00:00:02+09:00
#
#    event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                 2018                     9                  28
# 1                 2018                     9                  28
# 2                 2018                     9                  28
# 3                 2018                     9                  28
# 4                 2018                     9                  28
#
#    event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                    0                      0                      0
# 1                    0                      0                      0
# 2                    0                      0                      0
# 3                    0                      0                      1
# 4                    0                      0                      2
#
#   device_manufacturer device_type  os_type os_version app_version  \
# 0               Apple      iPhone      iOS     11.4.1       4.0.4
# 1             Samsung    SM-N935S  Android        7.0       3.3.5
# 2               Apple      iPhone      iOS       12.0       4.0.4
# 3               Apple      iPhone      iOS     11.4.1       4.0.4
# 4               Apple      iPhone      iOS     11.4.1       4.0.4
#
#   event_category view_category            view_id view_action  \
# 0           goal     home.view               home        view
# 1           goal           gig         gig_detail        view
# 2           goal         inbox       inbox_detail        view
# 3     foreground           NaN                NaN         NaN
# 4           goal         buyer  buyer_order_track        view
#
#     in_app_event_category  in_app_event_label   source_type       channel  \
# 0               home.view                 NaN  unattributed  unattributed
# 1         gig_detail.view             41201.0  unattributed  unattributed
# 2       inbox_detail.view                 NaN  unattributed  unattributed
# 3                     NaN                 NaN           NaN           NaN
# 4  buyer_order_track.view                 NaN         viral           web
#
#   params_campaign params_medium params_term is_first_activity  \
# 0             NaN           NaN         NaN             False
# 1             NaN           NaN         NaN             False
# 2             NaN           NaN         NaN             False
# 3             NaN           NaN         NaN               NaN
# 4             NaN           NaN         NaN             False
#
#   is_first_goal_activity
# 0                  False
# 1                  False
# 2                  False
# 3                    NaN
# 4                  False

# %% [markdown]
# **10. funnel 데이터를 정리해주세요.**
#
# 다음으로는 퍼널(funnel) 데이터를 정리하겠습니다. 퍼널 데이터에는 크몽 서비스에서 사용하는 퍼널에 대한 부연 설명을 담고 있습니다. 기쁘게도 이 데이터는 잘 정리되어 있기 때문에, 별도로 처리해줘야 하는 건 많지 않습니다. 다음의 설명을 참고하여 데이터를 정리해주세요.
#
#   1. 먼저 컬럼을 ```Lv1```, ```Lv2```, ```viewid```, ```viewid desc```, ```funnel name```, ```funnel desc``` 순으로 정렬해주세요.
#   2. 그 다음 모든 컬럼을 소문자로 통일하고(ex: Lv1 -> lv1), 띄어쓰기를 언더바(_)로 바꿔주세요. (ex: funnel name -> funnel_name)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>lv1</th>
#             <th>lv2</th>
#             <th>view_id</th>
#             <th>view_desc</th>
#             <th>funnel_name</th>
#             <th>funnel_desc</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>11</td>
#             <td>1100</td>
#             <td>home</td>
#             <td>홈 (탭)</td>
#             <td>home</td>
#             <td>홈</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>12</td>
#             <td>1210</td>
#             <td>category_list</td>
#             <td>카테고리 목록 (탭)</td>
#             <td>category</td>
#             <td>카테고리</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>12</td>
#             <td>1200</td>
#             <td>category_gig</td>
#             <td>카테고리-상품목록</td>
#             <td>category</td>
#             <td>카테고리</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>13</td>
#             <td>1300</td>
#             <td>search</td>
#             <td>검색</td>
#             <td>search</td>
#             <td>검색</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>13</td>
#             <td>1301</td>
#             <td>search_gig</td>
#             <td>검색-상품목록</td>
#             <td>search</td>
#             <td>검색</td>
#         </tr>
#     </tbody>
# </table>

# %%
funnel = funnel.rename(columns={'Lv2':'lv2', 'viewid':'view_id', 'Lv1':'lv1'})
funnel.columns = funnel.columns.str.replace(' ', '_').str.lower()

# %%
funnel=funnel.rename(columns={'viewid_desc':'view_desc'})

# %%
funnel=funnel[['lv1', 'lv2', 'view_id', 'view_desc', 'funnel_name', 'funnel_desc']]

# %%
funnel.head()
# Out:
#    lv1   lv2        view_id    view_desc funnel_name funnel_desc
# 0   11  1100           home        홈 (탭)        home           홈
# 1   12  1210  category_list  카테고리 목록 (탭)    category        카테고리
# 2   12  1200   category_gig    카테고리-상품목록    category        카테고리
# 3   13  1300         search           검색      search          검색
# 4   13  1301     search_gig      검색-상품목록      search          검색

# %% [markdown]
# **11. category 데이터를 정리해주세요.**
#
# 퍼널(funnel) 데이터와 마찬가지로, category 데이터도 정리하겠습니다. category 데이터는크몽에서 판매하는 상품의 카테고리를 나타내는 정보인데, 퍼널 데이터와 마찬가지로 이 데이터로 잘 정리되어 있기 때문에 크게 건드려줘야 하는 부분은 없고, 컬럼명만 바꿔주면 될 것 같습니다. 다음의 기준을 참고하여 컬럼명을 시정해주세요.
#
# * 단어 사이에는 언더바(```_```)를 붙입니다. (ex: categoryid -> category_id)
# * 축약어는 전체 단어로 풀어서 작성합니다. (ex: cat1 -> category1)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>depth</th>
#             <th>category_id</th>
#             <th>category_name</th>
#             <th>category1_id</th>
#             <th>category2_id</th>
#             <th>category3_id</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>1</td>
#             <td>1</td>
#             <td>디자인</td>
#             <td>1</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>디자인</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>1</td>
#             <td>2</td>
#             <td>마케팅</td>
#             <td>2</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>마케팅</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>1</td>
#             <td>3</td>
#             <td>번역·통역</td>
#             <td>3</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>번역·통역</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>1</td>
#             <td>4</td>
#             <td>문서작성</td>
#             <td>4</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>문서작성</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>1</td>
#             <td>6</td>
#             <td>IT·프로그래밍</td>
#             <td>6</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>IT·프로그래밍</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#     </tbody>
# </table>

# %%
category = category.rename(columns={'categoryid':'category_id', 'categoryname':'category_name',
                                    'cat1_id':'category1_id', 'cat2_id':'category2_id', 'cat3_id':'category3_id',
                                    'cat1':'category1', 'cat2':'category2', 'cat3':'category3'})

# %%
category.head()
# Out:
#    depth  category_id category_name  category1_id  category2_id  category3_id  \
# 0      1            1           디자인             1           NaN           NaN
# 1      1            2           마케팅             2           NaN           NaN
# 2      1            3         번역·통역             3           NaN           NaN
# 3      1            4          문서작성             4           NaN           NaN
# 4      1            6      IT·프로그래밍             6           NaN           NaN
#
#   category1 category2 category3
# 0       디자인       NaN       NaN
# 1       마케팅       NaN       NaN
# 2     번역·통역       NaN       NaN
# 3      문서작성       NaN       NaN
# 4  IT·프로그래밍       NaN       NaN

# %% [markdown]
# ### 세 개의 데이터를 하나로 합치기
#
# 이번에는 수정한 ```log```, ```funnel```, ```category``` 데이터를 하나로 합쳐보겠습니다. 이 부분은 다소 난이도가 높기 때문에, 적극적으로 구글을 검색하거나 다른 자료를 참고하는 것을 추천드립니다. 특히나 [Merge, join, and concatenate](https://pandas.pydata.org/pandas-docs/stable/merging.html) 자료를 한 번 살펴보신 뒤 아래 문제를 시도한다면 더 쉽게 문제를 풀 수 있을 것입니다.

# %% [markdown]
# **12. ```log``` 데이터의 view_id 컬럼과 ```funnel``` 데이터의 view_id 컬럼을 활용하여 두 개의 데이터를 합쳐주세요**
#
# 앞서 설명드린대로 ```log``` 데이터에 사용자의 액티비티가 모두 모여져있고, 여기에서 가장 중요한 정보 중 하나인 퍼널(funnel)에 대한 부연 설명이 ```funnel``` 데이터에 모여 있습니다. 그러므로 이 두개를 합친다면, 차후에 ```log```데이터에서 퍼널 분석을 할 때 다른 데이터 분석가들이 더 직관적으로 데이터를 이해할 수 있을 것 같습니다.
#
# 그러므로 두 개의 데이터를 합쳐주세요. 두 개의 데이터와 연관이 있는 컬럼은 ```view_id```라는 이름의 컬럼이며, 데이터를 합칠 때는 [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html)라는 함수를 잘 사용하면 생각보다 쉽게 데이터를 합칠 수 있습니다. 또한 합칠 때 ```log``` 데이터는 누락되지 않고 전부 살아있어야 하며, ```funnel```데이터는 ```log```데이터에 일치하는 것만 살리고 나머지는 지워져도 상관 없습니다. (이를 전문 용어로 **left merge**라고 합니다)
#
# 최종적으로는 다음의 결과가 나와야 합니다. (```log``` 데이터와 동일해보이지만 자세히 보시면 오른쪽에 ```funnel``` 데이터가 추가되어 있습니다)

# %% [markdown]
# <table border="1" class="dataframe">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>source_type</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#             <th>lv1</th>
#             <th>lv2</th>
#             <th>view_desc</th>
#             <th>funnel_name</th>
#             <th>funnel_desc</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>11.0</td>
#             <td>1100.0</td>
#             <td>홈 (탭)</td>
#             <td>home</td>
#             <td>홈</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>14.0</td>
#             <td>1400.0</td>
#             <td>상품상세</td>
#             <td>gig</td>
#             <td>상품</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>16.0</td>
#             <td>1610.0</td>
#             <td>메시지목록-상세</td>
#             <td>inbox</td>
#             <td>메시지</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>viral</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>24.0</td>
#             <td>2410.0</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>transaction_history</td>
#             <td>거래관리</td>
#         </tr>
#     </tbody>
# </table>

# %%
left_merge=pd.merge(conversion, funnel, on='view_id', how='left')

# %%
print(left_merge.shape)
# Out:
# (434244, 33)

# %% [markdown]
# **13. 12번 데이터의 ```in_app_event_label``` 컬럼과 ```category``` 데이터의 ```category_id``` 컬럼을 활용하여 두 개의 데이터를 합쳐주세요.**
#
# 퍼널(funnel)과 마찬가지로 ```category``` 데이터도 하나로 합쳐보겠습니다.
#
# 이것도 12번 데이터와 마찬가지로 판다스(Pandas)의 [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html), 그것도 **left merge**를 사용하면 됩니다. 다만 두 데이터가 ```view_id```라는 공통의 컬럼을 보유하고 있던 이전과는 다르게, 이번에는 12번 데이터에는 ```in_app_event_label``` 컬럼이, ```category``` 데이터에는 ```category_id``` 컬럼이 서로 연관이 있습니다. 이 컬럼을 사용하여 두 개를 합쳐주세요.
#
# 최종적으로는 다음의 결과가 나와야 합니다. (자세히 보시면 오른쪽에 ```category_id``` 데이터가 추가되어 있습니다)

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>source_type</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#             <th>lv1</th>
#             <th>lv2</th>
#             <th>view_desc</th>
#             <th>funnel_name</th>
#             <th>funnel_desc</th>
#             <th>depth</th>
#             <th>category_id</th>
#             <th>category_name</th>
#             <th>category1_id</th>
#             <th>category2_id</th>
#             <th>category3_id</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>11.0</td>
#             <td>1100.0</td>
#             <td>홈 (탭)</td>
#             <td>home</td>
#             <td>홈</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>14.0</td>
#             <td>1400.0</td>
#             <td>상품상세</td>
#             <td>gig</td>
#             <td>상품</td>
#             <td>3.0</td>
#             <td>41201.0</td>
#             <td>자기소개서</td>
#             <td>4.0</td>
#             <td>412.0</td>
#             <td>41201.0</td>
#             <td>문서작성</td>
#             <td>자기소개서·이력서</td>
#             <td>자기소개서</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>16.0</td>
#             <td>1610.0</td>
#             <td>메시지목록-상세</td>
#             <td>inbox</td>
#             <td>메시지</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>viral</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>24.0</td>
#             <td>2410.0</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>transaction_history</td>
#             <td>거래관리</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#     </tbody>
# </table>

# %%
result=pd.merge(left_merge,category, how='left', left_on='in_app_event_label', right_on='category_id')

# %%
result.head()
# Out:
#                                row_uuid app_package_name  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817    com.kmong.iOS
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# 2  14eb3197-db83-493a-b7be-83582960c40b    com.kmong.iOS
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b    com.kmong.iOS
# 4  236e9946-7801-4898-b609-06c8ab1139dc    com.kmong.iOS
#
#                                 user_id            event_datetime  \
# 0  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957 2018-09-28 00:00:00+09:00
# 1  8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:00+09:00
# 2  A9E5778A-8F3D-4597-9718-74BF953A9F64 2018-09-28 00:00:00+09:00
# 3  168761CB-CB67-4592-867D-52780D651297 2018-09-28 00:00:01+09:00
# 4  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D 2018-09-28 00:00:02+09:00
#
#    event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                 2018                     9                  28
# 1                 2018                     9                  28
# 2                 2018                     9                  28
# 3                 2018                     9                  28
# 4                 2018                     9                  28
#
#    event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                    0                      0                      0
# 1                    0                      0                      0
# 2                    0                      0                      0
# 3                    0                      0                      1
# 4                    0                      0                      2
#
#   device_manufacturer device_type  os_type os_version app_version  \
# 0               Apple      iPhone      iOS     11.4.1       4.0.4
# 1             Samsung    SM-N935S  Android        7.0       3.3.5
# 2               Apple      iPhone      iOS       12.0       4.0.4
# 3               Apple      iPhone      iOS     11.4.1       4.0.4
# 4               Apple      iPhone      iOS     11.4.1       4.0.4
#
#   event_category view_category            view_id view_action  \
# 0           goal     home.view               home        view
# 1           goal           gig         gig_detail        view
# 2           goal         inbox       inbox_detail        view
# 3     foreground           NaN                NaN         NaN
# 4           goal         buyer  buyer_order_track        view
#
#     in_app_event_category  in_app_event_label   source_type       channel  \
# 0               home.view                 NaN  unattributed  unattributed
# 1         gig_detail.view             41201.0  unattributed  unattributed
# 2       inbox_detail.view                 NaN  unattributed  unattributed
# 3                     NaN                 NaN           NaN           NaN
# 4  buyer_order_track.view                 NaN         viral           web
#
#   params_campaign params_medium params_term is_first_activity  \
# 0             NaN           NaN         NaN             False
# 1             NaN           NaN         NaN             False
# 2             NaN           NaN         NaN             False
# 3             NaN           NaN         NaN               NaN
# 4             NaN           NaN         NaN             False
#
#   is_first_goal_activity   lv1     lv2        view_desc          funnel_name  \
# 0                  False  11.0  1100.0            홈 (탭)                 home
# 1                  False  14.0  1400.0             상품상세                  gig
# 2                  False  16.0  1610.0         메시지목록-상세                inbox
# 3                    NaN   NaN     NaN              NaN                  NaN
# 4                  False  24.0  2410.0  메뉴목록-구매관리-거래메시지  transaction_history
#
#   funnel_desc  depth  category_id category_name  category1_id  category2_id  \
# 0           홈    NaN          NaN           NaN           NaN           NaN
# 1          상품    3.0      41201.0         자기소개서           4.0         412.0
# 2         메시지    NaN          NaN           NaN           NaN           NaN
# 3         NaN    NaN          NaN           NaN           NaN           NaN
# 4        거래관리    NaN          NaN           NaN           NaN           NaN
#
#    category3_id category1  category2 category3
# 0           NaN       NaN        NaN       NaN
# 1       41201.0      문서작성  자기소개서·이력서     자기소개서
# 2           NaN       NaN        NaN       NaN
# 3           NaN       NaN        NaN       NaN
# 4           NaN       NaN        NaN       NaN

# %% [markdown]
# **14. 합친 데이터에서 필요하지 않은 컬럼은 버려주고 정렬해주세요.**
#
# 이제 데이터를 다 정리하고 합쳤으면, 나머지는 분석에 필요하지 않은 데이터를 버려주는 일만 남았습니다. 실제 회사에서는 데이터를 처음 읽을 때 굉장히 많은 컬럼을 읽어오게 되는데, 이를 전부 읽어와 분석하지 않고 1) 필요하지 않은 컬럼은 사전에 버려주고, 2) 남은 데이터에서 분석할 때 필요한 데이터만 그때그때 가져오는 습관을 드리는 것이 좋습니다.
#
# 그러므로 다음의 컬럼은 사용하지 않을 예정이니 데이터에서 삭제하도록 하겠습니다.
#
#   * ```in_app_event_category```
#   * ```in_app_event_label```
#   * ```source_type```
#   * ```Lv1```, ```Lv2```
#   * ```funnel_name```, ```depth```
#   * ```category_id```, ```category1_id```, ```category2_id```, ```category3_id```
#
# 또한 여기에서 다음의 순서대로 데이터를 정렬해주세요.
#
#   * ```row_uuid```
#   * ```app_package_name```
#   * ```user_id```
#   * ```event_datetime```
#   * ```event_datetime_year```
#   * ```event_datetime_month```
#   * ```event_datetime_day```
#   * ```event_datetime_hour```
#   * ```event_datetime_minute```
#   * ```event_datetime_second```
#   * ```device_manufacturer```
#   * ```device_type```
#   * ```os_type```
#   * ```os_version```
#   * ```app_version```
#   * ```event_category```
#   * ```view_category```
#   * ```view_id```
#   * ```view_action```
#   * ```funnel_desc```
#   * ```view_desc```
#   * ```category_name```
#   * ```category1```
#   * ```category2```
#   * ```category3```
#   * ```channel```
#   * ```params_campaign```
#   * ```params_medium```
#   * ```params_term```
#   * ```is_first_activity```
#   * ```is_first_goal_activity```
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>funnel_desc</th>
#             <th>view_desc</th>
#             <th>category_name</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>홈</td>
#             <td>홈 (탭)</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>상품</td>
#             <td>상품상세</td>
#             <td>자기소개서</td>
#             <td>문서작성</td>
#             <td>자기소개서·이력서</td>
#             <td>자기소개서</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>메시지</td>
#             <td>메시지목록-상세</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>거래관리</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 필요하지 않은 컬럼 제거
result = result.drop(columns=['in_app_event_category', 'in_app_event_label', 'source_type', 'lv1', 'lv2', 'funnel_name', 'depth', 'category_id', 'category1_id', 'category2_id', 'category3_id'])

# %%
result=result[['row_uuid','app_package_name','user_id','event_datetime','event_datetime_year',
                 'event_datetime_month','event_datetime_day','event_datetime_hour','event_datetime_minute','event_datetime_second',
                 'device_manufacturer','device_type','os_type','os_version','app_version','event_category','view_category',
                 'view_id','view_action','funnel_desc','view_desc','category_name','category1','category2','category3',
                 'channel','params_campaign','params_medium','params_term','is_first_activity','is_first_goal_activity']]

# %%
result.head()
# Out:
#                                row_uuid app_package_name  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817    com.kmong.iOS
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# 2  14eb3197-db83-493a-b7be-83582960c40b    com.kmong.iOS
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b    com.kmong.iOS
# 4  236e9946-7801-4898-b609-06c8ab1139dc    com.kmong.iOS
#
#                                 user_id            event_datetime  \
# 0  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957 2018-09-28 00:00:00+09:00
# 1  8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:00+09:00
# 2  A9E5778A-8F3D-4597-9718-74BF953A9F64 2018-09-28 00:00:00+09:00
# 3  168761CB-CB67-4592-867D-52780D651297 2018-09-28 00:00:01+09:00
# 4  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D 2018-09-28 00:00:02+09:00
#
#    event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                 2018                     9                  28
# 1                 2018                     9                  28
# 2                 2018                     9                  28
# 3                 2018                     9                  28
# 4                 2018                     9                  28
#
#    event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                    0                      0                      0
# 1                    0                      0                      0
# 2                    0                      0                      0
# 3                    0                      0                      1
# 4                    0                      0                      2
#
#   device_manufacturer device_type  os_type os_version app_version  \
# 0               Apple      iPhone      iOS     11.4.1       4.0.4
# 1             Samsung    SM-N935S  Android        7.0       3.3.5
# 2               Apple      iPhone      iOS       12.0       4.0.4
# 3               Apple      iPhone      iOS     11.4.1       4.0.4
# 4               Apple      iPhone      iOS     11.4.1       4.0.4
#
#   event_category view_category            view_id view_action funnel_desc  \
# 0           goal     home.view               home        view           홈
# 1           goal           gig         gig_detail        view          상품
# 2           goal         inbox       inbox_detail        view         메시지
# 3     foreground           NaN                NaN         NaN         NaN
# 4           goal         buyer  buyer_order_track        view        거래관리
#
#          view_desc category_name category1  category2 category3       channel  \
# 0            홈 (탭)           NaN       NaN        NaN       NaN  unattributed
# 1             상품상세         자기소개서      문서작성  자기소개서·이력서     자기소개서  unattributed
# 2         메시지목록-상세           NaN       NaN        NaN       NaN  unattributed
# 3              NaN           NaN       NaN        NaN       NaN           NaN
# 4  메뉴목록-구매관리-거래메시지           NaN       NaN        NaN       NaN           web
#
#   params_campaign params_medium params_term is_first_activity  \
# 0             NaN           NaN         NaN             False
# 1             NaN           NaN         NaN             False
# 2             NaN           NaN         NaN             False
# 3             NaN           NaN         NaN               NaN
# 4             NaN           NaN         NaN             False
#
#   is_first_goal_activity
# 0                  False
# 1                  False
# 2                  False
# 3                    NaN
# 4                  False

# %% [markdown]
# **15. ```row_uuid```를 인덱스(index)로 지정해주세요.**
#
# 데이터를 다 정리했으면 마지막으로 인덱스(index)를 지정하고 마무리하겠습니다. 현재 가지고 있는 데이터에서 인덱스가 될 수 있을만한 컬럼은 ```row_uuid``` 입니다. 이 컬럼을 인덱스로 지정하면, 앞으로 데이터의 행(row)을 가져오고 분석할 때 큰 도움이 될 것 같습니다. 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>app_package_name</th>
#       <th>user_id</th>
#       <th>event_datetime</th>
#       <th>event_datetime_year</th>
#       <th>event_datetime_month</th>
#       <th>event_datetime_day</th>
#       <th>event_datetime_hour</th>
#       <th>event_datetime_minute</th>
#       <th>event_datetime_second</th>
#       <th>device_manufacturer</th>
#       <th>device_type</th>
#       <th>os_type</th>
#       <th>os_version</th>
#       <th>app_version</th>
#       <th>event_category</th>
#       <th>view_category</th>
#       <th>view_id</th>
#       <th>view_action</th>
#       <th>funnel_desc</th>
#       <th>view_desc</th>
#       <th>category_name</th>
#       <th>category1</th>
#       <th>category2</th>
#       <th>category3</th>
#       <th>channel</th>
#       <th>params_campaign</th>
#       <th>params_medium</th>
#       <th>params_term</th>
#       <th>is_first_activity</th>
#       <th>is_first_goal_activity</th>
#     </tr>
#     <tr>
#       <th>row_uuid</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>fd2a188c-bc9b-4702-9c47-b546b2614817</th>
#       <td>com.kmong.iOS</td>
#       <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#       <td>2018-09-27 15:00:00</td>
#       <td>2018</td>
#       <td>9</td>
#       <td>27</td>
#       <td>15</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Apple</td>
#       <td>iPhone</td>
#       <td>iOS</td>
#       <td>11.4.1</td>
#       <td>4.0.4</td>
#       <td>goal</td>
#       <td>home</td>
#       <td>home</td>
#       <td>view</td>
#       <td>홈</td>
#       <td>홈 (탭)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>unattributed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>e62dccef-dd70-4415-8a33-c8324ddaed38</th>
#       <td>com.kmong.kmong</td>
#       <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#       <td>2018-09-27 15:00:00</td>
#       <td>2018</td>
#       <td>9</td>
#       <td>27</td>
#       <td>15</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Samsung</td>
#       <td>SM-N935S</td>
#       <td>Android</td>
#       <td>7.0</td>
#       <td>3.3.5</td>
#       <td>goal</td>
#       <td>gig</td>
#       <td>gig_detail</td>
#       <td>view</td>
#       <td>상품</td>
#       <td>상품상세</td>
#       <td>자기소개서</td>
#       <td>문서작성</td>
#       <td>자기소개서·이력서</td>
#       <td>자기소개서</td>
#       <td>unattributed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b                     9
# 236e9946-7801-4898-b609-06c8ab1139dc                     9
#
#                                       event_datetime_day  event_datetime_hour  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817                  28                    0
# e62dccef-dd70-4415-8a33-c8324ddaed38                  28                    0
# 14eb3197-db83-493a-b7be-83582960c40b                  28                    0
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b                  28                    0
# 236e9946-7801-4898-b609-06c8ab1139dc                  28                    0
#
#                                       event_datetime_minute  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817                      0
# e62dccef-dd70-4415-8a33-c8324ddaed38                      0
# 14eb3197-db83-493a-b7be-83582960c40b                      0
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b                      0
# 236e9946-7801-4898-b609-06c8ab1139dc                      0
#
#                                       event_datetime_second  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817                      0
# e62dccef-dd70-4415-8a33-c8324ddaed38                      0
# 14eb3197-db83-493a-b7be-83582960c40b                      0
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b                      1
# 236e9946-7801-4898-b609-06c8ab1139dc                      2
#
#                                      device_manufacturer device_type  os_type  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817               Apple      iPhone      iOS
# e62dccef-dd70-4415-8a33-c8324ddaed38             Samsung    SM-N935S  Android
# 14eb3197-db83-493a-b7be-83582960c40b               Apple      iPhone      iOS
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b               Apple      iPhone      iOS
# 236e9946-7801-4898-b609-06c8ab1139dc               Apple      iPhone      iOS
#
#                                      os_version app_version event_category  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817     11.4.1       4.0.4           goal
# e62dccef-dd70-4415-8a33-c8324ddaed38        7.0       3.3.5           goal
# 14eb3197-db83-493a-b7be-83582960c40b       12.0       4.0.4           goal
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b     11.4.1       4.0.4     foreground
# 236e9946-7801-4898-b609-06c8ab1139dc     11.4.1       4.0.4           goal
#
#                                      view_category            view_id  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817     home.view               home
# e62dccef-dd70-4415-8a33-c8324ddaed38           gig         gig_detail
# 14eb3197-db83-493a-b7be-83582960c40b         inbox       inbox_detail
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b           NaN                NaN
# 236e9946-7801-4898-b609-06c8ab1139dc         buyer  buyer_order_track
#
#                                      view_action funnel_desc        view_desc  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817        view           홈            홈 (탭)
# e62dccef-dd70-4415-8a33-c8324ddaed38        view          상품             상품상세
# 14eb3197-db83-493a-b7be-83582960c40b        view         메시지         메시지목록-상세
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b         NaN         NaN              NaN
# 236e9946-7801-4898-b609-06c8ab1139dc        view        거래관리  메뉴목록-구매관리-거래메시지
#
#                                      category_name category1  category2  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817           NaN       NaN        NaN
# e62dccef-dd70-4415-8a33-c8324ddaed38         자기소개서      문서작성  자기소개서·이력서
# 14eb3197-db83-493a-b7be-83582960c40b           NaN       NaN        NaN
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b           NaN       NaN        NaN
# 236e9946-7801-4898-b609-06c8ab1139dc           NaN       NaN        NaN
#
#                                      category3       channel params_campaign  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817       NaN  unattributed             NaN
# e62dccef-dd70-4415-8a33-c8324ddaed38     자기소개서  unattributed             NaN
# 14eb3197-db83-493a-b7be-83582960c40b       NaN  unattributed             NaN
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b       NaN           NaN             NaN
# 236e9946-7801-4898-b609-06c8ab1139dc       NaN           web             NaN
#
#                                      params_medium params_term  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817           NaN         NaN
# e62dccef-dd70-4415-8a33-c8324ddaed38           NaN         NaN
# 14eb3197-db83-493a-b7be-83582960c40b           NaN         NaN
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b           NaN         NaN
# 236e9946-7801-4898-b609-06c8ab1139dc           NaN         NaN
#
#                                      is_first_activity is_first_goal_activity
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817             False                  False
# e62dccef-dd70-4415-8a33-c8324ddaed38             False                  False
# 14eb3197-db83-493a-b7be-83582960c40b             False                  False
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b               NaN                    NaN
# 236e9946-7801-4898-b609-06c8ab1139dc             False                  False

# %% [markdown]
# ## 제출
#
# 과제를 다 끝내셨으면 http://bit.ly/ds-assignment 에서 안내에 따라 과제를 제출하여 주세요! 과제를 제출해주시면 솔루션과 검토 결과를 드립니다. 오프라인 수업의 경우 과제를 제출하지 않으시더라도 솔루션은 다음 수업 시간에 제공해드립니다.
#
# 수업이나 과제 관련 질문, 수료증 문의 등은 담당 튜터(조교)에게 문의 주세요. 영수증 발급 등의 문의는 support@dsschool.co.kr 로 메일 주시면 담당자분이 응대해주실 겁니다. 기타 궁금한 사항은 슬랙으로 문의 주세요!

# %% [markdown]
# ## 데이터에서 체크할 부분-1

# %%
# event_category가 'goal'이 아닌 경우에는 'view_category'의 값이 없어야 한다. 하지만 존재
result.loc[result['event_category']!='goal'].loc[result['view_category'].notnull()]
# Out:
#                                      app_package_name  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265  com.kmong.kmong
# da0a9e12-d89e-4948-8121-862f8c61a702  com.kmong.kmong
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48  com.kmong.kmong
# deb015e1-06da-402f-ba01-322588f9a730  com.kmong.kmong
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c  com.kmong.kmong
# ...                                               ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d  com.kmong.kmong
# 1c337bf1-0967-49ee-bceb-a08aba001cef  com.kmong.kmong
# 9562dc74-d108-4276-83da-0055a591a56b  com.kmong.kmong
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209  com.kmong.kmong
# 24b55835-cc49-4778-8230-73a7f2ba41ff  com.kmong.kmong
#
#                                                                    user_id  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265  165c40f3-7bf9-49f0-9c64-5b285bd0225a
# da0a9e12-d89e-4948-8121-862f8c61a702  c0def9b8-b54e-4efa-ba9e-5d960e9fce2d
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48  a96fe42f-036c-43b5-bef8-3609cf21ca8b
# deb015e1-06da-402f-ba01-322588f9a730  a79e726c-6cc8-4790-abb0-cc3873cc4fd7
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c  cb076d8e-65a2-4b52-afb7-b356a0978af9
# ...                                                                    ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d  66300e86-67a9-48a5-a76c-97d8457aa6a3
# 1c337bf1-0967-49ee-bceb-a08aba001cef  b6ebe87d-7f86-4d1b-96b4-53fa9f8cffab
# 9562dc74-d108-4276-83da-0055a591a56b  d35f8a5f-4b07-4e4d-8f5f-ccdba452373f
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209  5cf2d759-2bef-4254-9d30-0a3364c5272f
# 24b55835-cc49-4778-8230-73a7f2ba41ff  7883117b-0c36-4dfd-aa77-8ea55c984ecd
#
#                                                 event_datetime  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265 2018-09-28 00:32:52+09:00
# da0a9e12-d89e-4948-8121-862f8c61a702 2018-09-28 00:55:16+09:00
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48 2018-09-28 01:02:00+09:00
# deb015e1-06da-402f-ba01-322588f9a730 2018-09-28 01:03:07+09:00
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c 2018-09-28 01:19:19+09:00
# ...                                                        ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d 2018-09-29 23:51:23+09:00
# 1c337bf1-0967-49ee-bceb-a08aba001cef 2018-09-29 23:51:44+09:00
# 9562dc74-d108-4276-83da-0055a591a56b 2018-09-29 23:52:10+09:00
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209 2018-09-29 23:55:06+09:00
# 24b55835-cc49-4778-8230-73a7f2ba41ff 2018-09-29 23:58:35+09:00
#
#                                       event_datetime_year  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265                 2018
# da0a9e12-d89e-4948-8121-862f8c61a702                 2018
# 60a57be1-f0c4-4468-88b0-fc44c7f59e
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209      8.1.0       3.3.5         launch
# 24b55835-cc49-4778-8230-73a7f2ba41ff      8.0.0       3.3.5         launch
#
#                                      view_category            view_id  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265         inbox       inbox_detail
# da0a9e12-d89e-4948-8121-862f8c61a702         buyer  buyer_order_track
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48           gig         gig_detail
# deb015e1-06da-402f-ba01-322588f9a730         inbox       inbox_detail
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c     home.view               home
# ...                                            ...                ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d         buyer  buyer_order_track
# 1c337bf1-0967-49ee-bceb-a08aba001cef         buyer  buyer_order_track
# 9562dc74-d108-4276-83da-0055a591a56b         buyer  buyer_order_track
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209           gig         gig_detail
# 24b55835-cc49-4778-8230-73a7f2ba41ff         buyer  buyer_order_track
#
#                                      view_action funnel_desc        view_desc  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265        view         메시지         메시지목록-상세
# da0a9e12-d89e-4948-8121-862f8c61a702        view        거래관리  메뉴목록-구매관리-거래메시지
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48        view          상품             상품상세
# deb015e1-06da-402f-ba01-322588f9a730        view         메시지         메시지목록-상세
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c        view           홈            홈 (탭)
# ...                                          ...         ...              ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d        view        거래관리  메뉴목록-구매관리-거래메시지
# 1c337bf1-0967-49ee-bceb-a08aba001cef        view        거래관리  메뉴목록-구매관리-거래메시지
# 9562dc74-d108-4276-83da-0055a591a56b        view        거래관리  메뉴목록-구매관리-거래메시지
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209        view          상품             상품상세
# 24b55835-cc49-4778-8230-73a7f2ba41ff        view        거래관리  메뉴목록-구매관리-거래메시지
#
#                                      category_name category1  category2  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265           NaN       NaN        NaN
# da0a9e12-d89e-4948-8121-862f8c61a702           NaN       NaN        NaN
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48     연관검색·자동완성       마케팅  상위노출·검색작업
# deb015e1-06da-402f-ba01-322588f9a730           NaN       NaN        NaN
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c           NaN       NaN        NaN
# ...                                            ...       ...        ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d           NaN       NaN        NaN
# 1c337bf1-0967-49ee-bceb-a08aba001cef           NaN       NaN        NaN
# 9562dc74-d108-4276-83da-0055a591a56b           NaN       NaN        NaN
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209           노하우       마케팅    마케팅 컨설팅
# 24b55835-cc49-4778-8230-73a7f2ba41ff           NaN       NaN        NaN
#
#                                       category3       channel params_campaign  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265        NaN  unattributed             NaN
# da0a9e12-d89e-4948-8121-862f8c61a702        NaN  unattributed             NaN
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48  연관검색·자동완성  unattributed             NaN
# deb015e1-06da-402f-ba01-322588f9a730        NaN  unattributed             NaN
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c        NaN        google             NaN
# ...                                         ...           ...             ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d        NaN  unattributed             NaN
# 1c337bf1-0967-49ee-bceb-a08aba001cef        NaN  unattributed             NaN
# 9562dc74-d108-4276-83da-0055a591a56b        NaN  unattributed             NaN
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209        노하우  unattributed             NaN
# 24b55835-cc49-4778-8230-73a7f2ba41ff        NaN  unattributed             NaN
#
#                                      params_medium params_term  \
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265           NaN         NaN
# da0a9e12-d89e-4948-8121-862f8c61a702           NaN         NaN
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48           NaN         NaN
# deb015e1-06da-402f-ba01-322588f9a730           NaN         NaN
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c       organic         NaN
# ...                                            ...         ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d           NaN         NaN
# 1c337bf1-0967-49ee-bceb-a08aba001cef           NaN         NaN
# 9562dc74-d108-4276-83da-0055a591a56b           NaN         NaN
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209           NaN         NaN
# 24b55835-cc49-4778-8230-73a7f2ba41ff           NaN         NaN
#
#                                      is_first_activity is_first_goal_activity
# row_uuid
# 503c500f-cc15-4886-ae8b-dcc03ce4f265             False                  False
# da0a9e12-d89e-4948-8121-862f8c61a702             False                  False
# 60a57be1-f0c4-4468-88b0-fc44c7f59e48             False                  False
# deb015e1-06da-402f-ba01-322588f9a730             False                  False
# 4c53732c-4068-4af4-b193-c8e4d11c2e0c             False                  False
# ...                                                ...                    ...
# 3a2771a2-a44c-4270-89b5-57bdb398f51d             False                  False
# 1c337bf1-0967-49ee-bceb-a08aba001cef             False                  False
# 9562dc74-d108-4276-83da-0055a591a56b             False                  False
# e0e8e5fa-96b5-45b3-8ac1-ca33e2be1209             False                  False
# 24b55835-cc49-4778-8230-73a7f2ba41ff             False                  False
#
# [1674 rows x 30 columns]

# %%
# view_action에 따라 이를 'goal'로 볼 것인가 말것인가 파악
result.loc[result['event_category']!='goal'].loc[result['view_category'].notnull()][['view_action']].value_counts()
# Out:
# view_action
# view           1670
# click             4
# dtype: int64

# %%
1674/len(result)      # 전체 데이터의 0.3%에 해당
                      # 하지만 이 데이터들을 'goal'로 볼지, 'launch'로 볼지 2가지의 경우로 나눠지기에 오류율은 0.6%로 판단
                      # 우리는 0.6%라는 수치는 괜찮다고 판단하여 데이터를 그대로 유지하기로 결정
# Out:
# 0.00385497554370354

# %% [markdown]
# ## 데이터에서 체크할 부분-2

# %%
# 결제완료한 로그에 'category' 데이터가 남지 않은 경우
# 이러한 경우 무슨 상품을 결제완료한 건지 파악 불가
result[result.funnel_desc=='결제완료']
# Out:
#                                      app_package_name  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561    com.kmong.iOS
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9  com.kmong.kmong
# 198679d3-46bc-4886-9fdf-361ece639092  com.kmong.kmong
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90    com.kmong.iOS
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5  com.kmong.kmong
# ...                                               ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12    com.kmong.iOS
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90    com.kmong.iOS
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4  com.kmong.kmong
# a4984e1a-5cee-4252-9335-01abfcc347e7  com.kmong.kmong
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7    com.kmong.iOS
#
#                                                                    user_id  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561  5423AD20-B746-40F2-B058-56A57E6EB241
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9  ffeac67d-b2a6-4cda-b80e-0230b5498d46
# 198679d3-46bc-4886-9fdf-361ece639092  62061f8c-5c09-4ef2-98fc-87f96fabe2e5
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90  5DF88625-EAE2-4DF4-B171-43499D9681CC
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5  212111d6-54f3-4e3c-be49-470399d33058
# ...                                                                    ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12  93403117-BB0B-4A19-9592-775B24AE4038
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90  C194D65F-B2AF-4BEC-B6A7-CC21467B0A31
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4  02a3627c-4fd6-4d6e-921a-dbea8724b1de
# a4984e1a-5cee-4252-9335-01abfcc347e7  7ad59ae6-83cb-4582-9a98-a63b04c779d7
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7  2E30D23A-5262-4CAA-8575-8A394FBD4C2C
#
#                                                 event_datetime  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561 2018-09-28 00:02:25+09:00
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9 2018-09-28 00:05:06+09:00
# 198679d3-46bc-4886-9fdf-361ece639092 2018-09-28 00:34:59+09:00
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90 2018-09-28 01:09:32+09:00
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5 2018-09-28 02:01:46+09:00
# ...                                                        ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12 2018-09-29 23:28:12+09:00
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90 2018-09-29 23:50:03+09:00
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4 2018-09-29 23:51:35+09:00
# a4984e1a-5cee-4252-9335-01abfcc347e7 2018-09-29 23:51:59+09:00
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7 2018-09-29 23:53:23+09:00
#
#                                       event_datetime_year  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                 2018
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9                 2018
# 198679d3-46bc-4886-9fdf-361ece639092                 2018
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90                 2018
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5                 2018
# ...                                                   ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12                 2018
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90                 2018
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4                 2018
# a4984e1a-5cee-4252-9335-01abfcc347e7                 2018
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7                 2018
#
#                                       event_datetime_month  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                     9
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9                     9
# 198679d3-46bc-4886-9fdf-361ece639092                     9
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90                     9
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5                     9
# ...                                                    ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12                     9
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90                     9
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4                     9
# a4984e1a-5cee-4252-9335-01abfcc347e7                     9
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7                     9
#
#                                       event_datetime_day  event_datetime_hour  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                  28                    0
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9                  28                    0
# 198679d3-46bc-4886-9fdf-361ece639092                  28                    0
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90                  28                    1
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5                  28                    2
# ...                                                  ...                  ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12                  29                   23
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90                  29                   23
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4                  29                   23
# a4984e1a-5cee-4252-9335-01abfcc347e7                  29                   23
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7                  29                   23
#
#                                       event_datetime_minute  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                      2
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9                      5
# 198679d3-46bc-4886-9fdf-361ece639092                     34
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90                      9
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5                      1
# ...                                                     ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12                     28
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90                     50
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4                     51
# a4984e1a-5cee-4252-9335-01abfcc347e7                     51
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7                     53
#
#                                       event_datetime_second  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                     25
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9                      6
# 198679d3-46bc-4886-9fdf-361ece639092                     59
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90                     32
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5                     46
# ...                                                     ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12                     12
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90                      3
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4                     35
# a4984e1a-5cee-4252-9335-01abfcc347e7                     59
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7                     23
#
#                                      device_manufacturer device_type  os_type  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561               Apple      iPhone      iOS
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9             Samsung     SM-P580  Android
# 198679d3-46bc-4886-9fdf-361ece639092             Samsung    SM-N935K  Android
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90               Apple      iPhone      iOS
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5             Samsung    SM-N950N  Android
# ...                                                  ...         ...      ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12               Apple      iPhone      iOS
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90               Apple      iPhone      iOS
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4             Samsung    SM-G930K  Android
# a4984e1a-5cee-4252-9335-01abfcc347e7             Samsung    SM-N960N  Android
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7               Apple      iPhone      iOS
#
#                                      os_version app_version event_category  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561       11.4       4.0.4           goal
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9        7.0       3.3.5           goal
# 198679d3-46bc-4886-9fdf-361ece639092      8.0.0       3.3.5           goal
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90     11.4.1       4.0.4           goal
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5      8.0.0       3.3.5           goal
# ...                                         ...         ...            ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12     11.4.1       4.0.4           goal
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90     11.4.1       4.0.4           goal
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4      8.0.0       3.3.5           goal
# a4984e1a-5cee-4252-9335-01abfcc347e7      8.1.0       3.3.5           goal
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7     10.3.3       4.0.4           goal
#
#                                        view_category   view_id view_action  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561  thankyou.click  thankyou       click
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9   thankyou.view  thankyou        view
# 198679d3-46bc-4886-9fdf-361ece639092   thankyou.view  thankyou        view
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90  thankyou.click  thankyou       click
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5   thankyou.view  thankyou        view
# ...                                              ...       ...         ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12  thankyou.click  thankyou       click
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90  thankyou.click  thankyou       click
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4   thankyou.view  thankyou        view
# a4984e1a-5cee-4252-9335-01abfcc347e7   thankyou.view  thankyou        view
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7  thankyou.click  thankyou       click
#
#                                      funnel_desc view_desc category_name  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561        결제완료      결제완료           NaN
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9        결제완료      결제완료          연애상담
# 198679d3-46bc-4886-9fdf-361ece639092        결제완료      결제완료         자기소개서
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90        결제완료      결제완료     PPT·인포그래픽
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5        결제완료      결제완료            홍보
# ...                                          ...       ...           ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12        결제완료      결제완료         로고디자인
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90        결제완료      결제완료           NaN
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4        결제완료      결제완료           트래픽
# a4984e1a-5cee-4252-9335-01abfcc347e7        결제완료      결제완료            운세
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7        결제완료      결제완료           NaN
#
#                                      category1  category2 category3  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561       NaN        NaN       NaN
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9    상담·컨설팅       연애상담       NaN
# 198679d3-46bc-4886-9fdf-361ece639092      문서작성  자기소개서·이력서     자기소개서
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90       디자인  PPT·인포그래픽       NaN
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5       마케팅    SNS 마케팅        홍보
# ...                                        ...        ...       ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12       디자인      로고디자인       NaN
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90       NaN        NaN       NaN
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4       마케팅     카페·블로그       트래픽
# a4984e1a-5cee-4252-9335-01abfcc347e7    상담·컨설팅         운세       NaN
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7       NaN        NaN       NaN
#
#                                            channel   params_campaign  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561  unattributed               NaN
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9  unattributed               NaN
# 198679d3-46bc-4886-9fdf-361ece639092        google  mweb-app-install
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90  unattributed               NaN
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5  unattributed               NaN
# ...                                            ...               ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12  unattributed               NaN
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90  unattributed               NaN
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4  unattributed               NaN
# a4984e1a-5cee-4252-9335-01abfcc347e7  unattributed               NaN
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7           web               NaN
#
#                                      params_medium params_term  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561           NaN         NaN
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9           NaN         NaN
# 198679d3-46bc-4886-9fdf-361ece639092           cpc         NaN
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90           NaN         NaN
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5           NaN         NaN
# ...                                            ...         ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12           NaN         NaN
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90           NaN         NaN
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4           NaN         NaN
# a4984e1a-5cee-4252-9335-01abfcc347e7           NaN         NaN
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7           NaN         NaN
#
#                                      is_first_activity is_first_goal_activity
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561             False                  False
# 37b8e086-e2d2-47c6-b9e2-141d76e244c9              True                  False
# 198679d3-46bc-4886-9fdf-361ece639092              True                   True
# 1c5b0f55-52a3-4a32-8f42-d7faf7899c90              True                   True
# a548c1d8-6997-48a0-8cd1-6b2a6ffcfaa5              True                  False
# ...                                                ...                    ...
# a7e730e8-34d4-4cf3-bbae-b2df17fd9d12              True                   True
# a57fd5d1-ed21-4f68-9901-dc3baa4d6a90             False                  False
# 7a1f9f16-70b0-4572-bf43-de6424ddf9a4              True                   True
# a4984e1a-5cee-4252-9335-01abfcc347e7              True                   True
# 5edfc6fe-09f2-4b47-99c0-160caeee36a7              True                   True
#
# [418 rows x 30 columns]

# %%
# 첫 로그에 '결제완료'가 찍힌 경우 'category' 파악 불가
result[result['user_id']=='5423AD20-B746-40F2-B058-56A57E6EB241']
# Out:
#                                      app_package_name  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561    com.kmong.iOS
# 286dd761-bb1c-4edc-8684-b982fd611944    com.kmong.iOS
# 7291bcbb-9335-4a89-9d5c-c817db0e9627    com.kmong.iOS
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b    com.kmong.iOS
# 1618d18d-98a7-4575-84fd-96ba0c93b04b    com.kmong.iOS
# ...                                               ...
# d89a4c05-5866-47d4-a949-089dc4f26434    com.kmong.iOS
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8    com.kmong.iOS
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f    com.kmong.iOS
# 8a0442e3-b057-4164-9884-53abac2daf57    com.kmong.iOS
# 8d7063d9-789f-4589-8cc4-85a150fded7b    com.kmong.iOS
#
#                                                                    user_id  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d
\
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                      2
# 286dd761-bb1c-4edc-8684-b982fd611944                      2
# 7291bcbb-9335-4a89-9d5c-c817db0e9627                      2
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b                      2
# 1618d18d-98a7-4575-84fd-96ba0c93b04b                      2
# ...                                                     ...
# d89a4c05-5866-47d4-a949-089dc4f26434                     50
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8                     50
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f                     50
# 8a0442e3-b057-4164-9884-53abac2daf57                     50
# 8d7063d9-789f-4589-8cc4-85a150fded7b                     50
#
#                                       event_datetime_second  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561                     25
# 286dd761-bb1c-4edc-8684-b982fd611944                     34
# 7291bcbb-9335-4a89-9d5c-c817db0e9627                     37
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b                     41
# 1618d18d-98a7-4575-84fd-96ba0c93b04b                     47
# ...                                                     ...
# d89a4c05-5866-47d4-a949-089dc4f26434                     43
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8                     48
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f                     50
# 8a0442e3-b057-4164-9884-53abac2daf57                     51
# 8d7063d9-789f-4589-8cc4-85a150fded7b                     53
#
#                                      device_manufacturer device_type os_type  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561               Apple      iPhone     iOS
# 286dd761-bb1c-4edc-8684-b982fd611944               Apple      iPhone     iOS
# 7291bcbb-9335-4a89-9d5c-c817db0e9627               Apple      iPhone     iOS
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b               Apple      iPhone     iOS
# 1618d18d-98a7-4575-84fd-96ba0c93b04b               Apple      iPhone     iOS
# ...                                                  ...         ...     ...
# d89a4c05-5866-47d4-a949-089dc4f26434               Apple      iPhone     iOS
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8               Apple      iPhone     iOS
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f               Apple      iPhone     iOS
# 8a0442e3-b057-4164-9884-53abac2daf57               Apple      iPhone     iOS
# 8d7063d9-789f-4589-8cc4-85a150fded7b               Apple      iPhone     iOS
#
#                                      os_version app_version event_category  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561       11.4       4.0.4           goal
# 286dd761-bb1c-4edc-8684-b982fd611944       11.4       4.0.4           goal
# 7291bcbb-9335-4a89-9d5c-c817db0e9627       11.4       4.0.4           goal
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b       11.4       4.0.4           goal
# 1618d18d-98a7-4575-84fd-96ba0c93b04b       11.4       4.0.4           goal
# ...                                         ...         ...            ...
# d89a4c05-5866-47d4-a949-089dc4f26434       11.4       4.0.4           goal
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8       11.4       4.0.4           goal
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f       11.4       4.0.4           goal
# 8a0442e3-b057-4164-9884-53abac2daf57       11.4       4.0.4           goal
# 8d7063d9-789f-4589-8cc4-85a150fded7b       11.4       4.0.4     background
#
#                                        view_category            view_id  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561  thankyou.click           thankyou
# 286dd761-bb1c-4edc-8684-b982fd611944           buyer  buyer_order_track
# 7291bcbb-9335-4a89-9d5c-c817db0e9627             gig         gig_detail
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b           inbox       inbox_detail
# 1618d18d-98a7-4575-84fd-96ba0c93b04b           buyer  buyer_order_track
# ...                                              ...                ...
# d89a4c05-5866-47d4-a949-089dc4f26434           inbox       inbox_detail
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8      inbox.view              inbox
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f           inbox       inbox_detail
# 8a0442e3-b057-4164-9884-53abac2daf57           buyer  buyer_order_track
# 8d7063d9-789f-4589-8cc4-85a150fded7b             NaN                NaN
#
#                                      view_action funnel_desc        view_desc  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561       click        결제완료             결제완료
# 286dd761-bb1c-4edc-8684-b982fd611944        view        거래관리  메뉴목록-구매관리-거래메시지
# 7291bcbb-9335-4a89-9d5c-c817db0e9627        view          상품             상품상세
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b        view         메시지         메시지목록-상세
# 1618d18d-98a7-4575-84fd-96ba0c93b04b        view        거래관리  메뉴목록-구매관리-거래메시지
# ...                                          ...         ...              ...
# d89a4c05-5866-47d4-a949-089dc4f26434        view         메시지         메시지목록-상세
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8        view         메시지        메시지목록 (탭)
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f        view         메시지         메시지목록-상세
# 8a0442e3-b057-4164-9884-53abac2daf57        view        거래관리  메뉴목록-구매관리-거래메시지
# 8d7063d9-789f-4589-8cc4-85a150fded7b         NaN         NaN              NaN
#
#                                      category_name category1 category2  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561           NaN       NaN       NaN
# 286dd761-bb1c-4edc-8684-b982fd611944           NaN       NaN       NaN
# 7291bcbb-9335-4a89-9d5c-c817db0e9627        음악·사운드    콘텐츠 제작    음악·사운드
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b           NaN       NaN       NaN
# 1618d18d-98a7-4575-84fd-96ba0c93b04b           NaN       NaN       NaN
# ...                                            ...       ...       ...
# d89a4c05-5866-47d4-a949-089dc4f26434           NaN       NaN       NaN
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8           NaN       NaN       NaN
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f           NaN       NaN       NaN
# 8a0442e3-b057-4164-9884-53abac2daf57           NaN       NaN       NaN
# 8d7063d9-789f-4589-8cc4-85a150fded7b           NaN       NaN       NaN
#
#                                      category3       channel params_campaign  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561       NaN  unattributed             NaN
# 286dd761-bb1c-4edc-8684-b982fd611944       NaN  unattributed             NaN
# 7291bcbb-9335-4a89-9d5c-c817db0e9627       NaN  unattributed             NaN
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b       NaN  unattributed             NaN
# 1618d18d-98a7-4575-84fd-96ba0c93b04b       NaN  unattributed             NaN
# ...                                        ...           ...             ...
# d89a4c05-5866-47d4-a949-089dc4f26434       NaN  unattributed             NaN
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8       NaN  unattributed             NaN
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f       NaN  unattributed             NaN
# 8a0442e3-b057-4164-9884-53abac2daf57       NaN  unattributed             NaN
# 8d7063d9-789f-4589-8cc4-85a150fded7b       NaN           NaN             NaN
#
#                                      params_medium params_term  \
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561           NaN         NaN
# 286dd761-bb1c-4edc-8684-b982fd611944           NaN         NaN
# 7291bcbb-9335-4a89-9d5c-c817db0e9627           NaN         NaN
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b           NaN         NaN
# 1618d18d-98a7-4575-84fd-96ba0c93b04b           NaN         NaN
# ...                                            ...         ...
# d89a4c05-5866-47d4-a949-089dc4f26434           NaN         NaN
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8           NaN         NaN
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f           NaN         NaN
# 8a0442e3-b057-4164-9884-53abac2daf57           NaN         NaN
# 8d7063d9-789f-4589-8cc4-85a150fded7b           NaN         NaN
#
#                                      is_first_activity is_first_goal_activity
# row_uuid
# 3c45d3d3-df64-40ec-be70-bdc369c9d561             False                  False
# 286dd761-bb1c-4edc-8684-b982fd611944             False                  False
# 7291bcbb-9335-4a89-9d5c-c817db0e9627             False                  False
# 4cd8fa0f-0f6f-4f46-8e31-9fbe56dfe16b             False                  False
# 1618d18d-98a7-4575-84fd-96ba0c93b04b             False                  False
# ...                                                ...                    ...
# d89a4c05-5866-47d4-a949-089dc4f26434             False                  False
# 1326b3e5-0a9d-4173-9cda-94dc70d815f8             False                  False
# c428d0ff-f1d6-4bb5-bb7c-4ba65173de7f             False                  False
# 8a0442e3-b057-4164-9884-53abac2daf57             False                  False
# 8d7063d9-789f-4589-8cc4-85a150fded7b               NaN                    NaN
#
# [266 rows x 30 columns]

# %%
# '상품'을 본 후 '결제'퍼널로 넘어가 '결제'퍼널에는 'category'가 남음
# 하지만 '결제'퍼널 이후, '휴대폰인증'으로 인해 '결제완료'의 'category'가 없어짐
result[result['user_id']=='BBEAA97F-E8B8-495B-A9DF-39C0E4E8CEF
# 32a27ed6-0ba9-4488-9613-79a96bc7ed43               Apple      iPhone     iOS
# bb13d046-cb4e-4c4f-a709-d9e0784e6fdf               Apple      iPhone     iOS
# 13e69f74-25d1-4ed0-a562-a30a734eac02               Apple      iPhone     iOS
# bc01e679-a264-4cad-8f67-3d4319f7e2a4               Apple      iPhone     iOS
# 74b0187e-59c0-496f-8f39-467e3ad10c46               Apple      iPhone     iOS
# 5f67d39a-c000-42fb-a159-4cb3faa67706               Apple      iPhone     iOS
# 49b4c9aa-ef99-490b-af43-9d8b67d6c53d               Apple      iPhone     iOS
# ad473b1e-d89b-46bd-bc0d-558400af49dc               Apple      iPhone     iOS
# 3532138c-1705-43ce-81ea-3fc03ddc399f               Apple      iPhone     iOS
# 4005da70-b157-47d7-a79d-0cf65e087053               Apple      iPhone     iOS
# 07357100-f49c-47bc-a24e-8b6914a8062c               Apple      iPhone     iOS
# f4f35e0a-a754-402e-a5a1-3a993886ec86               Apple      iPhone     iOS
# 6c4a0440-1315-486b-97cb-34f08a8c2190               Apple      iPhone     iOS
# 23024710-8434-4a09-bfa2-b054ce466dbe               Apple      iPhone     iOS
# 9b163b94-e673-4814-8903-ef4349681d2f               Apple      iPhone     iOS
# d8cf577b-b4c1-41ad-bf93-868b9ee8747a               Apple      iPhone     iOS
# 7420083d-aa04-4362-8cc9-4c046ab65f60               Apple      iPhone     iOS
# 273a8e5c-02b2-4cb6-b3f3-dd0ca7414bf4               Apple      iPhone     iOS
# a297b338-68b3-4c3e-8ba0-3bda8abfc80f               Apple      iPhone     iOS
# e3da5c9c-384e-4a17-9788-120072e33882               Apple      iPhone     iOS
# 69cb8265-8e51-4aa0-b36b-bc7001ff2014               Apple      iPhone     iOS
# 2eb487b2-f652-4832-a61e-e52ec4a40591               Apple      iPhone     iOS
# 43ee7fde-7971-4ea3-81fa-1f105cd407e5               Apple      iPhone     iOS
# 2e819b85-2245-4b14-8a18-ed53b5dcaee9               Apple      iPhone     iOS
# 0cea9322-6aec-4c34-99be-791011964033               Apple      iPhone     iOS
# a1662cf5-00c8-432c-a3bf-8f80d4963634               Apple      iPhone     iOS
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684               Apple      iPhone     iOS
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e               Apple      iPhone     iOS
# 275cd800-db28-4a7c-8e20-3f9a844bba94               Apple      iPhone     iOS
# d8a6eab0-af9b-400d-91e0-0722d952501c               Apple      iPhone     iOS
# 4e395080-da2a-413b-8258-2783901dc3b1               Apple      iPhone     iOS
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8               Apple      iPhone     iOS
# de0ff352-c35f-4295-8e0d-87b4457fd635               Apple      iPhone     iOS
# 91657360-953c-4700-8404-1d42e83c2820               Apple      iPhone     iOS
# a99d3474-4faa-4e49-b523-3b3a6da58222               Apple      iPhone     iOS
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c               Apple      iPhone     iOS
# f259eacc-4026-454e-9ca0-2ca9bc8785c3               Apple      iPhone     iOS
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6f               Apple      iPhone     iOS
# 1b4ce2f7-38d7-485e-a361-90f249882303               Apple      iPhone     iOS
# 38e4ba06-b4b1-402d-b88a-815e26954a04               Apple      iPhone     iOS
# 6cabd6aa-8930-4429-b468-86435f107547               Apple      iPhone     iOS
# 49fa3ad9-5c22-4961-be53-f8e31f22ecc2               Apple      iPhone     iOS
# 364838ef-0295-4e4c-9111-153809a52f00               Apple      iPhone     iOS
# ea54d17e-cfbd-402e-8421-87c0e3588cd1               Apple      iPhone     iOS
# 6560eb93-d3f5-4756-ad51-85938d63d405               Apple      iPhone     iOS
# 4211c750-d25c-4684-9149-792ebb684351               Apple      iPhone     iOS
#
#                                      os_version app_version   event_category  \
# row_uuid
# 61a0dcd5-b356-4ff8-b023-0c2a338c347b     11.4.1       4.0.4           launch
# ccad2e4a-6c28-4d67-abfb-4b52bc8ceabc     11.4.1       4.0.4             goal
# a1c02411-87e8-46dd-82b7-969b121d8a66     11.4.1       4.0.4             goal
# f9018e0f-0814-4be1-b376-1eb6693baf79     11.4.1       4.0.4       background
# 8225cc30-a668-4050-93e7-57a55a215edb     11.4.1       4.0.4       foreground
# 894f6cb5-3d63-440c-b694-4f597abd4950     11.4.1       4.0.4             goal
# 6b352370-0026-42ab-8918-db3e28b15873     11.4.1       4.0.4             goal
# 22728744-516b-478f-834f-d5668b77bb1c     11.4.1       4.0.4             goal
# bd00f8ec-e455-45e3-abe9-05a0bb7dea38     11.4.1       4.0.4             goal
# 1752e884-f1e6-4b00-94c3-b0cc56d39163     11.4.1       4.0.4             goal
# 663de17f-1b04-406f-b530-8143a4e7026a     11.4.1       4.0.4             goal
# e3d79fd8-8fb6-4a24-81ae-1be130d6ff28     11.4.1       4.0.4             goal
# a448f8e5-4ad7-4ad8-9d02-30bc3f574927     11.4.1       4.0.4             goal
# dc41aae5-6a3b-4e60-a2d2-4725a7b1a42f     11.4.1       4.0.4             goal
# 32a27ed6-0ba9-4488-9613-79a96bc7ed43     11.4.1       4.0.4             goal
# bb13d046-cb4e-4c4f-a709-d9e0784e6fdf     11.4.1       4.0.4       background
# 13e69f74-25d1-4ed0-a562-a30a734eac02     11.4.1       4.0.4       foreground
# bc01e679-a264-4cad-8f67-3d4319f7e2a4     11.4.1       4.0.4             goal
# 74b0187e-59c0-496f-8f39-467e3ad10c46     11.4.1       4.0.4             goal
# 5f67d39a-c000-42fb-a159-4cb3faa67706     11.4.1       4.0.4             goal
# 49b4c9aa-ef99-490b-af43-9d8b67d6c53d     11.4.1       4.0.4       background
# ad473b1e-d89b-46bd-bc0d-558400af49dc     11.4.1       4.0.4       foreground
# 3532138c-1705-43ce-81ea-3fc03ddc399f     11.4.1       4.0.4             goal
# 4005da70-b157-47d7-a79d-0cf65e087053     11.4.1       4.0.4             goal
# 07357100-f49c-47bc-a24e-8b6914a8062c     11.4.1       4.0.4       background
# f4f35e0a-a754-402e-a5a1-3a993886ec86     11.4.1       4.0.4           launch
# 6c4a0440-1315-486b-97cb-34f08a8c2190     11.4.1       4.0.4             goal
# 23024710-8434-4a09-bfa2-b054ce466dbe     11.4.1       4.0.4             goal
# 9b163b94-e673-4814-8903-ef4349681d2f     11.4.1       4.0.4             goal
# d8cf577b-b4c1-41ad-bf93-868b9ee8747a     11.4.1       4.0.4       background
# 7420083d-aa04-4362-8cc9-4c046ab65f60     11.4.1       4.0.4       foreground
# 273a8e5c-02b2-4cb6-b3f3-dd0ca7414bf4     11.4.1       4.0.4             goal
# a297b338-68b3-4c3e-8ba0-3bda8abfc80f     11.4.1       4.0.4             goal
# e3da5c9c-384e-4a17-9788-120072e33882     11.4.1       4.0.4       background
# 69cb8265-8e51-4aa0-b36b-bc7001ff2014     11.4.1       4.0.4       foreground
# 2eb487b2-f652-4832-a61e-e52ec4a40591     11.4.1       4.0.4             goal
# 43ee7fde-7971-4ea3-81fa-1f105cd407e5     11.4.1       4.0.4       background
# 2e819b85-2245-4b14-8a18-ed53b5dcaee9     11.4.1       4.0.4  launchInSession
# 0cea9322-6aec-4c34-99be-791011964033     11.4.1       4.0.4             goal
# a1662cf5-00c8-432c-a3bf-8f80d4963634     11.4.1       4.0.4             goal
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684     11.4.1       4.0.4       background
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e     11.4.1       4.0.4       foreground
# 275cd800-db28-4a7c-8e20-3f9a844bba94     11.4.1       4.0.4       background
# d8a6eab0-af9b-400d-91e0-0722d952501c     11.4.1       4.0.4           launch
# 4e395080-da2a-413b-8258-2783901dc3b1     11.4.1       4.0.4             goal
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8     11.4.1       4.0.4             goal
# de0ff352-c35f-4295-8e0d-87b4457fd635     11.4.1       4.0.4             goal
# 91657360-953c-4700-8404-1d42e83c2820     11.4.1       4.0.4       background
# a99d3474-4faa-4e49-b523-3b3a6da58222     11.4.1       4.0.4  launchInSession
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c     11.4.1       4.0.4             goal
# f259eacc-4026-454e-9ca0-2ca9bc8785c3     11.4.1       4.0.4             goal
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6f     11.4.1       4.0.4       background
# 1b4ce2f7-38d7-485e-a361-90f249882303     11.4.1       4.0.4           launch
# 38e4ba06-b4b1-402d-b88a-815e26954a04     11.4.1       4.0.4             goal
# 6cabd6aa-8930-4429-b468-86435f107547     11.4.1       4.0.4             goal
# 49fa3ad9-5c22-4961-be53-f8e31f22ecc2     11.4.1       4.0.4             goal
# 364838ef-0295-4e4c-9111-153809a52f00     11.4.1       4.0.4             goal
# ea54d17e-cfbd-402e-8421-87c0e3588cd1     11.4.1       4.0.4           launch
# 6560eb93-d3f5-4756-ad51-85938d63d405     11.4.1       4.0.4             goal
# 4211c750-d25c-4684-9149-792ebb684351     11.4.1       4.0.4             goal
#
#                                          view_category            view_id  \
# row_uuid
# 61a0dcd5-b356-4ff8-b023-0c2a338c347b               NaN                NaN
# ccad2e4a-6c28-4d67-abfb-4b52bc8ceabc         home.view               home
# a1c02411-87e8-46dd-82b7-969b121d8a66         menu.view               menu
# f9018e0f-0814-4be1-b376-1eb6693baf79               NaN                NaN
# 8225cc30-a668-4050-93e7-57a55a215edb               NaN                NaN
# 894f6cb5-3d63-440c-b694-4f597abd4950          category      category_list
# 6b352370-0026-42ab-8918-db3e28b15873         home.view               home
# 22728744-516b-478f-834f-d5668b77bb1c       search.view             search
# bd00f8ec-e455-45e3-abe9-05a0bb7dea38            search         search_gig
# 1752e884-f1e6-4b00-94c3-b0cc56d39163               gig         gig_detail
# 663de17f-1b04-406f-b530-8143a4e7026a               gig         gig_detail
# e3d79fd8-8fb6-4a24-81ae-1be130d6ff28               gig  gig_detail_option
# a448f8e5-4ad7-4ad8-9d02-30bc3f574927             order    order_addOption
# dc41aae5-6a3b-4e60-a2d2-4725a7b1a42f  mobileAuth.click         mobileAuth
# 32a27ed6-0ba9-4488-9613-79a96bc7ed43             order    order_addOption
# bb13d046-cb4e-4c4f-a709-d9e0784e6fdf               NaN                NaN
# 13e69f74-25d1-4ed0-a562-a30a734eac02               NaN                NaN
# bc01e679-a264-4cad-8f67-3d4319f7e2a4  mobileAuth.click         mobileAuth
# 74b0187e-59c0-496f-8f39-467e3ad10c46             order    order_addOption
# 5f67d39a-c000-42fb-a159-4cb3faa67706             order      order_payment
# 49b4c9aa-ef99-490b-af43-9d8b67d6c53d               NaN                NaN
# ad473b1e-d89b-46bd-bc0d-558400af49dc               NaN                NaN
# 3532138c-1705-43ce-81ea-3fc03ddc399f    thankyou.click           thankyou
# 4005da70-b157-47d7-a79d-0cf65e087053             buyer  buyer_order_track
# 07357100-f49c-47bc-a24e-8b6914a8062c               NaN                NaN
# f4f35e0a-a754-402e-a5a1-3a993886ec86               NaN                NaN
# 6c4a0440-1315-486b-97cb-34f08a8c2190         home.view               home
# 23024710-8434-4a09-bfa2-b054ce466dbe             buyer  buyer_order_track
# 9b163b94-e673-4814-8903-ef4349681d2f             buyer  buyer_order_track
# d8cf577b-b4c1-41ad-bf93-868b9ee8747a               NaN                NaN
# 7420083d-aa04-4362-8cc9-4c046ab65f60               NaN                NaN
# 273a8e5c-02b2-4cb6-b3f3-dd0ca7414bf4         home.view               home
# a297b338-68b3-4c3e-8ba0-3bda8abfc80f             buyer  buyer_order_track
# e3da5c9c-384e-4a17-9788-120072e33882               NaN                NaN
# 69cb8265-8e51-4aa0-b36b-bc7001ff2014               NaN                NaN
# 2eb487b2-f652-4832-a61e-e52ec4a40591         home.view               home
# 43ee7fde-7971-4ea3-81fa-1f105cd407e5               NaN                NaN
# 2e819b85-2245-4b14-8a18-ed53b5dcaee9               NaN                NaN
# 0cea9322-6aec-4c34-99be-791011964033         home.view               home
# a1662cf5-00c8-432c-a3bf-8f80d4963634             buyer  buyer_order_track
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684               NaN                NaN
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e               NaN                NaN
# 275cd800-db28-4a7c-8e20-3f9a844bba94               NaN                NaN
# d8a6eab0-af9b-400d-91e0-0722d952501c               NaN                NaN
# 4e395080-da2a-413b-8258-2783901dc3b1         menu.view               menu
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8         home.view               home
# de0ff352-c35f-4295-8e0d-87b4457fd635             buyer  buyer_order_track
# 91657360-953c-4700-8404-1d42e83c2820               NaN                NaN
# a99d3474-4faa-4e49-b523-3b3a6da58222               NaN                NaN
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c         home.view               home
# f259eacc-4026-454e-9ca0-2ca9bc8785c3          category       category_gig
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6f               NaN                NaN
# 1b4ce2f7-38d7-485e-a361-90f249882303               NaN                NaN
# 38e4ba06-b4b1-402d-b88a-815e26954a04         home.view               home
# 6cabd6aa-8930-4429-b468-86435f107547             buyer  buyer_order_track
# 49fa3ad9-5c22-4961-be53-f8e31f22ecc2         home.view               home
# 364838ef-0295-4e4c-9111-153809a52f00         home.view               home
# ea54d17e-cfbd-402e-8421-87c0e3588cd1               NaN                NaN
# 6560eb93-d3f5-4756-ad51-85938d63d405         home.view               home
# 4211c750-d25c-4684-9149-792ebb684351         menu.view               menu
#
#                                      view_action funnel_desc        view_desc  \
# row_uuid
# 61a0dcd5-b356-4ff8-b023-0c2a338c347b         NaN         NaN              NaN
# ccad2e4a-6c28-4d67-abfb-4b52bc8ceabc        view           홈            홈 (탭)
# ...
# 69cb8265-8e51-4aa0-b36b-bc7001ff2014           NaN       NaN       NaN
# 2eb487b2-f652-4832-a61e-e52ec4a40591           NaN       NaN       NaN
# 43ee7fde-7971-4ea3-81fa-1f105cd407e5           NaN       NaN       NaN
# 2e819b85-2245-4b14-8a18-ed53b5dcaee9           NaN       NaN       NaN
# 0cea9322-6aec-4c34-99be-791011964033           NaN       NaN       NaN
# a1662cf5-00c8-432c-a3bf-8f80d4963634           NaN       NaN       NaN
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684           NaN       NaN       NaN
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e           NaN       NaN       NaN
# 275cd800-db28-4a7c-8e20-3f9a844bba94           NaN       NaN       NaN
# d8a6eab0-af9b-400d-91e0-0722d952501c           NaN       NaN       NaN
# 4e395080-da2a-413b-8258-2783901dc3b1           NaN       NaN       NaN
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8           NaN       NaN       NaN
# de0ff352-c35f-4295-8e0d-87b4457fd635           NaN       NaN       NaN
# 91657360-953c-4700-8404-1d42e83c2820           NaN       NaN       NaN
# a99d3474-4faa-4e49-b523-3b3a6da58222           NaN       NaN       NaN
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c           NaN       NaN       NaN
# f259eacc-4026-454e-9ca0-2ca9bc8785c3           디자인       디자인       NaN
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6f           NaN       NaN       NaN
# 1b4ce2f7-38d7-485e-a361-90f249882303           NaN       NaN       NaN
# 38e4ba06-b4b1-402d-b88a-815e26954a04           NaN       NaN       NaN
# 6cabd6aa-8930-4429-b468-86435f107547           NaN       NaN       NaN
# 49fa3ad9-5c22-4961-be53-f8e31f22ecc2           NaN       NaN       NaN
# 364838ef-0295-4e4c-9111-153809a52f00           NaN       NaN       NaN
# ea54d17e-cfbd-402e-8421-87c0e3588cd1           NaN       NaN       NaN
# 6560eb93-d3f5-4756-ad51-85938d63d405           NaN       NaN       NaN
# 4211c750-d25c-4684-9149-792ebb684351           NaN       NaN       NaN
#
#                                      category3       channel params_campaign  \
# row_uuid
# 61a0dcd5-b356-4ff8-b023-0c2a338c347b       NaN  unattributed             NaN
# ccad2e4a-6c28-4d67-abfb-4b52bc8ceabc       NaN  unattributed             NaN
# a1c02411-87e8-46dd-82b7-969b121d8a66       NaN  unattributed             NaN
# f9018e0f-0814-4be1-b376-1eb6693baf79       NaN           NaN             NaN
# 8225cc30-a668-4050-93e7-57a55a215edb       NaN           NaN             NaN
# 894f6cb5-3d63-440c-b694-4f597abd4950       NaN  unattributed             NaN
# 6b352370-0026-42ab-8918-db3e28b15873       NaN  unattributed             NaN
# 22728744-516b-478f-834f-d5668b77bb1c       NaN  unattributed             NaN
# bd00f8ec-e455-45e3-abe9-05a0bb7dea38       NaN  unattributed             NaN
# 1752e884-f1e6-4b00-94c3-b0cc56d39163   구독자·팔로워  unattributed             NaN
# 663de17f-1b04-406f-b530-8143a4e7026a   구독자·팔로워  unattributed             NaN
# e3d79fd8-8fb6-4a24-81ae-1be130d6ff28   구독자·팔로워  unattributed             NaN
# a448f8e5-4ad7-4ad8-9d02-30bc3f574927   구독자·팔로워  unattributed             NaN
# dc41aae5-6a3b-4e60-a2d2-4725a7b1a42f       NaN  unattributed             NaN
# 32a27ed6-0ba9-4488-9613-79a96bc7ed43       NaN  unattributed             NaN
# bb13d046-cb4e-4c4f-a709-d9e0784e6fdf       NaN           NaN             NaN
# 13e69f74-25d1-4ed0-a562-a30a734eac02       NaN           NaN             NaN
# bc01e679-a264-4cad-8f67-3d4319f7e2a4       NaN  unattributed             NaN
# 74b0187e-59c0-496f-8f39-467e3ad10c46       NaN  unattributed             NaN
# 5f67d39a-c000-42fb-a159-4cb3faa67706       NaN  unattributed             NaN
# 49b4c9aa-ef99-490b-af43-9d8b67d6c53d       NaN           NaN             NaN
# ad473b1e-d89b-46bd-bc0d-558400af49dc       NaN           NaN             NaN
# 3532138c-1705-43ce-81ea-3fc03ddc399f       NaN  unattributed             NaN
# 4005da70-b157-47d7-a79d-0cf65e087053       NaN  unattributed             NaN
# 07357100-f49c-47bc-a24e-8b6914a8062c       NaN           NaN             NaN
# f4f35e0a-a754-402e-a5a1-3a993886ec86       NaN  unattributed             NaN
# 6c4a0440-1315-486b-97cb-34f08a8c2190       NaN  unattributed             NaN
# 23024710-8434-4a09-bfa2-b054ce466dbe       NaN  unattributed             NaN
# 9b163b94-e673-4814-8903-ef4349681d2f       NaN  unattributed             NaN
# d8cf577b-b4c1-41ad-bf93-868b9ee8747a       NaN           NaN             NaN
# 7420083d-aa04-4362-8cc9-4c046ab65f60       NaN           NaN             NaN
# 273a8e5c-02b2-4cb6-b3f3-dd0ca7414bf4       NaN  unattributed             NaN
# a297b338-68b3-4c3e-8ba0-3bda8abfc80f       NaN  unattributed             NaN
# e3da5c9c-384e-4a17-9788-120072e33882       NaN           NaN             NaN
# 69cb8265-8e51-4aa0-b36b-bc7001ff2014       NaN           NaN             NaN
# 2eb487b2-f652-4832-a61e-e52ec4a40591       NaN  unattributed             NaN
# 43ee7fde-7971-4ea3-81fa-1f105cd407e5       NaN           NaN             NaN
# 2e819b85-2245-4b14-8a18-ed53b5dcaee9       NaN           NaN             NaN
# 0cea9322-6aec-4c34-99be-791011964033       NaN  unattributed             NaN
# a1662cf5-00c8-432c-a3bf-8f80d4963634       NaN  unattributed             NaN
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684       NaN           NaN             NaN
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e       NaN           NaN             NaN
# 275cd800-db28-4a7c-8e20-3f9a844bba94       NaN           NaN             NaN
# d8a6eab0-af9b-400d-91e0-0722d952501c       NaN  unattributed             NaN
# 4e395080-da2a-413b-8258-2783901dc3b1       NaN  unattributed             NaN
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8       NaN  unattributed             NaN
# de0ff352-c35f-4295-8e0d-87b4457fd635       NaN  unattributed             NaN
# 91657360-953c-4700-8404-1d42e83c2820       NaN           NaN             NaN
# a99d3474-4faa-4e49-b523-3b3a6da58222       NaN           NaN             NaN
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c       NaN  unattributed             NaN
# f259eacc-4026-454e-9ca0-2ca9bc8785c3       NaN  unattributed             NaN
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6f       NaN           NaN             NaN
# 1b4ce2f7-38d7-485e-a361-90f249882303       NaN  unattributed             NaN
# 38e4ba06-b4b1-402d-b88a-815e26954a04       NaN  unattributed             NaN
# 6cabd6aa-8930-4429-b468-86435f107547       NaN  unattributed             NaN
# 49fa3ad9-5c22-4961-be53-f8e31f22ecc2       NaN  unattributed             NaN
# 364838ef-0295-4e4c-9111-153809a52f00       NaN  unattributed             NaN
# ea54d17e-cfbd-402e-8421-87c0e3588cd1       NaN  unattributed             NaN
# 6560eb93-d3f5-4756-ad51-85938d63d405       NaN  unattributed             NaN
# 4211c750-d25c-4684-9149-792ebb684351       NaN  unattributed             NaN
#
#                                      params_medium params_term  \
# row_uuid
# 61a0dcd5-b356-4ff8-b023-0c2a338c347b           NaN         NaN
# ccad2e4a-6c28-4d67-abfb-4b52bc8ceabc           NaN         NaN
# a1c02411-87e8-46dd-82b7-969b121d8a66           NaN         NaN
# f9018e0f-0814-4be1-b376-1eb6693baf79           NaN         NaN
# 8225cc30-a668-4050-93e7-57a55a215edb           NaN         NaN
# 894f6cb5-3d63-440c-b694-4f597abd4950           NaN         NaN
# 6b352370-0026-42ab-8918-db3e28b15873           NaN         NaN
# 22728744-516b-478f-834f-d5668b77bb1c           NaN         NaN
# bd00f8ec-e455-45e3-abe9-05a0bb7dea38           NaN         NaN
# 1752e884-f1e6-4b00-94c3-b0cc56d39163           NaN         NaN
# 663de17f-1b04-406f-b530-8143a4e7026a           NaN         NaN
# e3d79fd8-8fb6-4a24-81ae-1be130d6ff28           NaN         NaN
# a448f8e5-4ad7-4ad8-9d02-30bc3f574927           NaN         NaN
# dc41aae5-6a3b-4e60-a2d2-4725a7b1a42f           NaN         NaN
# 32a27ed6-0ba9-4488-9613-79a96bc7ed43           NaN         NaN
# bb13d046-cb4e-4c4f-a709-d9e0784e6fdf           NaN         NaN
# 13e69f74-25d1-4ed0-a562-a30a734eac02           NaN         NaN
# bc01e679-a264-4cad-8f67-3d4319f7e2a4           NaN         NaN
# 74b0187e-59c0-496f-8f39-467e3ad10c46           NaN         NaN
# 5f67d39a-c000-42fb-a159-4cb3faa67706           NaN         NaN
# 49b4c9aa-ef99-490b-af43-9d8b67d6c53d           NaN         NaN
# ad473b1e-d89b-46bd-bc0d-558400af49dc           NaN         NaN
# 3532138c-1705-43ce-81ea-3fc03ddc399f           NaN         NaN
# 4005da70-b157-47d7-a79d-0cf65e087053           NaN         NaN
# 07357100-f49c-47bc-a24e-8b6914a8062c           NaN         NaN
# f4f35e0a-a754-402e-a5a1-3a993886ec86           NaN         NaN
# 6c4a0440-1315-486b-97cb-34f08a8c2190           NaN         NaN
# 23024710-8434-4a09-bfa2-b054ce466dbe           NaN         NaN
# 9b163b94-e673-4814-8903-ef4349681d2f           NaN         NaN
# d8cf577b-b4c1-41ad-bf93-868b9ee8747a           NaN         NaN
# 7420083d-aa04-4362-8cc9-4c046ab65f60           NaN         NaN
# 273a8e5c-02b2-4cb6-b3f3-dd0ca7414bf4           NaN         NaN
# a297b338-68b3-4c3e-8ba0-3bda8abfc80f           NaN         NaN
# e3da5c9c-384e-4a17-9788-120072e33882           NaN         NaN
# 69cb8265-8e51-4aa0-b36b-bc7001ff2014           NaN         NaN
# 2eb487b2-f652-4832-a61e-e52ec4a40591           NaN         NaN
# 43ee7fde-7971-4ea3-81fa-1f105cd407e5           NaN         NaN
# 2e819b85-2245-4b14-8a18-ed53b5dcaee9           NaN         NaN
# 0cea9322-6aec-4c34-99be-791011964033           NaN         NaN
# a1662cf5-00c8-432c-a3bf-8f80d4963634           NaN         NaN
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684           NaN         NaN
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e           NaN         NaN
# 275cd800-db28-4a7c-8e20-3f9a844bba94           NaN         NaN
# d8a6eab0-af9b-400d-91e0-0722d952501c           NaN         NaN
# 4e395080-da2a-413b-8258-2783901dc3b1           NaN         NaN
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8           NaN         NaN
# de0ff352-c35f-4295-8e0d-87b4457fd635           NaN         NaN
# 91657360-953c-4700-8404-1d42e83c2820           NaN         NaN
# a99d3474-4faa-4e49-b523-3b3a6da58222           NaN         NaN
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c           NaN         NaN
# f259eacc-4026-454e-9ca0-2ca9bc8785c3           NaN         NaN
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6
# 0cea9322-6aec-4c34-99be-791011964033             False                  False
# a1662cf5-00c8-432c-a3bf-8f80d4963634             False                  False
# 34b95a69-72a1-4e97-b98b-8e9c95cfe684               NaN                    NaN
# 3af989c6-ea21-4ae5-983e-3e7fd642d72e               NaN                    NaN
# 275cd800-db28-4a7c-8e20-3f9a844bba94               NaN                    NaN
# d8a6eab0-af9b-400d-91e0-0722d952501c             False                  False
# 4e395080-da2a-413b-8258-2783901dc3b1             False                  False
# 721e0f1d-d690-436c-b32d-a2d92c9d8ac8             False                  False
# de0ff352-c35f-4295-8e0d-87b4457fd635             False                  False
# 91657360-953c-4700-8404-1d42e83c2820               NaN                    NaN
# a99d3474-4faa-4e49-b523-3b3a6da58222               NaN                    NaN
# 6bce0b78-b147-4b50-a2e4-4c58442cd98c             False                  False
# f259eacc-4026-454e-9ca0-2ca9bc8785c3              True                   True
# 0f1c4bbd-0e61-4c97-859f-e1f8812d9f6f               NaN                    NaN
# 1b4ce2f7-38d7-485e-a361-90f249882303             False                  False
# 38e4ba06-b4b1-402d-b88a-815e26954a04             False                  False
# 6cabd6aa-8930-4429-b468-86435f107547             False                  False
# 49fa3ad9-5c22-4961-be53-f8e31f22ecc2             False                  False
# 364838ef-0295-4e4c-9111-153809a52f00             False                  False
# ea54d17e-cfbd-402e-8421-87c0e3588cd1             False                  False
# 6560eb93-d3f5-4756-ad51-85938d63d405             False                  False
# 4211c750-d25c-4684-9149-792ebb684351             False                  False

# %%
# 로그에 '상품'퍼널 자체가 찍히지 않았고, '메시지'관련 퍼널을 통해 '결제'한 경우 '결제완료'에 'category'가 남지 않음(가장 많은 경우로 추측됨)
result[result.user_id=='6CB97750-169C-485F-B5FB-6BE00A0E0010'].head(60)
# Out:
#                                      app_package_name  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf    com.kmong.iOS
# 06e26784-4036-46ce-9529-9008f9d58f6f    com.kmong.iOS
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05    com.kmong.iOS
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc    com.kmong.iOS
# 55a77352-d2c7-42d4-b3dd-b129a18926b4    com.kmong.iOS
# 88bd3964-ad73-4d36-b7cc-3d40286950a1    com.kmong.iOS
# 8efe517c-bc28-43db-8bdf-00f9d648af38    com.kmong.iOS
# 9530798e-48a0-4fa0-be44-e34f025f6d01    com.kmong.iOS
# 4ca329c2-8b89-47c5-964a-aab76833a927    com.kmong.iOS
# 2afda543-9b52-4df4-98f2-cc4089fefba6    com.kmong.iOS
# 65608d2e-f963-4fdc-ad8a-fde478a545b3    com.kmong.iOS
# 5444dfd9-0587-475c-9dc1-a189b7139ab6    com.kmong.iOS
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b    com.kmong.iOS
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1    com.kmong.iOS
# 799a76f0-3e70-47ff-b188-edb966192251    com.kmong.iOS
# 0aa584f1-f10d-45de-942f-de9b39e32979    com.kmong.iOS
# 32f2434b-3d07-4413-81f7-b6a790f59fab    com.kmong.iOS
# f49313fa-97e2-46bb-bdc0-683a277cf40a    com.kmong.iOS
# 407209ad-6450-48dd-b670-f9efe3751a65    com.kmong.iOS
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc    com.kmong.iOS
# a53ae97f-a23b-449a-b135-c2b773460d2f    com.kmong.iOS
# d57d29f0-15b9-4d84-966f-a0d0f5f279f
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b               Apple      iPhone     iOS
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1               Apple      iPhone     iOS
# 799a76f0-3e70-47ff-b188-edb966192251               Apple      iPhone     iOS
# 0aa584f1-f10d-45de-942f-de9b39e32979               Apple      iPhone     iOS
# 32f2434b-3d07-4413-81f7-b6a790f59fab               Apple      iPhone     iOS
# f49313fa-97e2-46bb-bdc0-683a277cf40a               Apple      iPhone     iOS
# 407209ad-6450-48dd-b670-f9efe3751a65               Apple      iPhone     iOS
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc               Apple      iPhone     iOS
# a53ae97f-a23b-449a-b135-c2b773460d2f               Apple      iPhone     iOS
# d57d29f0-15b9-4d84-966f-a0d0f5f279f3               Apple      iPhone     iOS
# 45e4f69e-deff-4868-af8e-6fa98d581034               Apple      iPhone     iOS
# a353683c-0f14-4428-8cd3-82752eeeb276               Apple      iPhone     iOS
# befe2048-cdf2-4ccb-bd4e-4d1964199524               Apple      iPhone     iOS
# 82c8666c-3dc2-4006-9092-644a784ba629               Apple      iPhone     iOS
# 9d7fd713-5e69-484b-8d55-5d362fe75fa2               Apple      iPhone     iOS
# c66d1dfd-e75d-4d6e-a52e-ba7caf8c7154               Apple      iPhone     iOS
# 060cb918-9008-45aa-baa7-97ae3328bb3c               Apple      iPhone     iOS
# c73a8e66-49c4-4132-9f72-75e3787d2c41               Apple      iPhone     iOS
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b               Apple      iPhone     iOS
# 8c97106e-e573-4ebd-aa8a-25331600d8e5               Apple      iPhone     iOS
# 5be15f69-0ff0-4c74-822c-056bb910e664               Apple      iPhone     iOS
# 7c534a20-54a1-4af1-8c28-bb46364160e7               Apple      iPhone     iOS
# 787094d8-4c60-4491-a814-976d9f3a35ad               Apple      iPhone     iOS
# 8ebabb68-f039-49e8-9855-587ab37ae3c7               Apple      iPhone     iOS
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2               Apple      iPhone     iOS
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7               Apple      iPhone     iOS
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf               Apple      iPhone     iOS
# b2b064dc-0880-4ffd-af2e-66141380afae               Apple      iPhone     iOS
# 0b16e644-6663-4a15-ae21-a28d20bf682a               Apple      iPhone     iOS
# a40813c7-84f8-47d1-9613-76917a459319               Apple      iPhone     iOS
# 7ad84412-5609-4401-ba41-1299f1b448e0               Apple      iPhone     iOS
# a17194fc-c5ee-4706-aeb2-eca0c84138c2               Apple      iPhone     iOS
#
#                                      os_version app_version   event_category  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf     11.4.1       4.0.4           launch
# 06e26784-4036-46ce-9529-9008f9d58f6f     11.4.1       4.0.4             goal
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05     11.4.1       4.0.4             goal
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc     11.4.1       4.0.4             goal
# 55a77352-d2c7-42d4-b3dd-b129a18926b4     11.4.1       4.0.4             goal
# 88bd3964-ad73-4d36-b7cc-3d40286950a1     11.4.1       4.0.4       background
# 8efe517c-bc28-43db-8bdf-00f9d648af38     11.4.1       4.0.4       foreground
# 9530798e-48a0-4fa0-be44-e34f025f6d01     11.4.1       4.0.4       background
# 4ca329c2-8b89-47c5-964a-aab76833a927     11.4.1       4.0.4  launchInSession
# 2afda543-9b52-4df4-98f2-cc4089fefba6     11.4.1       4.0.4             goal
# 65608d2e-f963-4fdc-ad8a-fde478a545b3     11.4.1       4.0.4             goal
# 5444dfd9-0587-475c-9dc1-a189b7139ab6     11.4.1       4.0.4             goal
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b     11.4.1       4.0.4             goal
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1     11.4.1       4.0.4             goal
# 799a76f0-3e70-47ff-b188-edb966192251     11.4.1       4.0.4             goal
# 0aa584f1-f10d-45de-942f-de9b39e32979     11.4.1       4.0.4             goal
# 32f2434b-3d07-4413-81f7-b6a790f59fab     11.4.1       4.0.4       background
# f49313fa-97e2-46bb-bdc0-683a277cf40a     11.4.1       4.0.4           launch
# 407209ad-6450-48dd-b670-f9efe3751a65     11.4.1       4.0.4             goal
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc     11.4.1       4.0.4             goal
# a53ae97f-a23b-449a-b135-c2b773460d2f     11.4.1       4.0.4             goal
# d57d29f0-15b9-4d84-966f-a0d0f5f279f3     11.4.1       4.0.4       background
# 45e4f69e-deff-4868-af8e-6fa98d581034     11.4.1       4.0.4       foreground
# a353683c-0f14-4428-8cd3-82752eeeb276     11.4.1       4.0.4             goal
# befe2048-cdf2-4ccb-bd4e-4d1964199524     11.4.1       4.0.4             goal
# 82c8666c-3dc2-4006-9092-644a784ba629     11.4.1       4.0.4             goal
# 9d7fd713-5e69-484b-8d55-5d362fe75fa2     11.4.1       4.0.4             goal
# c66d1dfd-e75d-4d6e-a52e-ba7caf8c7154     11.4.1       4.0.4       background
# 060cb918-9008-45aa-baa7-97ae3328bb3c     11.4.1       4.0.4           launch
# c73a8e66-49c4-4132-9f72-75e3787d2c41     11.4.1       4.0.4             goal
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b     11.4.1       4.0.4       background
# 8c97106e-e573-4ebd-aa8a-25331600d8e5     11.4.1       4.0.4           launch
# 5be15f69-0ff0-4c74-822c-056bb910e664     11.4.1       4.0.4             goal
# 7c534a20-54a1-4af1-8c28-bb46364160e7     11.4.1       4.0.4             goal
# 787094d8-4c60-4491-a814-976d9f3a35ad     11.4.1       4.0.4             goal
# 8ebabb68-f039-49e8-9855-587ab37ae3c7     11.4.1       4.0.4             goal
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2     11.4.1       4.0.4             goal
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7     11.4.1       4.0.4       background
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf     11.4.1       4.0.4           launch
# b2b064dc-0880-4ffd-af2e-66141380afae     11.4.1       4.0.4             goal
# 0b16e644-6663-4a15-ae21-a28d20bf682a     11.4.1       4.0.4             goal
# a40813c7-84f8-47d1-9613-76917a459319     11.4.1       4.0.4       background
# 7ad84412-5609-4401-ba41-1299f1b448e0     11.4.1       4.0.4       foreground
# a17194fc-c5ee-4706-aeb2-eca0c84138c2     11.4.1       4.0.4       background
#
#                                        view_category            view_id  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf             NaN                NaN
# 06e26784-4036-46ce-9529-9008f9d58f6f       home.view               home
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05      inbox.view              inbox
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc       menu.view               menu
# 55a77352-d2c7-42d4-b3dd-b129a18926b4      inbox.view              inbox
# 88bd3964-ad73-4d36-b7cc-3d40286950a1             NaN                NaN
# 8efe517c-bc28-43db-8bdf-00f9d648af38             NaN                NaN
# 9530798e-48a0-4fa0-be44-e34f025f6d01             NaN                NaN
# 4ca329c2-8b89-47c5-964a-aab76833a927             NaN                NaN
# 2afda543-9b52-4df4-98f2-cc4089fefba6       home.view               home
# 65608d2e-f963-4fdc-ad8a-fde478a545b3           inbox       inbox_detail
# 5444dfd9-0587-475c-9dc1-a189b7139ab6      inbox.view              inbox
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b       home.view               home
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1        category      category_list
# 799a76f0-3e70-47ff-b188-edb966192251       menu.view               menu
# 0aa584f1-f10d-45de-942f-de9b39e32979       bookmarks      bookmarks_gig
# 32f2434b-3d07-4413-81f7-b6a790f59fab             NaN                NaN
# f49313fa-97e2-46bb-bdc0-683a277cf40a             NaN                NaN
# 407209ad-6450-48dd-b670-f9efe3751a65           inbox       inbox_detail
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc       home.view               home
# a53ae97f-a23b-449a-b135-c2b773460d2f           order    order_addOption
# d57d29f0-15b9-4d84-966f-a0d0f5f279f3             NaN                NaN
# 45e4f69e-deff-4868-af8e-6fa98d581034             NaN                NaN
# a353683c-0f14-4428-8cd3-82752eeeb276       menu.view               menu
# befe2048-cdf2-4ccb-bd4e-4d1964199524           buyer  buyer_order_track
# 82c8666c-3dc2-4006-9092-644a784ba629  thankyou.click           thankyou
# 9d7fd713-5e69-484b-8d55-5d362fe75fa2       menu.view               menu
# c66d1dfd-e75d-4d6e-a52e-ba7caf8c7154             NaN                NaN
# 060cb918-9008-45aa-baa7-97ae3328bb3c             NaN                NaN
# c73a8e66-49c4-4132-9f72-75e3787d2c41       home.view               home
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b             NaN                NaN
# 8c97106e-e573-4ebd-aa8a-25331600d8e5             NaN                NaN
# 5be15f69-0ff0-4c74-822c-056bb910e664       home.view               home
# 7c534a20-54a1-4af1-8c28-bb46364160e7      inbox.view              inbox
# 787094d8-4c60-4491-a814-976d9f3a35ad           inbox       inbox_detail
# 8ebabb68-f039-49e8-9855-587ab37ae3c7           buyer  buyer_order_track
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2           inbox       inbox_detail
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7             NaN                NaN
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf             NaN                NaN
# b2b064dc-0880-4ffd-af2e-66141380afae       home.view               home
# 0b16e644-6663-4a15-ae21-a28d20bf682a      inbox.view              inbox
# a40813c7-84f8-47d1-9613-76917a459319             NaN                NaN
# 7ad84412-5609-4401-ba41-1299f1b448e0             NaN                NaN
# a17194fc-c5ee-4706-aeb2-eca0c84138c2             NaN                NaN
#
#                                      view_action funnel_desc        view_desc  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf         NaN         NaN              NaN
# 06e26784-4036-46ce-9529-9008f9d58f6f        view           홈            홈 (탭)
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05        view         메시지        메시지목록 (탭)
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc        view        거래관리         메뉴목록 (탭)
# 55a77352-d2c7-42d4-b3dd-b129a18926b4        view         메시지        메시지목록 (탭)
# 88bd3964-ad73-4d36-b7cc-3d40286950a1         NaN         NaN              NaN
# 8efe517c-bc28-43db-8bdf-00f9d648af38         NaN         NaN              NaN
# 9530798e-48a0-4fa0-be44-e34f025f6d01         NaN         NaN              NaN
# 4ca329c2-8b89-47c5-964a-aab76833a927         NaN         NaN              NaN
# 2afda543-9b52-4df4-98f2-cc4089fefba6        view           홈            홈 (탭)
# 65608d2e-f963-4fdc-ad8a-fde478a545b3        view         메시지         메시지목록-상세
# 5444dfd9-0587-475c-9dc1-a189b7139ab6        view         메시지        메시지목록 (탭)
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b        view           홈            홈 (탭)
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1        view        카테고리      카테고리 목록 (탭)
# 799a76f0-3e70-47ff-b188-edb966192251        view        거래관리         메뉴목록 (탭)
# 0aa584f1-f10d-45de-942f-de9b39e32979        view         찜하기     메뉴목록-찜목록-서비스
# 32f2434b-3d07-4413-81f7-b6a790f59fab         NaN         NaN              NaN
# f49313fa-97e2-46bb-bdc0-683a277cf40a         NaN         NaN              NaN
# 407209ad-6450-48dd-b670-f9efe3751a65        view         메시지         메시지목록-상세
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc        view           홈            홈 (탭)
# a53ae97f-a23b-449a-b135-c2b773460d2f       click          결제        상품상세-주문하기
# d57d29f0-15b9-4d84-966f-a0d0f5f279f3         NaN         NaN              NaN
# 45e4f69e-deff-4868-af8e-6fa98d581034         NaN         NaN              NaN
# a353683c-0f14-4428-8cd3-82752eeeb276        view        거래관리         메뉴목록 (탭)
# befe2048-cdf2-4ccb-bd4e-4d1964199524        view        거래관리  메뉴목록-구매관리-거래메시지
# 82c8666c-3dc2-4006-9092-644a784ba629       click        결제완료             결제완료
# 9d7fd713-5e69-484b-8d55-5d362fe75fa2        view        거래관리         메뉴목록 (탭)
# c66d1dfd-e75d-4d6e-a52e-ba7caf8c7154         NaN         NaN              NaN
# 060cb918-9008-45aa-baa7-97ae3328bb3c         NaN         NaN              NaN
# c73a8e66-49c4-4132-9f72-75e3787d2c41        view           홈            홈 (탭)
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b         NaN         NaN              NaN
# 8c97106e-e573-4ebd-aa8a-25331600d8e5         NaN         NaN              NaN
# 5be15f69-0ff0-4c74-822c-056bb910e664        view           홈            홈 (탭)
# 7c534a20-54a1-4af1-8c28-bb46364160e7        view         메시지        메시지목록 (탭)
# 787094d8-4c60-4491-a814-976d9f3a35ad        view         메시지         메시지목록-상세
# 8ebabb68-f039-49e8-9855-587ab37ae3c7        view        거래관리  메뉴목록-구매관리-거래메시지
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2        view         메시지         메시지목록-상세
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7         NaN         NaN              NaN
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf         NaN         NaN              NaN
# b2b064dc-0880-4ffd-af2e-66141380afae        view           홈            홈 (탭)
# 0b16e644-6663-4a15-ae21-a28d20bf682a        view         메시지        메시지목록 (탭)
# a40813c7-84f8-47d1-9613-76917a459319         NaN         NaN              NaN
# 7ad84412-5609-4401-ba41-1299f1b448e0         NaN         NaN              NaN
# a17194fc-c5ee-4706-aeb2-eca0c84138c2         NaN         NaN              NaN
#
#                                      category_name category1 category2  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf           NaN       NaN       NaN
# 06e26784-4036-46ce-9529-9008f9d58f6f           NaN       NaN       NaN
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05           NaN       NaN       NaN
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc           NaN       NaN       NaN
# 55a77352-d2c7-42d4-b3dd-b129a18926b4           NaN       NaN       NaN
# 88bd3964-ad73-4d36-b7cc-3d40286950a1           NaN       NaN       NaN
# 8efe517c-bc28-43db-8bdf-00f9d648af38           NaN       NaN       NaN
# 9530798e-48a0-4fa0-be44-e34f025f6d01           NaN       NaN       NaN
# 4ca329c2-8b89-47c5-964a-aab76833a927           NaN       NaN       NaN
# 2afda543-9b52-4df4-98f2-cc4089fefba6           NaN       NaN       NaN
# 65608d2e-f963-4fdc-ad8a-fde478a545b3           NaN       NaN       NaN
# 5444dfd9-0587-475c-9dc1-a189b7139ab6           NaN       NaN       NaN
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b           NaN       NaN       NaN
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1           NaN       NaN       NaN
# 799a76f0-3e70-47ff-b188-edb966192251           NaN       NaN       NaN
# 0aa584f1-f10d-45de-942f-de9b39e32979           NaN       NaN       NaN
# 32f2434b-3d07-4413-81f7-b6a790f59fab           NaN       NaN       NaN
# f49313fa-97e2-46bb-bdc0-683a277cf40a           NaN       NaN       NaN
# 407209ad-6450-48dd-b670-f9efe3751a65           NaN       NaN       NaN
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc           NaN       NaN       NaN
# a53ae97f-a23b-449a-b135-c2b773460d2f           NaN       NaN       NaN
# d57d29f0-15b9-4d84-966f-a0d0f5f279f3           NaN       NaN       NaN
# 45e4f69e-deff-4868-af8e-6fa98d581034           NaN       NaN       NaN
# a353683c-0f14-4428-8cd3-82752eeeb276           NaN       NaN       NaN
# befe2048-cdf2-4ccb-bd4e-4d1964199524           NaN       NaN       NaN
# 82c8666c-3dc2-4006-9092-644a784ba629           NaN       NaN       NaN
# 9d7fd713-5e69-484b-8d55-5d362fe75fa2           NaN       NaN       NaN
# c66d1dfd-e75d-4d6e-a52e-ba7caf8c7154           NaN       NaN       NaN
# 060cb918-9008-45aa-baa7-97ae3328bb3c           NaN       NaN       NaN
# c73a8e66-49c4-4132-9f72-75e3787d2c41           NaN       NaN       NaN
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b           NaN       NaN       NaN
# 8c97106e-e573-4ebd-aa8a-25331600d8e5           NaN       NaN       NaN
# 5be15f69-0ff0-4c74-822c-056bb910e664           NaN       NaN       NaN
# 7c534a20-54a1-4af1-8c28-bb46364160e7           NaN       NaN       NaN
# 787094d8-4c60-4491-a814-976d9f3a35ad           NaN       NaN       NaN
# 8ebabb68-f039-49e8-9855-587ab37ae3c7           NaN       NaN       NaN
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2           NaN       NaN       NaN
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7           NaN       NaN       NaN
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf           NaN       NaN       NaN
# b2b064dc-0880-4ffd-af2e-66141380afae           NaN       NaN       NaN
# 0b16e644-6663-4a15-ae21-a28d20bf682a           NaN       NaN       NaN
# a40813c7-84f8-47d1-9613-76917a459319           NaN       NaN       NaN
# 7ad84412-5609-4401-ba41-1299f1b448e0           NaN       NaN       NaN
# a17194fc-c5ee-4706-aeb2-eca0c84138c2           NaN       NaN       NaN
#
#                                      category3       channel params_campaign  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf       NaN  unattributed             NaN
# 06e26784-4036-46ce-9529-9008f9d58f6f       NaN  unattributed             NaN
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05       NaN  unattributed             NaN
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc       NaN  unattributed             NaN
# 55a77352-d2c7-42d4-b3dd-b129a18926b4       NaN  unattributed             NaN
# 88bd3964-ad73-4d36-b7cc-3d40286950a1       NaN           NaN             NaN
# 8efe517c-bc28-43db-8bdf-00f9d648af38       NaN           NaN             NaN
# 9530798e-48a0-4fa0-be44-e34f025f6d01       NaN           NaN             NaN
# 4ca329c2-8b89-47c5-964a-aab76833a927       NaN           NaN             NaN
# 2afda543-9b52-4df4-98f2-cc4089fefba6       NaN  unattributed             NaN
# 65608d2e-f963-4fdc-ad8a-fde478a545b3       NaN  unattributed             NaN
# 5444dfd9-0587-475c-9dc1-a189b7139ab6       NaN  unattributed             NaN
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b       NaN  unattributed             NaN
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1       NaN  unattributed             NaN
# 799a76f0-3e70-47ff-b188-edb966192251       NaN  unattributed             NaN
# 0aa584f1-f10d-45de-942f-de9b39e32979       NaN  unattributed             NaN
# 32f2434b-3d07-4413-81f7-b6a790f59fab       NaN           NaN             NaN
# f49313fa-97e2-46bb-bdc0-683a277cf40a       NaN  unattributed             NaN
# 407209ad-6450-48dd-b670-f9efe3751a65       NaN  unattributed             NaN
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc       NaN  unattributed             NaN
# a53ae97f-a23b-449a-b135-c2b773460d2f       NaN  unattributed             NaN
# d57d29f0-15b9-4d84-966f-a0d0f5f279f3       NaN           NaN             NaN
# 45e4f69e-deff-4868-af8e-6fa98d581034       NaN           NaN             NaN
# a353683c-0f14-4428-8cd3-82752eeeb276       NaN  unattributed             NaN
# befe2048-cdf2-4ccb-bd4e-4d1964199524       NaN  unattributed             NaN
# 82c8666c-3dc2-4006-9092-644a784ba629       NaN  unattributed             NaN
# 9d7fd713-5e69-484b-8d55-5d362fe75fa2       NaN  unattributed             NaN
# c66d1dfd-e75d-4d6e-a52e-ba7caf8c7154       NaN           NaN             NaN
# 060cb918-9008-45aa-baa7-97ae3328bb3c       NaN  unattributed             NaN
# c73a8e66-49c4-4132-9f72-75e3787d2c41       NaN  unattributed             NaN
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b       NaN           NaN             NaN
# 8c97106e-e573-4ebd-aa8a-25331600d8e5       NaN  unattributed             NaN
# 5be15f69-0ff0-4c74-822c-056bb910e664       NaN  unattributed             NaN
# 7c534a20-54a1-4af1-8c28-bb46364160e7       NaN  unattributed             NaN
# 787094d8-4c60-4491-a814-976d9f3a35ad       NaN  unattributed             NaN
# 8ebabb68-f039-49e8-9855-587ab37ae3c7       NaN  unattributed             NaN
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2       NaN  unattributed             NaN
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7       NaN           NaN             NaN
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf       NaN  unattributed             NaN
# b2b064dc-0880-4ffd-af2e-66141380afae       NaN  unattributed             NaN
# 0b16e644-6663-4a15-ae21-a28d20bf682a       NaN  unattributed             NaN
# a40813c7-84f8-47d1-9613-76917a459319       NaN           NaN             NaN
# 7ad84412-5609-4401-ba41-1299f1b448e0       NaN           NaN             NaN
# a17194fc-c5ee-4706-aeb2-eca0c84138c2       NaN           NaN             NaN
#
#                                      params_medium params_term  \
# row_uuid
# d7777e64-60de-4974-9742-9f48f493afcf           NaN         NaN
# 06e26784-4036-46ce-9529-9008f9d58f6f           NaN         NaN
# 00c39fbe-2778-4f0c-8a14-8d9ce1243d05           NaN         NaN
# 9a87ec77-5664-49ce-ae4c-088dc196b6bc           NaN         NaN
# 55a77352-d2c7-42d4-b3dd-b129a18926b4           NaN         NaN
# 88bd3964-ad73-4d36-b7cc-3d40286950a1           NaN         NaN
# 8efe517c-bc28-43db-8bdf-00f9d648af38           NaN         NaN
# 9530798e-48a0-4fa0-be44-e34f025f6d01           NaN         NaN
# 4ca329c2-8b89-47c5-964a-aab76833a927           NaN         NaN
# 2afda543-9b52-4df4-98f2-cc4089fefba6           NaN         NaN
# 65608d2e-f963-4fdc-ad8a-fde478a545b3           NaN         NaN
# 5444dfd9-0587-475c-9dc1-a189b7139ab6           NaN         NaN
# 8e8e3731-2881-4b16-9e24-a2b0fe1af08b           NaN         NaN
# 8c1ec1c6-fb4b-40da-90af-6ab32a6d55f1           NaN         NaN
# 799a76f0-3e70-47ff-b188-edb966192251           NaN         NaN
# 0aa584f1-f10d-45de-942f-de9b39e32979           NaN         NaN
# 32f2434b-3d07-4413-81f7-b6a790f59fab           NaN         NaN
# f49313fa-97e2-46bb-bdc0-683a277cf40a           NaN         NaN
# 407209ad-6450-48dd-b670-f9efe3751a65           NaN         NaN
# a4b6348a-4fa5-46bf-a738-f0363e7f2ebc           NaN         NaN
# a53ae97f-a23b-449a-b135-c2b773460d2f           NaN         NaN
# d57d29f0-15b9-4d84-966f-a0d0f5f279f
# c73a8e66-49c4-4132-9f72-75e3787d2c41             False                  False
# a3eac3c0-56de-4e63-82a1-511b10f9dc7b               NaN                    NaN
# 8c97106e-e573-4ebd-aa8a-25331600d8e5             False                  False
# 5be15f69-0ff0-4c74-822c-056bb910e664             False                  False
# 7c534a20-54a1-4af1-8c28-bb46364160e7             False                  False
# 787094d8-4c60-4491-a814-976d9f3a35ad             False                  False
# 8ebabb68-f039-49e8-9855-587ab37ae3c7             False                  False
# f3fd9eab-789f-461a-9ccd-e7bec1c66af2             False                  False
# 3f9ef3ef-69b2-4a9a-a38f-6524bda937f7               NaN                    NaN
# 89e0d47b-a0fc-47b3-bb26-6dbc1558eeaf             False                  False
# b2b064dc-0880-4ffd-af2e-66141380afae             False                  False
# 0b16e644-6663-4a15-ae21-a28d20bf682a             False                  False
# a40813c7-84f8-47d1-9613-76917a459319               NaN                    NaN
# 7ad84412-5609-4401-ba41-1299f1b448e0               NaN                    NaN
# a17194fc-c5ee-4706-aeb2-eca0c84138c2               NaN                    NaN

# %%
# 다 파악은 못 했지만 위의 3가지 예시를 볼 수 있음

# %% [markdown]
# ## 데이터에서 체크할 부분-3

# %%
result['channel'].value_counts()     #
# Out:
# unattributed    270834
# web              27639
# google           27235
# (not set)         2444
# naver             1224
# daum               966
# apple              697
# facebook           126
# Name: channel, dtype: int64

# %% [markdown]
# ## 함수 정리

# %%
# 퍼널 확인하기 위해 필요한 컬럼들만 추출해서 확인용 데이터프레임 만들기
process_check_list = ['user_id', 'event_datetime', 'event_category', 'view_id', 'view_desc', 'funnel_desc', 'category_name']
check = result[process_check_list]

# %%
# eventcategory와 view_desc를 합쳐 전체 프로세스를 확인할 수 있는 view_process 컬럼 만들기
check['view_process'] = check.view_desc
check.view_process.fillna(check.event_category, inplace=True)

# eventcategory와 funnel_desc를 합쳐 전체 프로세스를 확인할 수 있는 funnel_process 컬럼 만들기
check['funnel_process'] = check.funnel_desc
check.funnel_process.fillna(check.event_category, inplace=True)
# Out:
# <ipython-input-64-6cd62071e6d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check['view_process'] = check.view_desc
# C:\Users\hmkim\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# <ipython-input-64-6cd62071e6d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check['funnel_process'] = check.funnel_desc

# %%
check[['event_category', 'view_desc', 'funnel_desc', 'view_process', 'funnel_process']].head(10)
# Out:
#                                      event_category        view_desc  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817           goal            홈 (탭)
# e62dccef-dd70-4415-8a33-c8324ddaed38           goal             상품상세
# 14eb3197-db83-493a-b7be-83582960c40b           goal         메시지목록-상세
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b     foreground              NaN
# 236e9946-7801-4898-b609-06c8ab1139dc           goal  메뉴목록-구매관리-거래메시지
# db8ce65f-3707-4c1b-8361-51bcb9d4ecd9           goal            홈 (탭)
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e           goal             상품상세
# be1137d1-bf1d-4e42-8ad2-ae0d98bf3c03         launch              NaN
# d75ee65f-a82f-40a6-b123-93afd0a703fb     background              NaN
# e646eb49-3288-4379-8994-daaf6de1fec3           goal        메뉴목록-구매관리
#
#                                      funnel_desc     view_process  \
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817           홈            홈 (탭)
# e62dccef-dd70-4415-8a33-c8324ddaed38          상품             상품상세
# 14eb3197-db83-493a-b7be-83582960c40b         메시지         메시지목록-상세
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b         NaN       foreground
# 236e9946-7801-4898-b609-06c8ab1139dc        거래관리  메뉴목록-구매관리-거래메시지
# db8ce65f-3707-4c1b-8361-51bcb9d4ecd9           홈            홈 (탭)
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e          상품             상품상세
# be1137d1-bf1d-4e42-8ad2-ae0d98bf3c03         NaN           launch
# d75ee65f-a82f-40a6-b123-93afd0a703fb         NaN       background
# e646eb49-3288-4379-8994-daaf6de1fec3        거래관리        메뉴목록-구매관리
#
#                                      funnel_process
# row_uuid
# fd2a188c-bc9b-4702-9c47-b546b2614817              홈
# e62dccef-dd70-4415-8a33-c8324ddaed38             상품
# 14eb3197-db83-493a-b7be-83582960c40b            메시지
# f9bb91af-248b-44dc-9f5c-1c00b37ea97b     foreground
# 236e9946-7801-4898-b609-06c8ab1139dc           거래관리
# db8ce65f-3707-4c1b-8361-51bcb9d4ecd9              홈
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e             상품
# be1137d1-bf1d-4e42-8ad2-ae0d98bf3c03         launch
# d75ee65f-a82f-40a6-b123-93afd0a703fb     background
# e646eb49-3288-4379-8994-daaf6de1fec3           거래관리

# %%
# 특정 퍼널(funnel_desc) 직후에 있는 로그 모음 출력하는 함수
def funnel_next(keyword):
    id = list(check[check.funnel_process==keyword].user_id.unique())
    
    log = []
    
    # 아이디를 돌면서
    for i in id:
        # 개인별로 로그를 확인함
        process_list = list(check[check.user_id==i].funnel_process)
        
        for j in range(len(process_list)-1):
            if process_list[j] == keyword:
                log.append(process_list[j+1])
    
    return pd.Series(log).value_counts()


# 특정 퍼널(funnel_desc) 직전에 있는 로그 모음 출력하는 함수
def funnel_prev(keyword):
    id = list(check[check.funnel_process==keyword].user_id.unique())
    
    log = []
    
    # 아이디를 돌면서
    for i in id:
        # 개인별로 로그를 확인함
        process_list = list(check[check.user_id==i].funnel_process)
        
        for j in range(len(process_list)):
            if process_list[j] == keyword:
                log.append(process_list[j-1])
    
    return pd.Series(log).value_counts()

# %%
# 특정 퍼널(view_desc) 직후에 있는 로그 모음 출력하는 함수
def view_next(keyword):
    id = list(check[check.view_process==keyword].user_id.unique())
    
    log = []
    
    # 아이디를 돌면서
    for i in id:
        # 개인별로 로그를 확인함
        process_list = list(check[check.user_id==i].view_process)
        
        for j in range(len(process_list)-1):
            if process_list[j] == keyword:
                log.append(process_list[j+1])
    
    return pd.Series(log).value_counts()


# 특정 퍼널(view_desc) 직전에 있는 로그 모음 출력하는 함수
def view_prev(keyword):
    id = list(check[check.view_process==keyword].user_id.unique())
    
    log = []
    
    # 아이디를 돌면서
    for i in id:
        # 개인별로 로그를 확인함
        process_list = list(check[check.user_id==i].view_process)
        
        for j in range(len(process_list)):
            if process_list[j] == keyword:
                log.append(process_list[j-1])
    
    return pd.Series(log).value_counts()

# %%
view_prev('결제완료')
# Out:
# foreground          194
# 상품상세-주문하기           113
# 상품상세-주문하기-결제하기       61
# background           24
# 메뉴목록-구매관리-거래메시지      12
# 결제완료                  6
# 메뉴목록 (탭)              2
# 메뉴목록-크몽캐시-캐시충전하기      2
# 메시지목록-상세              2
# 상품상세                  1
# 메뉴목록-계정설정-프로필         1
# dtype: int64

# %% [markdown]
# ## 퍼널 정보 전환율, 이탈율

# %%
# eventcategory는 유저들의 값이 중복될 수도 있기에 확인해 봄.
result['user_id'].value_counts()
# Out:
# fd13d46d-dcbc-4c40-a5a9-913d7b0b9319    1590
# A14BAFD0-6064-46E6-8983-35A1C6A432E7    1218
# 1c84ee9d-c261-4925-8566-9757075e5a1b    1052
# 1906c617-57cb-47d9-9bb1-f2f1b7f76f84     967
# 8efd7a3c-b748-4e72-9b9e-204502c0dc4a     821
#                                         ...
# 373375f4-b413-4ab6-928d-a3d24962275a       1
# 356F569A-6576-4663-9898-2BD7831FCAE9       1
# 4ce416aa-b521-4d7a-9246-34da9e1d0496       1
# 5F660625-D78B-4685-BC6C-E68CA5CD10F1       1
# 2ECB460B-0C00-4490-BEDC-0C1D80B2C841       1
# Name: user_id, Length: 10081, dtype: int64

# %%
# 로그를 남긴 전체 고객의 수
entire_count=result['user_id'].nunique()

# %%
# 퍼널 정보 단계에 따른 고객의 수

def funnel_user_count(result,funnel_name):

    grouped = result[result['funnel_desc'] == funnel_name]['user_id'].unique()
    
    return len(grouped)

# %%
# '홈'이라는 퍼널이 로그에 한번이라도 남긴 고객의 수
home_count=funnel_user_count(result, '홈')

# %%
# '상품'이라는 퍼널이 로그에 한번이라도 남긴 고객의 수
product_count=funnel_user_count(result, '상품')

# %%
# '결제완료'라는 퍼널이 로그에 한번이라도 남긴 고객의 수
pay_count=funnel_user_count(result, '결제완료')

# %%
# '결제'를 두 번이상(재구매)한 고객의 수
repay_count=result.loc[result['funnel_desc']=='결제완료'].loc[result['is_first_goal_activity']==False]['user_id'].nunique()

# %%
# 퍼널 정보 전환율

print(f'Acquisition -> Activation1 전환율 : {home_count/entire_count * 100 : .2f} %')
print(f'Activation1 -> Activation2 전환율 : {product_count/home_count * 100 : .2f} %')
print(f'Activation2 -> Revenue 전환율 : {pay_count/product_count * 100 : .2f} %')
print(f'Revenue -> Retention 전환율 : {repay_count/pay_count * 100 : .2f} %')
# Out:
# Acquisition -> Activation1 전환율 :  87.75 %
# Activation1 -> Activation2 전환율 :  43.55 %
# Activation2 -> Revenue 전환율 :  9.16 %
# Revenue -> Retention 전환율 :  43.06 %

# %%
# 퍼널 정보 이탈율

print(f'Acquisition -> Activation1 이탈율 : {(1-(home_count/entire_count))* 100 : .2f} %')
print(f'Activation1 -> Activation2 이탈율 : {(1-(product_count/home_count))* 100 : .2f} %')
print(f'Activation2 -> Revenue 이탈율 : {(1-(pay_count/product_count))* 100 : .2f} %')
print(f'Revenue -> Retention 이탈율 : {(1-(repay_count/pay_count))* 100 : .2f} %')
# Out:
# Acquisition -> Activation1 이탈율 :  12.25 %
# Activation1 -> Activation2 이탈율 :  56.45 %
# Activation2 -> Revenue 이탈율 :  90.84 %
# Revenue -> Retention 이탈율 :  56.94 %

# %% [markdown]
# ## install에서 channel값 비율 구하기

# %%
practice=result[['user_id','event_datetime','event_category','view_id','channel']]

practice['process'] = practice.view_id
practice.process.fillna(practice.event_category, inplace=True)
# Out:
# <ipython-input-82-7ff06f753df3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   practice['process'] = practice.view_id
# C:\Users\hmkim\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
result_install=practice.loc[practice["process"]=="install"]

# %%
result_install["channel"].value_counts()
# Out:
# unattributed    615
# google          609
# web             242
# naver            28
# (not set)        26
# apple            14
# daum              9
# facebook          5
# Name: channel, dtype: int64

# %%
result_install["channel"].value_counts(normalize=True)
# Out:
# unattributed    0.397287
# google          0.393411
# web             0.156331
# naver           0.018088
# (not set)       0.016796
# apple           0.009044
# daum            0.005814
# facebook        0.003230
# Name: channel, dtype: float64

# %% [markdown]
# ## install > 홈 퍼널 분석

# %%
# home 나오면 이후의 값은 삭제
result_home = practice.groupby('user_id').apply(lambda x: x[:x['process'].eq('home').idxmax()] if 'home' in x['process'].values else x)

# %%
# process 컬럼의 install 직후값들의 비율

launch_indices = result_home[result_home.process == 'install'].index

next_values = result_home['process'].shift(-1).loc[launch_indices]
next_value_counts = next_values.value_counts()

next_value_ratios = next_value_counts / next_value_counts.sum()

next_value_ratios

# install -> launch : 1 %
# install -> launchInSession : 0.2 %
# install -> tutorial : 84 %
# install -> home : 4 %
# Out:
# tutorial           0.842556
# background         0.048748
# home               0.040843
# exit               0.038867
# launch             0.017128
# inbox_detail       0.003953
# launchInSession    0.002635
# install            0.002635
# foreground         0.001318
# profile            0.000659
# gig_detail         0.000659
# Name: process, dtype: float64

# %%
# process 컬럼의 launch직후값들의 비율

launch_indices = result_home[result_home.process == 'launch'].index

next_values = result_home['process'].shift(-1).loc[launch_indices]
next_value_counts = next_values.value_counts()

next_value_ratios = next_value_counts / next_value_counts.sum()

next_value_ratios

# launch -> tutorial : 4 %
# launch -> home : 62 %
# Out:
# home                         0.625437
# background                   0.128824
# inbox_detail                 0.063920
# tutorial                     0.042286
# exit                         0.032124
# buyer_order_track            0.030704
# launch                       0.021635
# inbox                        0.019996
# menu                         0.015188
# install                      0.003169
# foreground                   0.002622
# notification                 0.002185
# gig_detail                   0.001858
# category_gig                 0.001639
# search                       0.001530
# launchInSession              0.001530
# bookmarks_gig                0.001202
# profile                      0.000983
# search_gig                   0.000874
# seller_selling_history       0.000874
# inbox_detail_orderRequest    0.000437
# category_list                0.000219
# buyer_order_history          0.000219
# account_setting              0.000109
# seller_profits_history       0.000109
# kmongNotification            0.000109
# buyer_order_track_cancel     0.000109
# seller_mileage_history       0.000109
# Name: process, dtype: float64

# %%
# process 컬럼의 launchInSession직후값들의 비율

launch_indices = result_home[result_home.process == 'launchInSession'].index

next_values = result_home['process'].shift(-1).loc[launch_indices]
next_value_counts = next_values.value_counts()

next_value_ratios = next_value_counts / next_value_counts.sum()

next_value_ratios

# launchInSession -> tutorial : 16 %
# launchInSession -> home : 38 %
# Out:
# home                 0.380952
# background           0.292517
# tutorial             0.163265
# exit                 0.040816
# launch               0.034014
# inbox_detail         0.028571
# launchInSession      0.019048
# buyer_order_track    0.014966
# foreground           0.009524
# inbox                0.008163
# menu                 0.004082
# install              0.002721
# category_gig         0.001361
# Name: process, dtype: float64

# %%
# process 컬럼의 tutorial직후값들의 비율

launch_indices = result_home[result_home.process == 'tutorial'].index

next_values = result_home['process'].shift(-1).loc[launch_indices]
next_value_counts = next_values.value_counts()

next_value_ratios = next_value_counts / next_value_counts.sum()

next_value_ratios

# tutorial -> home : 56 %
# Out:
# home               0.564484
# tutorial           0.232624
# exit               0.068702
# background         0.046605
# login_sns          0.042587
# launch             0.015267
# foreground         0.015267
# install            0.009642
# launchInSession    0.003616
# inbox_detail       0.000804
# search             0.000402
# Name: process, dtype: float64

# %%
# process 컬럼의 deeplinkLaunch직후값들의 비율

launch_indices = result_home[result_home.process == 'deeplinkLaunch'].index

next_values = result_home['process'].shift(-1).loc[launch_indices]
next_value_counts = next_values.value_counts()

next_value_ratios = next_value_counts / next_value_counts.sum()

next_value_ratios

# deeplinkLaunch -> home : 9 % (1명)
# Out:
# gig_detail        0.454545
# login_sns         0.272727
# home              0.090909
# background        0.090909
# deeplinkLaunch    0.090909
# Name: process, dtype: float64

# %% [markdown]
# ## 홈 > 상품 퍼널 분석 - lv1(funnel_desc) 기준

# %%
# '홈' 또는 '상품'을 가지고 있는 user_id 리스트
# 이 경우, '홈'만 가지고 있거나, '상품'만 가지고 있는 id가 포함됨
id_list = list(result[result.funnel_desc.isin(['홈','상품'])].user_id.unique())
len(id_list)
# Out:
# 8861

# %%
# '홈'과 '상품'을 모두 가지고 있는 user_id를 저장할 리스트
home_product_id = []

for id in id_list:
    # 개인별 퍼널 로그 확인
    funnel_log = list(result[result.user_id == id].funnel_desc)
    
    # 개인의 로그 안에 '홈'과 '상품'이 있는 경우, 해당 아이디를 저장
    if ('홈' in funnel_log) & ('상품' in funnel_log):
        home_product_id.append(id)
        
print(len(home_product_id))
# Out:
# 3837

# %%
# 더 간단한 방법
# '홈'과 '상품'을 모두 보유하고 있는 아이디의 로그 모음
home_product_log = result[result.user_id.isin(home_product_id)]

# funnel_desc(lv1)와 view_desc(lv2)의 유저별 로그를 한 줄 리스트로 저장
lv1_tmp = home_product_log.groupby('user_id')['funnel_desc'].apply(list).reset_index(name='funnel_desc_list')
lv2_tmp = home_product_log.groupby('user_id')['view_desc'].apply(list).reset_index(name='view_desc_list')

# user_id 기준으로 merge
home_product_funnel = pd.merge(lv1_tmp, lv2_tmp, on='user_id')

# 데이터 손실 없이 잘 합쳐진 모습
print(len(home_product_id))
print(home_product_funnel.shape)
home_product_funnel
# Out:
# 3837
# (3837, 3)
#                                    user_id  \
# 0     001B9A43-5F55-4145-84B5-6495DF1EAF80
# 1     0030912D-F045-4685-BDFD-E19F06E1250E
# 2     0036380c-ab46-4fd1-8079-5e7d844d04e2
# 3     004ae4cb-4d37-4ab9-83de-9ffd0ed0c54d
# 4     004ae9e7-7ce5-4051-a883-1ca25e6541a7
# ...                                    ...
# 3832  ffb35dfe-422d-489a-8bc0-267310894f75
# 3833  ffcdd929-861d-46a1-9f6d-e529b80d7286
# 3834  ffd16a90-26a5-4187-9ef5-5aafb20695cb
# 3835  ffe1de22-316d-4d47-abf5-560d7755bf5f
# 3836  ffeac67d-b2a6-4cda-b80e-0230b5498d46
#
#                                        funnel_desc_list  \
# 0     [nan, 홈, 메시지, 거래관리, 거래관리, 거래관리, nan, 계정관리 - 판매...
# 1     [nan, 거래관리, nan, nan, 홈, 메시지, 상품, 메시지, nan, na...
# 2     [nan, 홈, 알림, 거래관리, 알림, 메시지, 메시지, 메시지, 메시지, 메시지...
# 3     [nan, 홈, 메시지, 거래관리, 거래관리, 거래관리, 거래관리, 거래관리, 메시...
# 4     [nan, 소개 및 안내, 홈, 검색, 검색, 검색, 검색, 검색, 검색, 상품, ...
# ...                                                 ...
# 3832  [nan, 홈, 메시지, nan, nan, 메시지, 메시지, 상품, 상품, 결제, ...
# 3833                          [nan, 홈, 검색, 검색, 상품, nan]
# 3834  [nan, 소개 및 안내, 홈, 홈, 검색, 검색, 검색, 상품, 검색, 검색, 상...
# 3835  [nan, 소개 및 안내, 홈, 거래관리, 거래관리, 거래관리, 홈, 검색, 검색,...
# 3836  [홈, nan, 메시지, 메시지, 상품, 메시지, 상품, 메시지, 메시지, 메시지,...
#
#                                          view_desc_list
# 0     [nan, 홈 (탭), 메시지목록 (탭), 메뉴목록 (탭), 메뉴목록-판매관리, 메...
# 1     [nan, 메뉴목록 (탭), nan, nan, 홈 (탭), 메시지목록-상세, 상품상...
# 2     [nan, 홈 (탭), 알림-알림, 메뉴목록-구매관리-거래메시지, 알림-알림, 메시...
# 3     [nan, 홈 (탭), 메시지목록 (탭), 메뉴목록 (탭), 메뉴목록-판매관리, 메...
# 4     [nan, 튜토리얼, 홈 (탭), 검색, 검색-상품목록, 검색, 검색-상품목록, 검...
# ...                                                 ...
# 3832  [nan, 홈 (탭), 메시지목록 (탭), nan, nan, 메시지목록 (탭), 메...
# 3833               [nan, 홈 (탭), 검색, 검색-상품목록, 상품상세, nan]
# 3834  [nan, 튜토리얼, 홈 (탭), 홈 (탭), 검색, 검색, 검색-상품목록, 상품상...
# 3835  [nan, 튜토리얼, 홈 (탭), 메뉴목록 (탭), 메뉴목록-구매관리, 메뉴목록 (...
# 3836  [홈 (탭), nan, 메시지목록 (탭), 메시지목록-상세, 상품상세, 메시지목록-...
#
# [3837 rows x 3 columns]

# %%
# '홈'에서 '상품'까지의 로그를 [[홈, 상품], [홈, 검색, 검색, 상품], ...] 형태의 2차원 배열로 저장하는 함수

# 예시 입력값: home_product_funnel, 0
# data는 반드시 함수 내 컬럼명('funnel_desc_list')과 데이터 타입, 내용이 일치해야 함
def make_2d_home_product_lv1(data, index):
    
    funnel_list = data['funnel_desc_list'][index]
    
    # while 문을 돌 때 사용할 변수
    # 이면서 [홈 ~ 상품]을 슬라이싱할 때 사용할 첫 번째 인덱스
    start_idx = 0
    
    # [홈 ~ 상품]을 저장할 배열
    between_funnel = []

    while start_idx < len(funnel_list):
        if funnel_list[start_idx] == '홈':

            # 홈 이후에 상품이 없으면 루프 종료
            if '상품' not in funnel_list[start_idx : ]:
                break

            # 원래 인덱스 값 + 홈 이후 처음으로 등장하는 '상품'의 인덱스 + '상품'까지 포함하기 위해 1 더하기
            end_idx = start_idx + funnel_list[start_idx:].index('상품') + 1
            # 홈 ~ 상품 까지 리스트 형태로 저장
            between_funnel.append(funnel_list[start_idx : end_idx])

            # 기준 인덱스를 '상품'으로 이동
            start_idx = end_idx

        start_idx += 1 # 증감식
        
    return between_funnel

# %%
# 2차원 배열을 돌면서 카테고리, 검색, 다이렉트의 로그 수를 세는 함수
def count_home_product_type(between_home_and_product):
    category = 0
    search = 0
    direct = 0

    for i in between_home_and_product:
        # 리스트의 길이가 2를 초과할 때,
        if len(i) >= 3:
            # 상품 직전 로그가 홈이면
            if i[-2] == '홈':
                direct += 1

                # i[1:-2]: 마지막 다이렉트 부분을 제외하고 슬라이싱
                # set()으로 중복 제거 후 다시 리스트로 변환
                log_list = list(set(i[1:-2]))

                # 다이렉트 제외 나머지 퍼널 카운트
                for j in log_list:
                    if j == '카테고리':
                        category += 1
                    elif j == '검색':
                        search += 1


            # 상품 직전 로그가 홈이 아니면
            else:
                # i[1:-1]: 슬라이싱으로 처음 값('홈')과 마지막 값('상품') 제외
                # set()으로 중복 제거 후 다시 리스트로 변환
                log_list = list(set(i[1:-1]))

                # 퍼널 카운트
                for j in log_list:
                    if j == '카테고리':
                        category += 1
                    elif j == '검색':
                        search += 1

        # 리스트의 길이가 2일 때 ('홈 - 상품'인 경우)
        else:
            direct += 1
    
    # 튜플 형태로 반환
    return category, search, direct

# %%
cut_home_product_log = []

for i in range(len(home_product_funnel)):
    log = make_2d_home_product_lv1(home_product_funnel, i)
    
    for j in log:
        cut_home_product_log.append(j)
        
# 각 로그 수를 저장할 변수 선언
category_count = 0
search_count = 0
direct_count = 0
        
category_count = count_home_product_type(cut_home_product_log)[0]
search_count = count_home_product_type(cut_home_product_log)[1]
direct_count = count_home_product_type(cut_home_product_log)[2]

# %%
log_sum = category_count + search_count + direct_count

print(f'카테고리: {category_count} 건')
print(f'검    색: {search_count} 건')
print(f'다이렉트: {direct_count} 건')
print(f'----\n합계: {log_sum} 건\n')

print(f'카테고리: {category_count / log_sum * 100 : .2f} %')
print(f'검    색: {search_count / log_sum * 100 : .2f} %')
print(f'다이렉트: {direct_count / log_sum * 100 : .2f} %')
# Out:
# 카테고리: 3818 건
# 검    색: 2193 건
# 다이렉트: 1511 건
# ----
# 합계: 7522 건
#
# 카테고리:  50.76 %
# 검    색:  29.15 %
# 다이렉트:  20.09 %

# %% [markdown]
# ## 홈 > 상품 퍼널 상세 분석 - lv2(view_desc) 기준

# %%
# 개인 로그 데이터를 인자로 받았을 때,
# 해당 로그에서 홈에서 상품까지의 로그를 [[홈, 상품], [홈, 검색, 검색, 상품], ...] 형태의 2차원 배열로 저장하는 함수

# 예시 입력값: home_product_funnel, 0
# data는 반드시 함수 내 컬럼명과 데이터 타입이 일치해야 함
def make_2d_home_product_lv2(data, index):
    lv1_list = data['funnel_desc_list'][index]
    lv2_list = data['view_desc_list'][index]
    # while 문을 돌 때 사용할 변수
    # 이면서 [홈 ~ 상품]을 슬라이싱할 때 사용할 첫 번째 인덱스
    start_idx = 0
    
    # [홈 ~ 상품]을 저장할 배열
    between_home_and_product = []

    while start_idx < len(lv1_list):
        if lv1_list[start_idx] == '홈':

            # 홈 이후에 상품이 없으면 루프 종료
            if '상품' not in lv1_list[start_idx : ]:
                break

            # 원래 인덱스 값 + 홈 이후 처음으로 등장하는 '상품'의 인덱스 + '상품'까지 포함하기 위해 1 더하기
            end_idx = start_idx + lv1_list[start_idx:].index('상품') + 1
            # 홈 ~ 상품 까지 리스트 형태로 저장
            between_home_and_product.append(lv2_list[start_idx : end_idx])

            # 기준 인덱스를 '상품'으로 이동
            start_idx = end_idx

        start_idx += 1 # 증감식
        
    return between_home_and_product

# %%
# 2차원 배열을 돌면서 카테고리, 검색, 다이렉트의 로그 수를 세는 함수
def count_home_product_type_lv2(between_home_and_product):
    
    category_list, category_gig, search, search_gig, search_seller = 0, 0, 0, 0, 0
    
    for i in between_home_and_product:
        
        # 중복 제거
        log_list = list(set(i))
        
        for funnel in log_list:
            if funnel == '카테고리 목록 (탭)':
                category_list += 1
            elif funnel == '카테고리-상품목록':
                category_gig += 1
            elif funnel == '검색':
                search += 1
            elif funnel == '검색-상품목록':
                search_gig += 1
            elif funnel == '검색-전문가':
                search_seller += 1
    
    # 튜플 형태로 반환
    return category_list, category_gig, search, search_gig, search_seller

# %%
cut_lv2_home_product_log = []

for i in range(len(home_product_funnel)):
    log = make_2d_home_product_lv2(home_product_funnel, i)
    
    for j in log:
        cut_lv2_home_product_log.append(j)
        
cut_lv2_home_product_log
# Out:
# [['홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   nan,
#   '메뉴목록-나의서비스',
#   nan,
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메뉴목록 (탭)', '메뉴목록-찜목록-서비스', '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '메시지목록-상세', '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-마일리지 내역',
#   '메뉴목록-마일리지 내역',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '검색',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '상품상세'],
#  ['홈 (탭)', nan, nan, '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', nan, nan, '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '검색-상품목록', '검색-상품목록', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', nan, '카테고리-상품목록', nan, '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '상품상세'],
#  ['홈 (탭)', '메시지목록-상세', '메뉴목록-계정설정-프로필', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '간편로그인-이메일로그인-아이디/비밀번호-찾기',
#   '간편로그인-이메일로그인',
#   '간편로그인-이메일로그인-아이디/비밀번호-찾기',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-전문가', '검색-상품목록', '검색', '홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)', '메뉴목록 (탭)', '메뉴목록-나의서비스', '상품상세'],
#  ['홈 (탭)', '메뉴목록 (탭)', '메뉴목록-나의서비스', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지-취소/문제해결',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메뉴목록 (탭)', '메뉴목록-구매관리', '메뉴목록-구매관리-거래메시지', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '검색',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색',
#   '검색',
#   '검색',
#   '검색',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-마일리지 내역',
#   '메뉴목록 (탭)',
#   '검색',
#   '메뉴목록 (탭)',
#   '검색',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '메뉴목록-계정설정-프로필', '상품상세'],
#  ['홈 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정-프로필',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-비밀번호 변경',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-마일리지 내역',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   nan,
#   nan,
#   nan,
#   '메뉴목록-판매관리',
#   nan,
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-나의서비스',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-찜목록-서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   nan,
#   nan,
#   '메뉴목록-찜목록-포트폴리오',
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록-서비스등록',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메뉴목록 (탭)', '홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   'NPS',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', nan, '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '검색',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '검색',
#   '검색-상품목록',
#   nan,
#   nan,
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   nan,
#   nan,
#   nan,
#   nan,
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   'NPS',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', nan, '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '검색', '검색-상품목록', '검색', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, nan, '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)', '메뉴목록 (탭)', '메뉴목록-구매관리', '메뉴목록-구매관리-거래메시지', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '홈 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', nan, '메뉴목록-계정설정-프로필', nan, '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '메뉴목록-계정설정-프로필', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '카테고리 목록 (탭)', '홈 (탭)', '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '알림-알림',
#   '홈 (탭)',
#   nan,
#   nan,
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '전문가프로필'],
#  ['홈 (탭)', '알림-알림', '홈 (탭)', '검색', '검색-상품목록', '검색', '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '알림-알림',
#   '알림-알림',
#   '알림-알림',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '간편로그인',
#   '메뉴목록-찜목록-서비스',
#   nan,
#   '간편로그인',
#   nan,
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '전문가프로필'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '홈 (탭)', '카테고리-상품목록', '홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '검색',
#   '검색-상품목록',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   nan,
#   nan,
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필'],
#  ['홈 (탭)', '메뉴목록 (탭)', '메시지목록 (탭)', '메뉴목록-찜목록-서비스', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', nan, nan, '카테고리-상품목록', nan, '상품상세'],
#  ['홈 (탭)', '메뉴목록 (탭)', '메뉴목록-찜목록-서비스', '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-친구초대',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   '카테고리-상품목록',
#   nan,
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정-프로필',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록-계정설정-인증정보',
#   '메뉴목록-서비스등록',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정-프로필',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-비밀번호 변경',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-비밀번호 변경',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-알림설정',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', nan, nan, '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, '홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '전문가프로필'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '알림-알림', '간편로그인', '간편로그인', '알림-알림', '홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, nan, '홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록-크몽안내',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-크몽안내',
#   '알림-알림',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   nan,
#   '카테고리-상품목록',
#   '알림-알림',
#   '메뉴목록-크몽안내',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '검색', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '알림-알림', '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색', '검색', nan, nan, '홈 (탭)', '검색', '검색-상품목록', '검색', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색-상품목록', '검색', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색-상품목록', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '검색',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   nan,
#   '간편로그인',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '검색-상품목록', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   'NPS',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '알림-알림',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '알림-알림-상세',
#   '알림-알림',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '알림-알림',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '간편로그인',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '간편로그인',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '알림-알림',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록-찜목록-포트폴리오',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '검색',
#   '검색',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '메뉴목록 (탭)',
#   '메뉴목록-친구초대',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽이용방법',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-크몽안내',
#   '알림-알림',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '알림-알림',
#   '메뉴목록-크몽안내',
#   '메뉴목록-크몽안내',
#   '메뉴목록-크몽안내-상세',
#   '메뉴목록-크몽안내',
#   '메뉴목록-크몽안내-상세',
#   '메뉴목록-크몽안내',
#   '메뉴목록-크몽안내-상세',
#   '메뉴목록-크몽안내',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '홈 (탭)', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색-상품목록', '검색-상품목록', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '카테고리-상품목록',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '메뉴목록-찜목록-서비스', '홈 (탭)', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메뉴목록-계정설정-프로필',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필'],
#  ['홈 (탭)', nan, nan, '홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '전문가프로필'],
#  ['홈 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '카테고리-상품목록', nan, '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '알림-알림',
#   '홈 (탭)',
#   '알림-알림',
#   '알림-알림',
#   '알림-알림',
#   '알림-알림',
#   '알림-알림',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '전문가프로필'],
#  ['홈 (탭)', '홈 (탭)', '카테고리 목록 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '상품상세'],
#  ['홈 (탭)', nan, nan, nan, '홈 (탭)', '메뉴목록-찜목록-서비스', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', nan, '홈 (탭)', nan, nan, '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-알림설정',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-인증정보',
#   '휴대폰인증',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽이용방법',
#   '메뉴목록-계정설정-인증정보',
#   '메뉴목록-크몽이용방법',
#   '메뉴목록 (탭)',
#   '메뉴목록-계정설정',
#   '메뉴목록-계정설정-인증정보',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록-쿠폰내역',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
# ...
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '알림-알림',
#   '알림-알림',
#   '알림-알림',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-수익관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '홈 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '메뉴목록-찜목록-서비스', '상품상세'],
#  ['홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록-찜목록-서비스',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-마일리지 내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-마일리지 내역',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '검색',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '알림-알림',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지-취소/문제해결',
#   '메뉴목록-구매관리-거래메시지-취소/문제해결-제출',
#   '메뉴목록-구매관리-거래메시지',
#   '알림-알림',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '메시지목록 (탭)', '메시지목록-상세', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   nan,
#   '간편로그인',
#   '간편로그인',
#   '간편로그인-이메일로그인',
#   '간편로그인-이메일로그인-아이디/비밀번호-찾기',
#   '간편로그인-이메일로그인',
#   '간편로그인-이메일로그인-아이디/비밀번호-찾기',
#   '간편로그인-이메일로그인',
#   nan,
#   nan,
#   '간편로그인-이메일로그인',
#   nan,
#   nan,
#   '간편로그인-이메일로그인',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '검색', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리 목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   '홈 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   nan,
#   nan,
#   '검색',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-쿠폰내역',
#   nan,
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-판매관리',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   nan,
#   '검색-상품목록',
#   nan,
#   '검색',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메시지목록-상세',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '상품상세'],
#  ['홈 (탭)', '검색', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   nan,
#   '메뉴목록-구매관리-거래메시지',
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   nan,
#   '홈 (탭)',
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', nan, nan, '카테고리-상품목록', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '카테고리-상품목록',
#   nan,
#   '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, '홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   nan,
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '검색',
#   '검색-상품목록',
#   '검색-상품목록',
#   '검색-상품목록',
#   '검색-상품목록',
#   '검색-상품목록',
#   '카테고리 목록 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   nan,
#   '상품상세'],
#  ['홈 (탭)', '카테고리 목록 (탭)', '홈 (탭)', '카테고리-상품목록', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '간편로그인',
#   nan,
#   '간편로그인',
#   nan,
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '메시지목록-상세', '전문가프로필'],
#  ['홈 (탭)',
#   nan,
#   '홈 (탭)',
#   '검색',
#   '메뉴목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색',
#   '검색-상품목록',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', nan, nan, '상품상세'],
#  ['홈 (탭)',
#   '검색',
#   '홈 (탭)',
#   '검색',
#   '홈 (탭)',
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '검색',
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', nan, nan, '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록-상세',
#   nan,
#   '메시지목록 (탭)',
#   nan,
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-찜목록-서비스',
#   '메뉴목록 (탭)',
#   '메뉴목록-나의서비스',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '상품상세'],
#  ['홈 (탭)', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', nan, nan, '상품상세'],
#  ['홈 (탭)', '메시지목록 (탭)', '홈 (탭)', '검색', '검색-상품목록', nan, '검색-상품목록', '상품상세'],
#  ['홈 (탭)', '검색', '검색-상품목록', '검색', '검색-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '검색',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '카테고리-상품목록',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '카테고리-상품목록',
#   '홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '홈 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '카테고리 목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   nan,
#   nan,
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-계정설정-프로필',
#   '상품상세'],
#  ['홈 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   nan,
#   nan,
#   '홈 (탭)',
#   '메시지목록 (탭)',
#   '홈 (탭)',
#   '검색',
#   '검색-상품목록',
#   '상품상세'],
#  ['홈 (탭)', '메뉴목록-크몽안내', '알림-알림', '카테고리 목록 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)', '카테고리-상품목록', '상품상세'],
#  ['홈 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   nan,
#   nan,
#   '메뉴목록-구매관리',
#   nan,
#   '홈 (탭)',
#   nan,
#   nan,
#   '카테고리-상품목록',
#   '상품상세'],
#  ...]

# %%
category_gig_count = count_home_product_type_lv2(cut_lv2_home_product_log)[1]

search_gig_count = count_home_product_type_lv2(cut_lv2_home_product_log)[3]
search_seller_count = count_home_product_type_lv2(cut_lv2_home_product_log)[4]
search_sum = search_gig_count + search_seller_count

# %%
# '카테고리' 퍼널은 '카테고리 목록(탭)'->'카테고리-상품목록' 순으로 실행
print(f'카테고리-상품목록: {category_gig_count} 건')
# Out:
# 카테고리-상품목록: 3393 건

# %%
# print(f'검색: {search_count} 건')
print(f'검색-상품목록: {search_gig_count} 건')
print(f'검색-전문가: {search_seller_count} 건')
print(f'----\n검색 합계: {search_sum} 건\n')

# print(f'검색: {search_count / search_sum * 100 : .2f} %')
print(f'검색-상품목록: {search_gig_count / search_sum * 100 : .2f} %')
print(f'검색-전문가: {search_seller_count / search_sum * 100 : .2f} %')
# Out:
# 검색-상품목록: 1903 건
# 검색-전문가: 35 건
# ----
# 검색 합계: 1938 건
#
# 검색-상품목록:  98.19 %
# 검색-전문가:  1.81 %

# %% [markdown]
# **직전에 있는 로그만 셌을 때**
#
# +) 사용안한 부분임!

# %%
# 연속된 두 개의 퍼널(funnel_desc)을 가지고 있는 아이디를 출력하는 함수
def consecutive_funnel_id(keyword1, keyword2):
    id = list(check[check.funnel_process==keyword1].user_id.unique())
    
    id_set = set()
    
    # 아이디를 돌면서
    for i in id:
        # 개인별로 로그를 확인함
        process_list = list(check[check.user_id==i].funnel_process)
        
        for j in range(len(process_list)-1):
            # 두 키워드가 연속해있으면
            if (process_list[j] == keyword1) & (process_list[j+1] == keyword2):
                # 해당 아이디를 id_set에 저장
                id_set.add(i)
    
    return id_set

# %%
# 카테고리: 카테고리에서 상품으로 이동한 아이디
category_to_product_id = consecutive_funnel_id('카테고리', '상품')

# %%
category_to_product = len(category_to_product_id)
category_to_product
# Out:
# 1656

# %%
# 검색: 검색에서 상품으로 이동한 아이디
search_to_product_id = consecutive_funnel_id('검색', '상품')

# %%
search_to_product = len(search_to_product_id)
search_to_product
# Out:
# 1259

# %%
# 다이렉트: 홈에서 바로 상품으로 이동한 아이디
home_to_product_id = consecutive_funnel_id('홈', '상품')

# %%
home_to_product = len(home_to_product_id)
home_to_product
# Out:
# 930

# %%
product_people_sum = category_to_product + search_to_product + home_to_product

print('비율 (인원 수 기준)\n')
print(f'카테고리: {category_to_product / product_people_sum * 100: .2f} %')
print(f'검    색: {search_to_product / product_people_sum * 100: .2f} %')
print(f'다이렉트: {home_to_product / product_people_sum * 100: .2f} %\n')
print(f'총  인원: {product_people_sum} 명')
# Out:
# 비율 (인원 수 기준)
#
# 카테고리:  43.07 %
# 검    색:  32.74 %
# 다이렉트:  24.19 %
#
# 총  인원: 3845 명

# %%
# keyword1 - keyrowd2가 연속되어 있는 로그 수를 출력하는 함수 (funnel_desc 기준)
def consecutive_funnel_count(keyword1, keyword2):
    id = list(check[check.funnel_process==keyword1].user_id.unique())
    
    Count = 0
    
    # 아이디를 돌면서
    for i in id:
        # 개인별로 로그를 확인함
        process_list = list(check[check.user_id==i].funnel_process)
        
        for j in range(len(process_list)-1):
            # 두 키워드가 연속해있으면
            if (process_list[j] == keyword1) & (process_list[j+1] == keyword2):
                # Count로 세어줌
                Count += 1
    
    return Count

# %%
# 카테고리: 카테고리에서 상품으로 이동한 로그 수
category_to_product_log = consecutive_funnel_count('카테고리', '상품')

# %%
category_to_product_log
# Out:
# 10073

# %%
# 검색: 검색에서 상품으로 이동한 로그 수
search_to_product_log = consecutive_funnel_count('검색', '상품')

# %%
search_to_product_log
# Out:
# 7442

# %%
# 다이렉트: 홈에서 바로 상품으로 이동한 로그 수
home_to_product_log = consecutive_funnel_count('홈', '상품')

# %%
home_to_product_log
# Out:
# 1910

# %%
product_log_sum = category_to_product_log + search_to_product_log + home_to_product_log

print('비율 (로그 수)\n')
print(f'카테고리: {category_to_product_log / product_log_sum * 100: .2f} %')
print(f'검    색: {search_to_product_log / product_log_sum * 100: .2f} %')
print(f'다이렉트: {home_to_product_log / product_log_sum * 100: .2f} %\n')
print(f'총  로그: {product_log_sum} 건')
# Out:
# 비율 (로그 수)
#
# 카테고리:  51.86 %
# 검    색:  38.31 %
# 다이렉트:  9.83 %
#
# 총  로그: 19425 건

# %%
print('로그 수 / 인원 수\n')
print(f'카테고리: {category_to_product_log / category_to_product: .2f}')
print(f'검    색: {search_to_product_log / search_to_product : .2f}')
print(f'다이렉트: {home_to_product_log / home_to_product: .2f}')
# Out:
# 로그 수 / 인원 수
#
# 카테고리:  6.08
# 검    색:  5.91
# 다이렉트:  2.05

# %% [markdown]
# ## 상품 > 결제완료 퍼널 분석 - lv1(funnel_desc) 기준

# %%
# '상품 -> 결제완료' 과정에서 무조건 거치고 가는 퍼널은 '메시지', '결제','거래관리'이다.
propay=result[result['funnel_desc'].isin(['상품','메시지','결제','결제완료','거래관리'])]

# %%
# 'view_desc'가 '메뉴목록-판매관리', '메뉴목록-수익관리'인 데이터들은 '의뢰인'이 아닌 '전문가'데이터이기에 제외
propay=propay.loc[(propay['view_desc']!='메뉴목록-판매관리')
                  &(propay['view_desc']!='메뉴목록-수익관리')
                  &(propay['view_desc']!='메뉴목록-마일리지 내역')]

# %%
# propay는 '결제완료' 데이터이기에 환불이나 구매 취소 관련 데이터는 제외
propay_fin=propay.loc[(propay['view_desc']!='메뉴목록-크몽캐시-캐시환불')
                      &(propay['view_desc']!='메뉴목록-구매관리-거래메시지-취소/문제해결')
                      &(propay['view_desc']!='메뉴목록-구매관리-거래메시지-취소/문제해결-제출')]

# %%
# 'user_id' 열로 그룹화하여 각 그룹마다의 'funnel_desc' 열 값을 2차원 배열로 만듦
propay_fin_id = propay_fin.groupby('user_id')['funnel_desc'].apply(list).reset_index(name='funnel_desc_list')

# %%
# '상품'에서 '결제완료'까지의 로그를 [[상품, 결제, 결제완료], [상품, 거래, 거래, 결제완료], ...] 형태의 2차원 배열로 저장하는 함수

# data는 반드시 함수 내 컬럼명과 데이터 타입, 내용이 일치해야 함
def make_2d_product_thankyou_lv1(data, index):
    
    funnel_list = data['funnel_desc_list'][index]
    
    # while 문을 돌 때 사용할 변수
    # 이면서 [상품 ~ 결제완료]을 슬라이싱할 때 사용할 첫 번째 인덱스
    start_idx = 0
    
    # [상품 ~ 결제완료]을 저장할 배열
    between_product_and_thankyou = []

    while start_idx < len(funnel_list):
        if funnel_list[start_idx] == '상품':

            # 상품 이후에 결제완료가 없으면 루프 종료
            if '결제완료' not in funnel_list[start_idx : ]:
                break

            # 원래 인덱스 값 + 상품 이후 처음으로 등장하는 '결제완료'의 인덱스 + '결제완료'까지 포함하기 위해 1 더하기
            end_idx = start_idx + funnel_list[start_idx:].index('결제완료') + 1
            # 상품 ~ 결제완료 까지 리스트 형태로 저장
            between_product_and_thankyou.append(funnel_list[start_idx : end_idx])

            # 기준 인덱스를 '결제완료'으로 이동
            start_idx = end_idx

        start_idx += 1 # 증감식
        
    return between_product_and_thankyou

# %%
cut_product_thankyou_log = []

for i in range(len(propay_fin_id)):
    log = make_2d_product_thankyou_lv1(propay_fin_id, i)
    
    for j in log:
        cut_product_thankyou_log.append(j)

# %%
# 2차원 배열을 돌면서 메시지, 결제, 거래관리 로그 수를 세는 함수
inbox = 0
order = 0
transaction = 0

for i in cut_product_thankyou_log :
    
    # i[1:-1]: 슬라이싱으로 처음 값('상품')과 마지막 값('결제완료') 제외
    # set()으로 중복 제거 후 다시 리스트로 변환
    log_list = list(set(i[1:-1]))
    
    # 퍼널 카운트
    for j in log_list :
        if j == '메시지':
            inbox+=1
        elif j=='결제':
            order+=1
        else :
            transaction+=1

# %%
total_log = inbox + order + transaction

print(f'메  시  지: {inbox} 건')
print(f'결      제: {order} 건')
print(f'거 래 관 리: {transaction} 건')

print(f'----\n합계: {total_log} 건\n')

print(f'메  시  지: {inbox / total_log * 100 : .2f} %')
print(f'결      제: {order / total_log * 100 : .2f} %')
print(f'거 래 관 리: {transaction / total_log * 100 : .2f} %')
# Out:
# 메  시  지: 211 건
# 결      제: 351 건
# 거 래 관 리: 491 건
# ----
# 합계: 1053 건
#
# 메  시  지:  20.04 %
# 결      제:  33.33 %
# 거 래 관 리:  46.63 %

# %% [markdown]
# ## 상품 > 결제완료 상세 퍼널 분석 - lv2(view_desc) 기준

# %%
# 'user_id' 열로 그룹화하여 각 그룹마다의 'view_desc' 열 값을 2차원 배열로 만듦
propay_fin_view = propay_fin.groupby('user_id')['view_desc'].apply(list).reset_index(name='view_desc_list')
propay_fin_view['funnel_desc_list'] = propay_fin_id['funnel_desc_list']

# %%
# data는 반드시 함수 내 컬럼명과 데이터 타입이 일치해야 함
def make_2d_product_thankyou_lv2(data, index):
    lv1_list = data['funnel_desc_list'][index]
    lv2_list = data['view_desc_list'][index]
    # while 문을 돌 때 사용할 변수
    # 이면서 [상품 ~ 결제완료]을 슬라이싱할 때 사용할 첫 번째 인덱스
    start_idx = 0
    
    # [홈 ~ 상품]을 저장할 배열
    between_product_and_thankyou = []

    while start_idx < len(lv1_list):
        if lv1_list[start_idx] == '상품':

            # 홈 이후에 상품이 없으면 루프 종료
            if '결제완료' not in lv1_list[start_idx : ]:
                break

            # 원래 인덱스 값 + 홈 이후 처음으로 등장하는 '상품'의 인덱스 + '상품'까지 포함하기 위해 1 더하기
            end_idx = start_idx + lv1_list[start_idx:].index('결제완료') + 1
            # 홈 ~ 상품 까지 리스트 형태로 저장
            between_product_and_thankyou.append(lv2_list[start_idx : end_idx])

            # 기준 인덱스를 '상품'으로 이동
            start_idx = end_idx

        start_idx += 1 # 증감식
        
    return between_product_and_thankyou

# %%
cut_lv2_product_thankyou_log = []

for i in range(len(propay_fin_view)):
    log = make_2d_product_thankyou_lv2(propay_fin_view, i)
    
    for j in log:
        cut_lv2_product_thankyou_log.append(j)
        
cut_lv2_product_thankyou_log
# Out:
# [['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시-캐시충전하기',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시-캐시충전하기',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시-캐시충전하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시-캐시충전하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세', '상품상세', '상품상세', '상품상세', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세', '메시지목록-상세', '메시지목록 (탭)', '메시지목록-상세', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '메시지목록-상세', '메시지목록-상세', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '전문가프로필',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '메시지목록-상세',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '전문가프로필',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시-캐시충전하기',
#   '메뉴목록-크몽캐시',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['전문가프로필', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['전문가프로필', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세-결제요청',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세-결제요청',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['전문가프로필',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
# ...
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-쿠폰내역',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['전문가프로필',
#   '메시지목록-상세',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세-결제요청',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['전문가프로필', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '결제완료'],
#  ['전문가프로필',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-주문하기',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['전문가프로필', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '전문가프로필',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '전문가프로필',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-결제내역',
#   '메뉴목록 (탭)',
#   '메뉴목록-크몽캐시',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록 (탭)',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메뉴목록 (탭)',
#   '메뉴목록-구매관리',
#   '메뉴목록-구매관리-거래메시지',
#   '메뉴목록-구매관리',
#   '메뉴목록 (탭)',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료'],
#  ['전문가프로필', '상품상세', '상품상세-상품선택', '상품상세-주문하기', '상품상세-주문하기-결제하기', '결제완료'],
#  ['상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록 (탭)',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '상품상세-주문하기-결제하기',
#   '결제완료'],
#  ['상품상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '메시지목록-상세',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '메시지목록-상세',
#   '상품상세',
#   '상품상세-상품선택',
#   '상품상세-주문하기',
#   '결제완료']]

# %%
# 2차원 배열을 돌면서 '메시지, 결제, 거래관리'의 상세 페이지 로그 수를 세는 함수
inbox_tab, inbox_detail, inbox_detail_orderRequest = 0, 0, 0
order_addOption, order_payment, kmongCash_charge = 0, 0, 0
menu, buyer_order_track, buyer_order_history, buyer_coupon_history, buyer_payment_history, kmongCash_history = 0, 0, 0, 0, 0, 0

for i in cut_lv2_product_thankyou_log :

    log_list = list(set(i[1:-1]))
    
    for j in log_list :
        
        # '메시지'상세 페이지 퍼널 카운트
        if j == '메시지목록(탭)':
            inbox_tab+=1
        elif j=='메시지목록-상세':
            inbox_detail_orderRequest+=1
        elif j=='메시지목록-상세-결제요청':
            inbox_detail_orderRequest+=1
            
        # '결제' 상세 페이지 퍼널 카운트
        elif j == '상품상세-주문하기':
            order_addOption+=1
        elif j=='상품상세-주문하기-결제하기':
            order_payment+=1
        elif j=='메뉴목록-크몽캐시-캐시충전하기':
            kmongCash_charge+=1
            
        # '거래관리' 상세 페이지 퍼널 카운트
        elif j == '메뉴목록(탭)':
            menu+=1
        elif j=='메뉴목록-구매관리-거래메시지':
            buyer_order_track+=1
        elif j=='메뉴목록-구매관리':
            buyer_order_history+=1
        elif j == '메뉴목록-쿠폰내역':
            buyer_coupon_history+=1
        elif j=='메뉴목록-결제내역':
            buyer_payment_history+=1
        elif j=='메뉴목록-크몽캐시':
            kmongCash_history+=1

# %%
total_inbox_log = inbox_tab + inbox_detail + inbox_detail_orderRequest
total_order_log = order_addOption + order_payment + kmongCash_charge
total_transaction_log = menu + buyer_order_track + buyer_order_history + buyer_coupon_history + buyer_payment_history + kmongCash_history

# %%
print('< 메시지의 상세 페이지 로그 수 >\n')
print(f'메시지목록(탭):           {inbox_tab} 건')
print(f'메시지목록-상세:          {inbox_detail} 건')
print(f'메시지목록-상세-결제요청: {inbox_detail_orderRequest} 건')
print(f'-------------------------------')
print(f'                    합계: {total_inbox_log} 건\n\n')

print('< 메시지의 상세 페이지 비율 >\n')
print(f'메시지목록(탭):           {inbox_tab / total_inbox_log * 100 : .2f} %')
print(f'메시지목록-상세:          {inbox_detail / total_inbox_log * 100 : .2f} %')
print(f'메시지목록-상세-결제요청: {inbox_detail_orderRequest / total_inbox_log * 100 : .2f} %')
print(f'------------------------------------')
print(f'                    합계:  100.00 %')
# Out:
# < 메시지의 상세 페이지 로그 수 >
#
# 메시지목록(탭):           0 건
# 메시지목록-상세:          0 건
# 메시지목록-상세-결제요청: 210 건
# -------------------------------
#                     합계: 210 건
#
#
# < 메시지의 상세 페이지 비율 >
#
# 메시지목록(탭):            0.00 %
# 메시지목록-상세:           0.00 %
# 메시지목록-상세-결제요청:  100.00 %
# ------------------------------------
#                     합계:  100.00 %

# %%
print('< 결제의 상세 페이지 로그 수 >\n')
print(f'상품상세-주문하기:              {order_addOption} 건')
print(f'상품상세-주문하기-결제하기:     {order_payment} 건')
print(f'메뉴목록-크몽캐시-캐시충전하기: {kmongCash_charge} 건')
print(f'--------------------------------------')
print(f'                          합계: {total_order_log} 건\n\n')

print('< 결제의 상세 페이지 비율 >\n')
print(f'상  품  상  세 - 주  문  하 기: {order_addOption / total_order_log * 100 : .2f} %')
print(f'상품상세 - 주문하기 - 결제하기: {order_payment / total_order_log * 100 : .2f} %')
print(f'메뉴목록-크몽캐시-캐시충전하기: {kmongCash_charge / total_order_log * 100 : .2f} %')
print(f'-----------------------------------------')
print(f'                          합계: 100.00 %')
# Out:
# < 결제의 상세 페이지 로그 수 >
#
# 상품상세-주문하기:              348 건
# 상품상세-주문하기-결제하기:     133 건
# 메뉴목록-크몽캐시-캐시충전하기: 8 건
# --------------------------------------
#                           합계: 489 건
#
#
# < 결제의 상세 페이지 비율 >
#
# 상  품  상  세 - 주  문  하 기:  71.17 %
# 상품상세 - 주문하기 - 결제하기:  27.20 %
# 메뉴목록-크몽캐시-캐시충전하기:  1.64 %
# -----------------------------------------
#                           합계: 100.00 %

# %%
print('< 거래관리의 상세 페이지 로그 수 >\n')
print(f'메뉴목록(탭):                 {menu} 건')
print(f'메뉴목록-구매관리-거래메시지: {buyer_order_track} 건')
print(f'메뉴목록-구매관리:            {buyer_order_history} 건')
print(f'메뉴목록-쿠폰내역:            {buyer_coupon_history} 건')
print(f'메뉴목록-결제내역:            {buyer_payment_history} 건')
print(f'메뉴목록-크몽캐시:            {kmongCash_history} 건')
print(f'-----------------------------------')
print(f'                        합계: {total_transaction_log} 건\n\n')

print('< 거래관리의 상세 페이지 비율 >\n')
print(f'메뉴목록(탭):                 {menu / total_transaction_log * 100 : .2f} %')
print(f'메뉴목록-구매관리-거래메시지: {buyer_order_track / total_transaction_log * 100 : .2f} %')
print(f'메뉴목록-구매관리:            {buyer_order_history / total_transaction_log * 100 : .2f} %')
print(f'메뉴목록-쿠폰내역:            {buyer_coupon_history / total_transaction_log * 100 : .2f} %')
print(f'메뉴목록-결제내역:            {buyer_payment_history / total_transaction_log * 100 : .2f} %')
print(f'메뉴목록-크몽캐시:            {kmongCash_history / total_transaction_log * 100 : .2f} %')
print(f'---------------------------------------')
print(f'                         합계: 100.00 %')
# Out:
# < 거래관리의 상세 페이지 로그 수 >
#
# 메뉴목록(탭):                 0 건
# 메뉴목록-구매관리-거래메시지: 80 건
# 메뉴목록-구매관리:            63 건
# 메뉴목록-쿠폰내역:            12 건
# 메뉴목록-결제내역:            21 건
# 메뉴목록-크몽캐시:            14 건
# -----------------------------------
#                         합계: 190 건
#
#
# < 거래관리의 상세 페이지 비율 >
#
# 메뉴목록(탭):                  0.00 %
# 메뉴목록-구매관리-거래메시지:  42.11 %
# 메뉴목록-구매관리:             33.16 %
# 메뉴목록-쿠폰내역:             6.32 %
# 메뉴목록-결제내역:             11.05 %
# 메뉴목록-크몽캐시:             7.37 %
# ---------------------------------------
#                          합계: 100.00 %

# %% [markdown]
# ## 고객 유형별 카테고리 관심도 수치

# %%
# 결제 직전 로그. 하지만 결제완료는 하지 않은 로그

no_thankyou = result[~result.user_id.isin(result[result.funnel_desc=='결제완료'].user_id.unique())]

result_notcom = no_thankyou[no_thankyou.view_desc.isin(['상품상세-주문하기','상품상세-주문하기-결제하기', '메뉴목록-구매관리-거래메시지','메시지목록-상세-결제요청', '메뉴목록-크몽캐시-캐시충전하기'])]

# %%
# 결제완료한 로그
result_completed=result.loc[result["funnel_desc"]=="결제완료"]

# %%
# 재구매한 로그
result_repay=result.loc[result['funnel_desc']=='결제완료'].loc[result['is_first_goal_activity']==False]

# %%
def category1_ratio(data):
    print(data.category1.value_counts(normalize=True))

# %%
# 전체 고객의 카테고리별 관심도 수치
category1_ratio(result)
# Out:
# 디자인         0.295295
# 마케팅         0.259871
# 콘텐츠 제작      0.092991
# 상담·컨설팅      0.079281
# 레슨          0.077917
# 문서작성        0.069386
# IT·프로그래밍    0.066279
# 번역·통역       0.030411
# 핸드메이드       0.028570
# Name: category1, dtype: float64

# %%
# 결제완료한 고객의 카테고리별 관심도 수치
category1_ratio(result_completed)
# Out:
# 마케팅         0.537671
# 상담·컨설팅      0.164384
# 디자인         0.154110
# 문서작성        0.054795
# 콘텐츠 제작      0.037671
# 레슨          0.027397
# 번역·통역       0.013699
# IT·프로그래밍    0.006849
# 핸드메이드       0.003425
# Name: category1, dtype: float64

# %%
# 재구매한 고객의 카테고리별 관심도 수치
category1_ratio(result_repay)
# Out:
# 마케팅         0.646617
# 상담·컨설팅      0.187970
# 디자인         0.082707
# 문서작성        0.037594
# IT·프로그래밍    0.015038
# 콘텐츠 제작      0.015038
# 레슨          0.007519
# 번역·통역       0.007519
# Name: category1, dtype: float64

# %%
# 결제직전(결제완료는 하지 않은)까지 간 고객의 카테고리별 관심도 수치
category1_ratio(result_notcom)
# Out:
# 마케팅         0.384298
# 디자인         0.198347
# 문서작성        0.128099
# 상담·컨설팅      0.115702
# 콘텐츠 제작      0.049587
# IT·프로그래밍    0.037190
# 번역·통역       0.033058
# 레슨          0.033058
# 핸드메이드       0.020661
# Name: category1, dtype: float64

# %%
def category2_ratio(data):
    for i in data.category1.unique():
        print('<',i,'>')
        print(data[data.category1==i].category2.value_counts(normalize=True))
        print('----------------------------------')

# %%
category2_ratio(result)
# Out:
# < nan >
# Series([], Name: category2, dtype: float64)
# ----------------------------------
# < 문서작성 >
# 자기소개서·이력서    0.541022
# 글작성·창작·대본    0.110949
# 사업계획서·제안서    0.080876
# 카피라이팅        0.058394
# 타이핑          0.051679
# 교정·교열·편집     0.047007
# 보고서·리포트      0.033285
# 학문·논설        0.028029
# 문서서식·폼       0.024818
# 기타           0.019270
# 리서치·자료수집     0.004672
# Name: category2, dtype: float64
# ----------------------------------
# < 디자인 >
# 로고디자인        0.204276
# 명함·인쇄물       0.125429
# 일러스트·삽화      0.108325
# 3D 모델링·도면    0.082475
# 배너·상세페이지     0.082151
# 패키지·북커버      0.050081
# SNS·커뮤니티     0.049951
# 캘리그라피        0.048980
# 웹툰·캐릭터       0.044250
# 포토샵편집        0.042371
# 웹·모바일 디자인    0.035050
# 캐리커쳐·인물      0.033949
# 현수막·POP      0.028571
# PPT·인포그래픽    0.025462
# 공간·인테리어      0.020538
# 의류디자인        0.010820
# 기타           0.007321
# Name: category2, dtype: float64
# ----------------------------------
# < 마케팅 >
# SNS 마케팅       0.325069
# 카페·블로그        0.205234
# 상위노출·검색작업     0.155357
# 체험단·바이럴마케팅    0.057851
# 마케팅 컨설팅       0.048427
# 언론홍보          0.040380
# 기타            0.026243
# 검색최적화·SEO     0.020516
# 쇼핑몰           0.020516
# 키워드광고         0.019936
# 인플루언서         0.017906
# 앱·지도평가        0.016384
# 배너노출광고        0.014064
# 영상·PPL        0.009424
# 오프라인광고        0.008772
# 해외마케팅         0.007467
# 이메일·메시지       0.006452
# Name: category2, dtype: float64
# ----------------------------------
# < 핸드메이드 >
# 리빙·오피스    0.384196
# 패션        0.183470
# 전통주       0.092643
# 기타        0.085377
# 푸드        0.061762
# 육아·아동     0.060854
# 뷰티        0.052679
# 웨딩·파티     0.039964
# 반려동물      0.039055
# Name: category2, dtype: float64
# ----------------------------------
# < 콘텐츠 제작 >
# 영상        0.414223
# 사진        0.242670
# 더빙·녹음     0.221663
# 음악·사운드    0.089716
# 엔터테이너     0.022757
# 기타        0.008972
# Name: category2, dtype: float64
# ----------------------------------
# < 레슨 >
# 스포츠       0.151692
# 외국어       0.137690
# 영상        0.114352
# 컴퓨터       0.109977
# 뷰티·미용     0.070012
# 음악        0.063302
# 그래픽디자인    0.062719
# 자기계발      0.056301
# 악기        0.042590
# 사진        0.042299
# 취미미술      0.034131
# 공예        0.033256
# 요리·조리     0.030630
# 공간대여      0.027421
# 입시·학업     0.012252
# 기타        0.011377
# Name: category2, dtype: float64
# ----------------------------------
# < 상담·컨설팅 >
# 운세         0.416031
# 창업·사업계획    0.163868
# 연애상담       0.095929
# 취업         0.058270
# 비즈니스 팁     0.043766
# 여행         0.038931
# 심리상담       0.035369
# 기타         0.031552
# 자산관리       0.021374
# 구매·생활팁     0.020102
# 학업         0.015776
# 시장조사       0.015522
# 법률 자문      0.014504
# 세무회계       0.013486
# 특허         0.008397
# 법무         0.007125
# Name: category2, dtype: float64
# ----------------------------------
# < IT·프로그래밍 >
# 웹사이트 개발      0.248376
# 모바일앱·웹       0.213115
# 프로그램 개발      0.185586
# 쇼핑몰·커머스      0.107949
# 워드프레스        0.085370
# 데이터분석·리포트    0.057222
# 게임           0.037117
# 서버 및 기술지원    0.021033
# 기타           0.012991
# 챗봇           0.011135
# QA·테스트       0.007423
# 파일변환         0.006496
# 데이터베이스       0.006186
# Name: category2, dtype: float64
# ----------------------------------
# < 번역·통역 >
# 번역    0.888169
# 통역    0.111831
# Name: category2, dtype: float64
# ----------------------------------

# %%
category2_ratio(result_completed)
# Out:
# < nan >
# Series([], Name: category2, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 >
# 운세         0.729167
# 연애상담       0.104167
# 창업·사업계획    0.083333
# 자산관리       0.020833
# 취업         0.020833
# 여행         0.020833
# 기타         0.020833
# Name: category2, dtype: float64
# ----------------------------------
# < 문서작성 >
# 자기소개서·이력서    0.7500
# 카피라이팅        0.1250
# 사업계획서·제안서    0.0625
# 글작성·창작·대본    0.0625
# Name: category2, dtype: float64
# ----------------------------------
# < 디자인 >
# 로고디자인        0.422222
# 포토샵편집        0.111111
# SNS·커뮤니티     0.111111
# 명함·인쇄물       0.088889
# 일러스트·삽화      0.066667
# 캘리그라피        0.066667
# 캐리커쳐·인물      0.022222
# 기타           0.022222
# 배너·상세페이지     0.022222
# 3D 모델링·도면    0.022222
# PPT·인포그래픽    0.022222
# 웹툰·캐릭터       0.022222
# Name: category2, dtype: float64
# ----------------------------------
# < 마케팅 >
# SNS 마케팅       0.617834
# 카페·블로그        0.140127
# 체험단·바이럴마케팅    0.076433
# 상위노출·검색작업     0.038217
# 쇼핑몰           0.031847
# 기타            0.025478
# 마케팅 컨설팅       0.025478
# 언론홍보          0.012739
# 앱·지도평가        0.012739
# 이메일·메시지       0.012739
# 검색최적화·SEO     0.006369
# Name: category2, dtype: float64
# ----------------------------------
# < 레슨 >
# 컴퓨터    0.500
# 사진     0.125
# 음악     0.125
# 영상     0.125
# 외국어    0.125
# Name: category2, dtype: float64
# ----------------------------------
# < 콘텐츠 제작 >
# 더빙·녹음     0.363636
# 음악·사운드    0.272727
# 사진        0.181818
# 영상        0.181818
# Name: category2, dtype: float64
# ----------------------------------
# < 핸드메이드 >
# 리빙·오피스    1.0
# Name: category2, dtype: float64
# ----------------------------------
# < IT·프로그래밍 >
# 쇼핑몰·커머스    0.5
# 워드프레스      0.5
# Name: category2, dtype: float64
# ----------------------------------
# < 번역·통역 >
# 번역    1.0
# Name: category2, dtype: float64
# ----------------------------------

# %%
category2_ratio(result_repay)
# Out:
# < nan >
# Series([], Name: category2, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 >
# 운세         0.68
# 창업·사업계획    0.12
# 연애상담       0.12
# 기타         0.04
# 취업         0.04
# Name: category2, dtype: float64
# ----------------------------------
# < 마케팅 >
# SNS 마케팅       0.686047
# 카페·블로그        0.116279
# 체험단·바이럴마케팅    0.069767
# 쇼핑몰           0.046512
# 상위노출·검색작업     0.023256
# 기타            0.011628
# 앱·지도평가        0.011628
# 언론홍보          0.011628
# 마케팅 컨설팅       0.011628
# 이메일·메시지       0.011628
# Name: category2, dtype: float64
# ----------------------------------
# < 디자인 >
# 로고디자인        0.363636
# 포토샵편집        0.181818
# 캘리그라피        0.090909
# 명함·인쇄물       0.090909
# 3D 모델링·도면    0.090909
# SNS·커뮤니티     0.090909
# 기타           0.090909
# Name: category2, dtype: float64
# ----------------------------------
# < IT·프로그래밍 >
# 쇼핑몰·커머스    0.5
# 워드프레스      0.5
# Name: category2, dtype: float64
# ----------------------------------
# < 문서작성 >
# 자기소개서·이력서    0.8
# 글작성·창작·대본    0.2
# Name: category2, dtype: float64
# ----------------------------------
# < 콘텐츠 제작 >
# 사진       0.5
# 더빙·녹음    0.5
# Name: category2, dtype: float64
# ----------------------------------
# < 레슨 >
# 사진    1.0
# Name: category2, dtype: float64
# ----------------------------------
# < 번역·통역 >
# 번역    1.0
# Name: category2, dtype: float64
# ----------------------------------

# %%
category2_ratio(result_notcom)
# Out:
# < nan >
# Series([], Name: category2, dtype: float64)
# ----------------------------------
# < 마케팅 >
# SNS 마케팅       0.322581
# 카페·블로그        0.172043
# 마케팅 컨설팅       0.150538
# 검색최적화·SEO     0.139785
# 체험단·바이럴마케팅    0.064516
# 언론홍보          0.053763
# 기타            0.043011
# 상위노출·검색작업     0.043011
# 키워드광고         0.010753
# Name: category2, dtype: float64
# ----------------------------------
# < 디자인 >
# 명함·인쇄물       0.291667
# 로고디자인        0.145833
# 캐리커쳐·인물      0.125000
# 패키지·북커버      0.125000
# 캘리그라피        0.083333
# 3D 모델링·도면    0.062500
# 웹툰·캐릭터       0.062500
# 일러스트·삽화      0.041667
# 포토샵편집        0.020833
# 웹·모바일 디자인    0.020833
# 의류디자인        0.020833
# Name: category2, dtype: float64
# ----------------------------------
# < 문서작성 >
# 자기소개서·이력서    0.903226
# 문서서식·폼       0.064516
# 글작성·창작·대본    0.032258
# Name: category2, dtype: float64
# ----------------------------------
# < 레슨 >
# 뷰티·미용    0.375
# 영상       0.250
# 스포츠      0.250
# 공예       0.125
# Name: category2, dtype: float64
# ----------------------------------
# < 상담·컨설팅 >
# 운세         0.357143
# 연애상담       0.250000
# 세무회계       0.107143
# 여행         0.071429
# 학업         0.071429
# 법률 자문      0.071429
# 특허         0.035714
# 창업·사업계획    0.035714
# Name: category2, dtype: float64
# ----------------------------------
# < 콘텐츠 제작 >
# 음악·사운드    0.666667
# 사진        0.333333
# Name: category2, dtype: float64
# ----------------------------------
# < IT·프로그래밍 >
# 웹사이트 개발    0.777778
# 모바일앱·웹     0.222222
# Name: category2, dtype: float64
# ----------------------------------
# < 핸드메이드 >
# 리빙·오피스    1.0
# Name: category2, dtype: float64
# ----------------------------------
# < 번역·통역 >
# 번역    1.0
# Name: category2, dtype: float64
# ----------------------------------

# %%
def category3_ratio(data):
    for i in data.category1.unique():
        for j in data[data.category1==i].category2.unique():
            print('<', i,'-', j, '>')
            print(data[(data.category1==i)&(data.category2==j)].category3.value_counts(normalize=True))
            print('----------------------------------')

# %%
category3_ratio(result)
# Out:
# < 문서작성 - 자기소개서·이력서 >
# 자기소개서    0.987867
# 이력서      0.012133
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 타이핑 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 사업계획서·제안서 >
# 사업계획서    0.832536
# 제안서      0.167464
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 문서서식·폼 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 카피라이팅 >
# 기업명·슬로건     0.668874
# 광고 카피라이팅    0.172185
# 상품소개        0.112583
# 웹 카피라이팅     0.046358
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 글작성·창작·대본 >
# 블로그        0.444444
# 스크립트·각본    0.277778
# 이야기·시      0.227273
# 책·전자책      0.050505
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 보고서·리포트 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 학문·논설 >
# 논문     0.911765
# 에세이    0.088235
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 교정·교열·편집 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 리서치·자료수집 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 3D 모델링·도면 >
# 제품디자인     0.512795
# 공간디자인     0.359252
# 3D 프린팅    0.127953
# Name: category3, dtype: float64
# ----------------------------------
# < 디자인 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 로고디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - SNS·커뮤니티 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 의류디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캐리커쳐·인물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 웹툰·캐릭터 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 포토샵편집 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 현수막·POP >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 배너·상세페이지 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 공간·인테리어 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 일러스트·삽화 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 패키지·북커버 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캘리그라피 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 웹·모바일 디자인 >
# 그래픽 UI       0.726619
# 와이어프레임 UX    0.161871
# 아이콘·버튼       0.111511
# Name: category3, dtype: float64
# ----------------------------------
# < 디자인 - 명함·인쇄물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - PPT·인포그래픽 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 이메일·메시지 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - SNS 마케팅 >
# 구독자·팔로워    0.450168
# 홍보         0.381299
# 포스팅        0.094905
# 계정운영       0.073628
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 키워드광고 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 카페·블로그 >
# 포스팅     0.554253
# 관리운영    0.247830
# 트래픽     0.197917
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 마케팅 컨설팅 >
# 노하우            0.948718
# 브랜드 마케팅 노하우    0.051282
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 체험단·바이럴마케팅 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 쇼핑몰 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 오프라인광고 >
# 송출·영상광고    0.741176
# 교통매체광고     0.247059
# 신문·잡지광고    0.011765
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 배너노출광고 >
# SNS 배너광고     0.375000
# 블로그/카페       0.298611
# 기타 배너광고      0.173611
# 포털사이트        0.118056
# 네트워크 배너광고    0.034722
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 인플루언서 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 상위노출·검색작업 >
# 카페·블로그       0.487324
# 연관검색·자동완성    0.356056
# 앱·지도평가       0.109859
# 질문답변·기타      0.046761
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 언론홍보 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 검색최적화·SEO >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 영상·PPL >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 앱·지도평가 >
# 지도평가      0.573248
# 앱 다운로드    0.286624
# 앱 리뷰      0.140127
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 해외마케팅 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 육아·아동 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 뷰티 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 리빙·오피스 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 푸드 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 패션 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 반려동물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 웨딩·파티 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 전통주 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 음악·사운드 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 더빙·녹음 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 영상 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 엔터테이너 >
# 모델    0.740741
# 공연    0.148148
# MC    0.061728
# 기타    0.049383
# Name: category3, dtype: float64
# ----------------------------------
# < 레슨 - 외국어 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 컴퓨터 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 스포츠 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 그래픽디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 영상 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 음악 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 취미미술 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 요리·조리 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 뷰티·미용 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 공예 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 악기 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 자기계발 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 공간대여 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 입시·학업 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 연애상담 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 창업·사업계획 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 운세 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 심리상담 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 취업 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 여행 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 학업 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 세무회계 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 비즈니스 팁 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 특허 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 구매·생활팁 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 자산관리 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 시장조사 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 법률 자문 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 법무 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - 웹사이트 개발 >
# 웹사이트 제작          0.527046
# 웹사이트 개선          0.241331
# 웹사이트 제작(CMS)     0.119279
# HTML·CSS 퍼블리싱    0.079057
# 기타               0.018031
# 랜딩페이지            0.012483
# 보안               0.002774
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 데이터분석·리포트 >
# 데이터 마이닝·크롤링    0.568627
# VBA·매크로        0.300654
# 데이터 분석         0.111111
# 데이터 시각화        0.019608
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 프로그램 개발 >
# 일반 프로그램     0.838624
# 임베디드 시스템    0.113757
# 버그 수정       0.023810
# 기타          0.013228
# 프로그램 개선     0.010582
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - 쇼핑몰·커머스 >
# 웹사이트 개선         0.430000
# 웹사이트 제작(CMS)    0.293333
# 웹사이트 제작         0.250000
# 퍼포먼스·SEO        0.026667
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 워드프레스 >
# 웹사이트 제작      0.616438
# 웹사이트 개선      0.210046
# 복제·마이그레이션    0.086758
# 설치·설정        0.068493
# 퍼포먼스·SEO     0.009132
# 버그 수정        0.004566
# 랜딩페이지        0.004566
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 모바일앱·웹 >
# 네이티브앱    0.821363
# 웹앱       0.090239
# 앱 개선     0.042357
# 기타       0.025783
# 버그 수정    0.020258
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 게임 >
# 2D    0.710526
# 3D    0.263158
# 서버    0.026316
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 챗봇 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - 서버 및 기술지원 >
# 서버·호스팅      0.6
# 데스크탑·노트북    0.4
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 파일변환 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - QA·테스트 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - 데이터베이스 >
# 쿼리        0.666667
# 최적화·설계    0.333333
# Name: category3, dtype: float64
# ----------------------------------
# < 번역·통역 - nan >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 번역·통역 - 번역 >
# 영어        0.444792
# 중국어       0.242708
# 일본어       0.187500
# 스페인어      0.054167
# 기타        0.026042
# 베트남어      0.021875
# 프랑스어      0.008333
# 독일어       0.007292
# 인도네시아어    0.005208
# 러시아어      0.002083
# Name: category3, dtype: float64
# ----------------------------------
# < 번역·통역 - 통역 >
# 영어        0.394495
# 일본어       0.348624
# 중국어       0.100917
# 러시아어      0.055046
# 베트남어      0.055046
# 기타        0.018349
# 프랑스어      0.018349
# 인도네시아어    0.009174
# Name: category3, dtype: float64
# ----------------------------------

# %%
category3_ratio(result_completed)
# Out:
# < 상담·컨설팅 - 연애상담 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 운세 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 취업 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 창업·사업계획 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 여행 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 자산관리 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 자기소개서·이력서 >
# 자기소개서    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 사업계획서·제안서 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 글작성·창작·대본 >
# 블로그    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 카피라이팅 >
# 상품소개        0.5
# 광고 카피라이팅    0.5
# Name: category3, dtype: float64
# ----------------------------------
# < 디자인 - PPT·인포그래픽 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 포토샵편집 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 로고디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캘리그라피 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - SNS·커뮤니티 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 명함·인쇄물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 일러스트·삽화 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 배너·상세페이지 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캐리커쳐·인물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 3D 모델링·도면 >
# 제품디자인    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 디자인 - 웹툰·캐릭터 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - SNS 마케팅 >
# 홍보         0.494118
# 구독자·팔로워    0.470588
# 계정운영       0.023529
# 포스팅        0.011765
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 카페·블로그 >
# 포스팅    0.52381
# 트래픽    0.47619
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 쇼핑몰 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 마케팅 컨설팅 >
# 노하우    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 상위노출·검색작업 >
# 연관검색·자동완성    0.6
# 질문답변·기타      0.2
# 카페·블로그       0.2
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 검색최적화·SEO >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 언론홍보 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 체험단·바이럴마케팅 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 앱·지도평가 >
# 지도평가    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 이메일·메시지 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 컴퓨터 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 음악 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 외국어 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 영상 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 영상 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 더빙·녹음 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 음악·사운드 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 핸드메이드 - 리빙·오피스 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - 쇼핑몰·커머스 >
# 웹사이트 제작    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 워드프레스 >
# 웹사이트 제작    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 번역·통역 - 번역 >
# 영어     0.5
# 일본어    0.5
# Name: category3, dtype: float64
# ----------------------------------

# %%
category3_ratio(result_repay)
# Out:
# < 상담·컨설팅 - 연애상담 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 운세 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 취업 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 창업·사업계획 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - SNS 마케팅 >
# 홍보         0.588235
# 구독자·팔로워    0.411765
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 카페·블로그 >
# 포스팅    0.6
# 트래픽    0.4
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 쇼핑몰 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 마케팅 컨설팅 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 체험단·바이럴마케팅 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 상위노출·검색작업 >
# 연관검색·자동완성    0.5
# 질문답변·기타      0.5
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 이메일·메시지 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 앱·지도평가 >
# 지도평가    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 언론홍보 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 포토샵편집 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캘리그라피 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 로고디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 명함·인쇄물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - SNS·커뮤니티 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 3D 모델링·도면 >
# 제품디자인    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 쇼핑몰·커머스 >
# 웹사이트 제작    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 워드프레스 >
# 웹사이트 제작    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 자기소개서·이력서 >
# 자기소개서    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 글작성·창작·대본 >
# 블로그    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 콘텐츠 제작 - 더빙·녹음 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 번역·통역 - 번역 >
# 일본어    1.0
# Name: category3, dtype: float64
# ----------------------------------

# %%
category3_ratio(result_notcom)
# Out:
# < 마케팅 - 카페·블로그 >
# 트래픽     0.50
# 관리운영    0.25
# 포스팅     0.25
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - SNS 마케팅 >
# 구독자·팔로워    0.8
# 홍보         0.2
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 언론홍보 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 체험단·바이럴마케팅 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 상위노출·검색작업 >
# 연관검색·자동완성    0.5
# 카페·블로그       0.5
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 키워드광고 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 마케팅 컨설팅 >
# 노하우    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 마케팅 - 기타 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 마케팅 - 검색최적화·SEO >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 포토샵편집 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 의류디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 명함·인쇄물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캘리그라피 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 웹툰·캐릭터 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 웹·모바일 디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 캐리커쳐·인물 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 로고디자인 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 3D 모델링·도면 >
# 제품디자인    0.666667
# 공간디자인    0.333333
# Name: category3, dtype: float64
# ----------------------------------
# < 디자인 - 패키지·북커버 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 디자인 - 일러스트·삽화 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 문서서식·폼 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 문서작성 - 자기소개서·이력서 >
# 자기소개서    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 문서작성 - 글작성·창작·대본 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 스포츠 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 공예 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 뷰티·미용 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 레슨 - 영상 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 운세 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 연애상담 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 법률 자문 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 특허 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 세무회계 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 창업·사업계획 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 여행 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 상담·컨설팅 - 학업 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 사진 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 콘텐츠 제작 - 음악·사운드 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < IT·프로그래밍 - 웹사이트 개발 >
# 웹사이트 제작    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < IT·프로그래밍 - 모바일앱·웹 >
# 네이티브앱    1.0
# Name: category3, dtype: float64
# ----------------------------------
# < 핸드메이드 - 리빙·오피스 >
# Series([], Name: category3, dtype: float64)
# ----------------------------------
# < 번역·통역 - 번역 >
# 영어    1.0
# Name: category3, dtype: float64
# ----------------------------------

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### 머문 시간 계산

# %%
data = result.sort_values(['user_id', 'event_datetime']).copy()

# %%
data['time_shift'] = data.event_datetime.shift(-1).fillna(method='ffill')
data['time_shift'] = pd.to_datetime(data['time_shift'])
data['user_shift'] = data.user_id.shift(-1).fillna(0)

data[['user_id', 'user_shift', 'event_datetime', 'time_shift']]
# Out:
#                                                                    user_id  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2  00000000-0000-0000-0000-000000000000
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 6f7650bb-0429-4085-845b-815d756f7225  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 4046b150-4566-483e-a9ed-0e2460896481  001B9A43-5F55-4145-84B5-6495DF1EAF80
# d881fffc-19da-481d-9568-4680a655d595  001B9A43-5F55-4145-84B5-6495DF1EAF80
# ...                                                                    ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# eebb6e4a-8a84-45e9-bb18-8061930f1e41  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 122d2400-a285-4844-838d-df282b08ef32  ffffffff-c6bb-8616-cd10-2dbd151c76e2
#
#                                                                 user_shift  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2  001B9A43-5F55-4145-84B5-6495DF1EAF80
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 6f7650bb-0429-4085-845b-815d756f7225  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 4046b150-4566-483e-a9ed-0e2460896481  001B9A43-5F55-4145-84B5-6495DF1EAF80
# d881fffc-19da-481d-9568-4680a655d595  001B9A43-5F55-4145-84B5-6495DF1EAF80
# ...                                                                    ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# eebb6e4a-8a84-45e9-bb18-8061930f1e41  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 122d2400-a285-4844-838d-df282b08ef32                                     0
#
#                                                 event_datetime  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 2018-09-29 16:32:23+09:00
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8 2018-09-28 01:50:23+09:00
# 6f7650bb-0429-4085-845b-815d756f7225 2018-09-28 01:50:24+09:00
# 4046b150-4566-483e-a9ed-0e2460896481 2018-09-28 01:50:26+09:00
# d881fffc-19da-481d-9568-4680a655d595 2018-09-28 01:50:27+09:00
# ...                                                        ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c 2018-09-29 13:53:14+09:00
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5 2018-09-29 13:53:15+09:00
# eebb6e4a-8a84-45e9-bb18-8061930f1e41 2018-09-29 18:36:38+09:00
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d 2018-09-29 18:36:39+09:00
# 122d2400-a285-4844-838d-df282b08ef32 2018-09-29 18:36:44+09:00
#
#                                                     time_shift
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 2018-09-28 01:50:23+09:00
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8 2018-09-28 01:50:24+09:00
# 6f7650bb-0429-4085-845b-815d756f7225 2018-09-28 01:50:26+09:00
# 4046b150-4566-483e-a9ed-0e2460896481 2018-09-28 01:50:27+09:00
# d881fffc-19da-481d-9568-4680a655d595 2018-09-28 01:50:29+09:00
# ...                                                        ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c 2018-09-29 13:53:15+09:00
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5 2018-09-29 18:36:38+09:00
# eebb6e4a-8a84-45e9-bb18-8061930f1e41 2018-09-29 18:36:39+09:00
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d 2018-09-29 18:36:44+09:00
# 122d2400-a285-4844-838d-df282b08ef32 2018-09-29 18:36:44+09:00
#
# [434244 rows x 4 columns]

# %%
data['duration_time'] = data.time_shift - data.event_datetime
data[['user_id', 'user_shift', 'event_datetime', 'time_shift', 'duration_time']]
# Out:
#                                                                    user_id  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2  00000000-0000-0000-0000-000000000000
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 6f7650bb-0429-4085-845b-815d756f7225  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 4046b150-4566-483e-a9ed-0e2460896481  001B9A43-5F55-4145-84B5-6495DF1EAF80
# d881fffc-19da-481d-9568-4680a655d595  001B9A43-5F55-4145-84B5-6495DF1EAF80
# ...                                                                    ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# eebb6e4a-8a84-45e9-bb18-8061930f1e41  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 122d2400-a285-4844-838d-df282b08ef32  ffffffff-c6bb-8616-cd10-2dbd151c76e2
#
#                                                                 user_shift  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2  001B9A43-5F55-4145-84B5-6495DF1EAF80
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 6f7650bb-0429-4085-845b-815d756f7225  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 4046b150-4566-483e-a9ed-0e2460896481  001B9A43-5F55-4145-84B5-6495DF1EAF80
# d881fffc-19da-481d-9568-4680a655d595  001B9A43-5F55-4145-84B5-6495DF1EAF80
# ...                                                                    ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# eebb6e4a-8a84-45e9-bb18-8061930f1e41  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 122d2400-a285-4844-838d-df282b08ef32                                     0
#
#                                                 event_datetime  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 2018-09-29 16:32:23+09:00
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8 2018-09-28 01:50:23+09:00
# 6f7650bb-0429-4085-845b-815d756f7225 2018-09-28 01:50:24+09:00
# 4046b150-4566-483e-a9ed-0e2460896481 2018-09-28 01:50:26+09:00
# d881fffc-19da-481d-9568-4680a655d595 2018-09-28 01:50:27+09:00
# ...                                                        ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c 2018-09-29 13:53:14+09:00
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5 2018-09-29 13:53:15+09:00
# eebb6e4a-8a84-45e9-bb18-8061930f1e41 2018-09-29 18:36:38+09:00
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d 2018-09-29 18:36:39+09:00
# 122d2400-a285-4844-838d-df282b08ef32 2018-09-29 18:36:44+09:00
#
#                                                     time_shift  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 2018-09-28 01:50:23+09:00
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8 2018-09-28 01:50:24+09:00
# 6f7650bb-0429-4085-845b-815d756f7225 2018-09-28 01:50:26+09:00
# 4046b150-4566-483e-a9ed-0e2460896481 2018-09-28 01:50:27+09:00
# d881fffc-19da-481d-9568-4680a655d595 2018-09-28 01:50:29+09:00
# ...                                                        ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c 2018-09-29 13:53:15+09:00
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5 2018-09-29 18:36:38+09:00
# eebb6e4a-8a84-45e9-bb18-8061930f1e41 2018-09-29 18:36:39+09:00
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d 2018-09-29 18:36:44+09:00
# 122d2400-a285-4844-838d-df282b08ef32 2018-09-29 18:36:44+09:00
#
#                                          duration_time
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 -2 days +09:18:00
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8   0 days 00:00:01
# 6f7650bb-0429-4085-845b-815d756f7225   0 days 00:00:02
# 4046b150-4566-483e-a9ed-0e2460896481   0 days 00:00:01
# d881fffc-19da-481d-9568-4680a655d595   0 days 00:00:02
# ...                                                ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c   0 days 00:00:01
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5   0 days 04:43:23
# eebb6e4a-8a84-45e9-bb18-8061930f1e41   0 days 00:00:01
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d   0 days 00:00:05
# 122d2400-a285-4844-838d-df282b08ef32   0 days 00:00:00
#
# [434244 rows x 5 columns]

# %%
data.loc[data.user_id != data.user_shift, 'duration_time'] = None
data[['user_id', 'user_shift', 'event_datetime', 'time_shift', 'duration_time']]
# Out:
#                                                                    user_id  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2  00000000-0000-0000-0000-000000000000
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 6f7650bb-0429-4085-845b-815d756f7225  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 4046b150-4566-483e-a9ed-0e2460896481  001B9A43-5F55-4145-84B5-6495DF1EAF80
# d881fffc-19da-481d-9568-4680a655d595  001B9A43-5F55-4145-84B5-6495DF1EAF80
# ...                                                                    ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# eebb6e4a-8a84-45e9-bb18-8061930f1e41  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 122d2400-a285-4844-838d-df282b08ef32  ffffffff-c6bb-8616-cd10-2dbd151c76e2
#
#                                                                 user_shift  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2  001B9A43-5F55-4145-84B5-6495DF1EAF80
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 6f7650bb-0429-4085-845b-815d756f7225  001B9A43-5F55-4145-84B5-6495DF1EAF80
# 4046b150-4566-483e-a9ed-0e2460896481  001B9A43-5F55-4145-84B5-6495DF1EAF80
# d881fffc-19da-481d-9568-4680a655d595  001B9A43-5F55-4145-84B5-6495DF1EAF80
# ...                                                                    ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# eebb6e4a-8a84-45e9-bb18-8061930f1e41  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d  ffffffff-c6bb-8616-cd10-2dbd151c76e2
# 122d2400-a285-4844-838d-df282b08ef32                                     0
#
#                                                 event_datetime  \
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 2018-09-29 16:32:23+09:00
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8 2018-09-28 01:50:23+09:00
# 6f7650bb-0429-4085-845b-815d756f7225 2018-09-28 01:50:24+09:00
# 4046b150-4566-483e-a9ed-0e2460896481 2018-09-28 01:50:26+09:00
# d881fffc-19da-481d-9568-4680a655d595 2018-09-28 01:50:27+09:00
# ...                                                        ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c 2018-09-29 13:53:14+09:00
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5 2018-09-29 13:53:15+09:00
# eebb6e4a-8a84-45e9-bb18-8061930f1e41 2018-09-29 18:36:38+09:00
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d 2018-09-29 18:36:39+09:00
# 122d2400-a285-4844-838d-df282b08ef32 2018-09-29 18:36:44+09:00
#
#                                                     time_shift   duration_time
# row_uuid
# 2461124f-cd69-4a4d-8c38-3a51dc3087e2 2018-09-28 01:50:23+09:00             NaT
# b5131567-bde5-4b6e-8a2f-c85ee0f5fba8 2018-09-28 01:50:24+09:00 0 days 00:00:01
# 6f7650bb-0429-4085-845b-815d756f7225 2018-09-28 01:50:26+09:00 0 days 00:00:02
# 4046b150-4566-483e-a9ed-0e2460896481 2018-09-28 01:50:27+09:00 0 days 00:00:01
# d881fffc-19da-481d-9568-4680a655d595 2018-09-28 01:50:29+09:00 0 days 00:00:02
# ...                                                        ...             ...
# 742eaabd-fefb-4765-a3bb-b27c5a7efc8c 2018-09-29 13:53:15+09:00 0 days 00:00:01
# 2d93369e-d40d-4b24-bc9c-4f569b9fd4d5 2018-09-29 18:36:38+09:00 0 days 04:43:23
# eebb6e4a-8a84-45e9-bb18-8061930f1e41 2018-09-29 18:36:39+09:00 0 days 00:00:01
# 6aa5e2a5-7bb1-4f8c-a46b-8a4fe2c0345d 2018-09-29 18:36:44+09:00 0 days 00:00:05
# 122d2400-a285-4844-838d-df282b08ef32 2018-09-29 18:36:44+09:00             NaT
#
# [434244 rows x 5 columns]

# %%
data[data.view_desc=='홈 (탭)'].duration_time.mean()
# Out:
# Timedelta('0 days 00:04:02.051145624')

# %%
data[data.view_desc=='홈 (탭)'].duration_time.describe()
# Out:
# count                        53377
# mean     0 days 00:04:02.051145624
# std      0 days 01:04:41.027849658
# min                0 days 00:00:00
# 25%                0 days 00:00:01
# 50%                0 days 00:00:03
# 75%                0 days 00:00:06
# max                1 days 20:16:56
# Name: duration_time, dtype: object

# %%
data[(data.user_id.isin(home_product_id)) & (data.view_desc=='홈 (탭)')].duration_time.describe()
# Out:
# count                        33625
# mean     0 days 00:03:09.238780669
# std      0 days 00:55:15.753616273
# min                0 days 00:00:00
# 25%                0 days 00:00:01
# 50%                0 days 00:00:03
# 75%                0 days 00:00:06
# max                1 days 15:51:17
# Name: duration_time, dtype: object

# %%
# '홈' 또는 '상품'을 가지고 있는 user_id 리스트
# 이 경우, '홈'만 가지고 있거나, '상품'만 가지고 있는 id가 포함됨
id_list = list(result[result.funnel_desc.isin(['홈','결제완료'])].user_id.unique())
len(id_list)
# Out:
# 8847

# %%
# '홈'과 '상품'을 모두 가지고 있는 user_id를 저장할 리스트
home_revenue_id = []

for id in id_list:
    # 개인별 퍼널 로그 확인
    funnel_log = list(result[result.user_id == id].funnel_desc)
    
    # 개인의 로그 안에 '홈'과 '상품'이 있는 경우, 해당 아이디를 저장
    if ('홈' in funnel_log) & ('결제완료' in funnel_log):
        home_revenue_id.append(id)
        
print(len(home_revenue_id))
# Out:
# 352

# %%
data[(data.user_id.isin(home_revenue_id)) & (data.view_desc=='홈 (탭)')].duration_time.describe()
# Out:
# count                         5118
# mean     0 days 00:01:21.373388042
# std      0 days 00:30:37.682628561
# min                0 days 00:00:00
# 25%                0 days 00:00:01
# 50%                0 days 00:00:03
# 75%                0 days 00:00:05
# max                0 days 18:57:40
# Name: duration_time, dtype: object

# %%
data[(~data.user_id.isin(home_revenue_id)) & (data.view_desc=='홈 (탭)')].duration_time.describe()
# Out:
# count                        48259
# mean     0 days 00:04:19.091464804
# std      0 days 01:07:17.165174495
# min                0 days 00:00:00
# 25%                0 days 00:00:01
# 50%                0 days 00:00:03
# 75%                0 days 00:00:06
# max                1 days 20:16:56
# Name: duration_time, dtype: object
